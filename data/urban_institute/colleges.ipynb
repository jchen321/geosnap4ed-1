# %% [markdown]
# # Urban Institute API - college layer
#
# https://educationdata.urban.org/data-explorer/

# %% [markdown]
# Sources:
# - Integrated Postsecondary Education Data System (IPEDS)<br>
#     *The Integrated Postsecondary Education Data System (IPEDS) is built from
#     interrelated surveys conducted annually by the US Department of Education's
#     National Center for Education Statistics. IPEDS features data on enrollment,
#     program completion, graduation rates, faculty and staff, finances,
#     institutional prices, and student financial aid for every postsecondary
#     institution that participates in the federal student aid program. The
#     following endpoints are currently available:*
#
#     Directory<br>
#     Institutional characteristics<br>
#     Admissions<br>
#     Enrollment<br>
#     Fall retention<br>
#     Student-faculty ratios<br>
#     Graduation rates<br>
#     Outcome measures<br>
#     Completers<br>
#     Awards<br>
#     Academic libraries<br>
#     Finance<br>
#     Student financial aid<br>
#     Academic year charges<br>
#     Program year charges<br>
#
# - College Scorecard<br>
#     *Maintained by the Department of Education, the College Scorecard contains data
#     on costs, completion, financial aid, debt, repayment, and earnings for all
#     degree-granting institutions.*
#
# - National Historical Geographic Information System<br>
#     *Provided through IPUMS, the National Historical Geographic Information System
#     contains population, housing, agriculture, and economic data for all census
#     geographies from 1790 through the present.*
#
# - Federal Student Aid<br>
#     *The US Department of Education's Office of Federal Student Aid provides data
#     about federal financial assistance programs, including student aid data (Title
#     IV loans, grants, and campus-based programs), and financial responsibility
#     composite scores.*

# %%
from json import loads
from urllib.request import urlopen

# %%
root = "https://educationdata.urban.org/api/v1/"

# %%
colg = "college-university/"

# %% [markdown]
# options for layer are:
#
# `ipeds/` - lots of [subvariables](https://educationdata.urban.org/documentation/colleges.html#ipeds_directory) here.: "...Contains directory information for every institution in the IPEDS universe. This includes name, address, city, state, zip code, and various URL links to the institution's home page, admissions, financial aid offices, and the net price calculator. Identifies institutions as currently active and institutions that participate in Title IV federal financial aid programs for which IPEDS is mandatory. It also includes variables derived from the Institutional Characteristics survey, such as control and level of institution, highest level and highest degree offered and Carnegie classifications."
#
# `scorecard/`: "... Contains institutional characteristics for each college or university, primarily including flags for minority-serving institutions. To avoid duplication, we exclude data that College Scorecard sourced from IPEDS. For these data, you can see the other Institutional Characteristics and Directory endpoints. Notably, most of the information contained in this endpoint can be found in 2016 and aside from identification and year, only predominant degree awarded is available in other years."
#
# `nhgis/`: "...Contains geographic variables corresponding to 2010 Census geographies for each IPEDS institution. Geographies are merged on by latitude and longitude when available; when unavailable, latitudes and longitudes were obtained from address information using Urban's geocoder. The geocoder uses StreetMap Premium from Esri to perform accurate offline geocoding. Geocode accuracy variables indicate the degree of precision of this geocoding. Additional information on the match accuracy can be found [here](https://developers.arcgis.com/rest/geocode/api-reference/geocoding-service-output.htm). Geographies for older years of data or low-accuracy geocode matches should be used with caution.
#
# `fsa/`: "...Contains financial responsibility composites scores for for-profit and nonprofit institutions. These scores gauge an institution's financial health and help the Department of Education assess an institution's financial responsibility compliance. The scores are based on a primary reserve ratio, an equity ratio, and a net income ratio. They are collected at the OPEID level, but we report them at the UNITID level in order to facilitate merging with IPEDS data.
#
#
# `this cell does not reflect the extent of the datasets --update`

# %%
layer = "nhgis"

# %%
sublayer = "census-2010"

# %%
year = "2010"

# %%
url = root + colg + layer + sublayer + year

# %%
#api/v1/college-university/nhgis/census-2010/{year}/

# %%
url
# Out:
# 'https://educationdata.urban.org/api/v1/college-university/nhgiscensus-20102010'

# %%
dynurl = f"https://educationdata.urban.org/api/v1/college-university/{layer}/{sublayer}/{year}"

# %%
dynurl
# Out:
# 'https://educationdata.urban.org/api/v1/college-university/nhgis/census-2010/2010'

# %%
response = urlopen(dynurl)
data = loads(response.read())

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#      count                                               next previous  \
# 0     7494  https://educationdata.urban.org/api/v1/college...     None
# 1     7494  https://educationdata.urban.org/api/v1/college...     None
# 2     7494  https://educationdata.urban.org/api/v1/college...     None
# 3     7494  https://educationdata.urban.org/api/v1/college...     None
# 4     7494  https://educationdata.urban.org/api/v1/college...     None
# ..     ...                                                ...      ...
# 995   7494  https://educationdata.urban.org/api/v1/college...     None
# 996   7494  https://educationdata.urban.org/api/v1/college...     None
# 997   7494  https://educationdata.urban.org/api/v1/college...     None
# 998   7494  https://educationdata.urban.org/api/v1/college...     None
# 999   7494  https://educationdata.urban.org/api/v1/college...     None
#
#                                                results
# 0    {'year': 2010, 'fips': 72, 'unitid': 242626, '...
# 1    {'year': 2010, 'fips': 72, 'unitid': 446516, '...
# 2    {'year': 2010, 'fips': 72, 'unitid': 445498, '...
# 3    {'year': 2010, 'fips': 72, 'unitid': 418755, '...
# 4    {'year': 2010, 'fips': 72, 'unitid': 376385, '...
# ..                                                 ...
# 995  {'year': 2010, 'fips': 36, 'unitid': 457828, '...
# 996  {'year': 2010, 'fips': 36, 'unitid': 440262, '...
# 997  {'year': 2010, 'fips': 36, 'unitid': 195809, '...
# 998  {'year': 2010, 'fips': 36, 'unitid': 190691, '...
# 999  {'year': 2010, 'fips': 36, 'unitid': 439783, '...
#
# [1000 rows x 4 columns]

# %%
dfdict = dict(df['results'])
df = pd.DataFrame.from_dict(dfdict, orient='index')

# %%
df
# Out:
#      year  fips  unitid     opeid  \
# 0    2010    72  242626  00393804
# 1    2010    72  446516  03638300
# 2    2010    72  445498  03800300
# 3    2010    72  418755  03061900
# 4    2010    72  376385  03029700
# ..    ...   ...     ...       ...
# 995  2010    36  457828  04148000
# 996  2010    36  440262  03537300
# 997  2010    36  195809  00282300
# 998  2010    36  190691  00475900
# 999  2010    36  439783  03443300
#
#                                              inst_name  \
# 0    Inter American University of Puerto Rico-Aguad...
# 1              Rosslyn Training Academy of Cosmetology
# 2              Colegio Tecnico de Electricidad Galloza
# 3       Colegio Tecnologico y Comercial de Puerto Rico
# 4          Universal Technology College of Puerto Rico
# ..                                                 ...
# 995                        New Life Business Institute
# 996           New York Automotive and Diesel Institute
# 997                      St John's University-New York
# 998                                  CUNY York College
# 999   New York College of Traditional Chinese Medicine
#
#                                                address state_abbr         zip  \
# 0                        Barrio Corrales Sector Calero         PR       00602
# 1                                        Calle Paz 213         PR       00602
# 2    Carr 4416 Km 2.5 Interior, in the Colegio Tecn...         PR       00602
# 3                                  Calle Paz 165 Altos         PR  00602-0960
# 4                                      111 Comercio St         PR       00603
# ..                                                 ...        ...         ...
# 995                         161-10 Jamaica Ave Ste 404         NY       11432
# 996                              178-18 Liberty Avenue         NY  11433-1433
# 997                                    8000 Utopia Pky         NY       11439
# 998                           94-20 Guy R. Brewer Blvd         NY       11451
# 999                                       155 First St         NY       11501
#
#              county_name  county_fips  geo_longitude  geo_latitude  \
# 0       Aguada Municipio        72003     -67.113510     18.446060
# 1       Aguada Municipio        72003     -67.188150     18.379366
# 2       Aguada Municipio        72003     -67.191050     18.382160
# 3       Aguada Municipio        72003     -67.186615     18.379082
# 4    Aguadilla Municipio        72005     -67.154690     18.408825
# ..                   ...          ...            ...           ...
# 995        Queens County        36081     -73.798210     40.704150
# 996        Queens County        36081     -73.781260     40.705357
# 997        Queens County        36081     -73.791750     40.725650
# 998        Queens County        36081     -73.795425     40.702217
# 999        Nassau County        36059     -73.638565     40.742786
#
#      geocode_accuracy_detailed  geocode_accuracy  state_fips_geo  \
# 0                           -2                -2              72
# 1                           -2                -2              72
# 2                           -2                -2              72
# 3                           -2                -2              72
# 4                           -2                -2              72
# ..                         ...               ...             ...
# 995                         -2                -2              36
# 996                         -2                -2              36
# 997                         -2                -2              36
# 998                         -2                -2              36
# 999                         -2                -2              36
#
#      county_fips_geo   tract  puma  block_group   geoid_block  census_region  \
# 0              72005  401402   102            2  720054014022              9
# 1              72003  430300   101            2  720034303002              9
# 2              72003  430200   101            2  720034302002              9
# 3              72003  430300   101            2  720034303002              9
# 4              72005  401100   102            1  720054011001              9
# ..               ...     ...   ...          ...           ...            ...
# 995            36081   44601  4112            1  360810446011              1
# 996            36081   44000  4112            3  360810440003              1
# 997            36081  126700  4106            1  360811267001              1
# 998            36081   24600  4112            1  360810246001              1
# 999            36059  303600  3204            4  360593036004              1
#
#      census_division    csa     cbsa  \
# 0                NaN    NaN  10380.0
# 1                NaN    NaN  10380.0
# 2                NaN    NaN  10380.0
# 3                NaN    NaN  10380.0
# 4                NaN    NaN  10380.0
# ..               ...    ...      ...
# 995              2.0  408.0  35620.0
# 996              2.0  408.0  35620.0
# 997              2.0  408.0  35620.0
# 998              2.0  408.0  35620.0
# 999              2.0  408.0  35620.0
#
#                                              cbsa_name  cbsa_type  \
# 0                  Aguadilla-Isabela-San Sebastián, PR        1.0
# 1                  Aguadilla-Isabela-San Sebastián, PR        1.0
# 2                  Aguadilla-Isabela-San Sebastián, PR        1.0
# 3                  Aguadilla-Isabela-San Sebastián, PR        1.0
# 4                  Aguadilla-Isabela-San Sebastián, PR        1.0
# ..                                                 ...        ...
# 995  New York-Northern New Jersey-Long Island, NY-N...        1.0
# 996  New York-Northern New Jersey-Long Island, NY-N...        1.0
# 997  New York-Northern New Jersey-Long Island, NY-N...        1.0
# 998  New York-Northern New Jersey-Long Island, NY-N...        1.0
# 999  New York-Northern New Jersey-Long Island, NY-N...        1.0
#
#                 place_name  place_fips geoid_place  class_code  cbsa_city  \
# 0                                  NaN                     NaN        NaN
# 1       Aguada zona urbana       616.0     7200616        70.0        0.0
# 2       Aguada zona urbana       616.0     7200616        70.0        0.0
# 3       Aguada zona urbana       616.0     7200616        70.0        0.0
# 4    Aguadilla zona urbana       745.0     7200745        70.0        1.0
# ..                     ...         ...         ...         ...        ...
# 995          New York city     51000.0     3651000         1.0        1.0
# 996          New York city     51000.0     3651000         1.0        1.0
# 997          New York city     51000.0     3651000         1.0        1.0
# 998          New York city     51000.0     3651000         1.0        1.0
# 999        Mineola village     47636.0     3647636         1.0        0.0
#
#     upper_chamber state_leg_district_upper        upper_chamber_name  \
# 0             004                    72004   State Senate District 4
# 1             004                    72004   State Senate District 4
# 2             004                    72004   State Senate District 4
# 3             004                    72004   State Senate District 4
# 4             004                    72004   State Senate District 4
# ..            ...                      ...                       ...
# 995           014                    36014  State Senate District 14
# 996           014                    36014  State Senate District 14
# 997           011                    36011  State Senate District 11
# 998           010                    36010  State Senate District 10
# 999           007                    36007   State Senate District 7
#
#     lower_chamber state_leg_district_lower       lower_chamber_name  \
# 0             017                    72017  State House District 17
# 1             018                    72018  State House District 18
# 2             018                    72018  State House District 18
# 3             018                    72018  State House District 18
# 4             017                    72017  State House District 17
# ..            ...                      ...                      ...
# 995           032                    36032     Assembly District 32
# 996           029                    36029     Assembly District 29
# 997           025                    36025     Assembly District 25
# 998           032                    36032     Assembly District 32
# 999           017                    36017     Assembly District 17
#
#      lower_chamber_type
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3
# ..                  ...
# 995                   7
# 996                   7
# 997                   7
# 998                   7
# 999                   7
#
# [1000 rows x 38 columns]

# %% [markdown]
# NHGIS layer

# %%
layer = "nhgis/"

# %%
sublayer = "census-2010/"

# %%
year = "2014/"

# %%
url = root + colg + layer + sublayer + year

# %%
url
# Out:
# 'https://educationdata.urban.org/api/v1/college-university/nhgis/census-2010/2014/'

# %%
response = urlopen(url)

data = loads(response.read())

# %%
data
# Out:
# {'count': 7678,
#  'next': 'https://educationdata.urban.org/api/v1/college-university/nhgis/census-2010/2014/?page=2',
#  'previous': None,
#  'results': [{'year': 2014,
#    'fips': 1,
#    'unitid': 100636,
#    'opeid': '1230800',
#    'inst_name': 'Community College of the Air Force',
#    'address': '100 S Turner Blvd',
#    'state_abbr': 'AL',
#    'zip': '36114-3011',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.24452,
#    'geo_latitude': 32.406143,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 5301,
#    'puma': '2000',
#    'block_group': 1,
#    'geoid_block': '011010053011',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '01074',
#    'lower_chamber_name': 'State House District 74',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100654,
#    'opeid': '100200',
#    'inst_name': 'Alabama A & M University',
#    'address': '4900 Meridian Street',
#    'state_abbr': 'AL',
#    'zip': '35762',
#    'county_name': 'Madison',
#    'county_fips': 1089,
#    'geo_longitude': -86.57228,
#    'geo_latitude': 34.783787,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1089,
#    'tract': 202,
#    'puma': '302',
#    'block_group': 1,
#    'geoid_block': '010890002021',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': 'Huntsville city',
#    'place_fips': 37000,
#    'geoid_place': '0137000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '007',
#    'state_leg_district_upper': '01007',
#    'upper_chamber_name': 'State Senate District 7',
#    'lower_chamber': '019',
#    'state_leg_district_lower': '01019',
#    'lower_chamber_name': 'State House District 19',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100663,
#    'opeid': '105200',
#    'inst_name': 'University of Alabama at Birmingham',
#    'address': 'Administration Bldg Suite 1070',
#    'state_abbr': 'AL',
#    'zip': '35294-0110',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.81208,
#    'geo_latitude': 33.50592,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 4500,
#    'puma': '1302',
#    'block_group': 1,
#    'geoid_block': '010730045001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Birmingham city',
#    'place_fips': 7000,
#    'geoid_place': '0107000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '018',
#    'state_leg_district_upper': '01018',
#    'upper_chamber_name': 'State Senate District 18',
#    'lower_chamber': '053',
#    'state_leg_district_lower': '01053',
#    'lower_chamber_name': 'State House District 53',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100690,
#    'opeid': '2503400',
#    'inst_name': 'Amridge University',
#    'address': '1200 Taylor Rd',
#    'state_abbr': 'AL',
#    'zip': '36117-3553',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.17152,
#    'geo_latitude': 32.36399,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 5407,
#    'puma': '2000',
#    'block_group': 2,
#    'geoid_block': '011010054072',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '075',
#    'state_leg_district_lower': '01075',
#    'lower_chamber_name': 'State House District 75',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100706,
#    'opeid': '105500',
#    'inst_name': 'University of Alabama in Huntsville',
#    'address': '301 Sparkman Dr',
#    'state_abbr': 'AL',
#    'zip': '35899',
#    'county_name': 'Madison',
#    'county_fips': 1089,
#    'geo_longitude': -86.64404,
#    'geo_latitude': 34.72349,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1089,
#    'tract': 1500,
#    'puma': '301',
#    'block_group': 3,
#    'geoid_block': '010890015003',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': 'Huntsville city',
#    'place_fips': 37000,
#    'geoid_place': '0137000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '002',
#    'state_leg_district_upper': '01002',
#    'upper_chamber_name': 'State Senate District 2',
#    'lower_chamber': '006',
#    'state_leg_district_lower': '01006',
#    'lower_chamber_name': 'State House District 6',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100724,
#    'opeid': '100500',
#    'inst_name': 'Alabama State University',
#    'address': '915 S Jackson Street',
#    'state_abbr': 'AL',
#    'zip': '36104-0271',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.29613,
#    'geo_latitude': 32.36599,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 1500,
#    'puma': '2000',
#    'block_group': 3,
#    'geoid_block': '011010015003',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '026',
#    'state_leg_district_upper': '01026',
#    'upper_chamber_name': 'State Senate District 26',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '01077',
#    'lower_chamber_name': 'State House District 77',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100733,
#    'opeid': '800400',
#    'inst_name': 'University of Alabama System Office',
#    'address': '500 University Blvd. East',
#    'state_abbr': 'AL',
#    'zip': '35401',
#    'county_name': 'Tuscaloosa',
#    'county_fips': 1125,
#    'geo_longitude': -87.52961,
#    'geo_latitude': 33.206635,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1125,
#    'tract': 11200,
#    'puma': '1600',
#    'block_group': 1,
#    'geoid_block': '011250112001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 46220,
#    'cbsa_name': 'Tuscaloosa, AL',
#    'cbsa_type': 1,
#    'place_name': 'Tuscaloosa city',
#    'place_fips': 77256,
#    'geoid_place': '0177256',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '021',
#    'state_leg_district_upper': '01021',
#    'upper_chamber_name': 'State Senate District 21',
#    'lower_chamber': '063',
#    'state_leg_district_lower': '01063',
#    'lower_chamber_name': 'State House District 63',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100751,
#    'opeid': '105100',
#    'inst_name': 'The University of Alabama',
#    'address': '739 University Blvd',
#    'state_abbr': 'AL',
#    'zip': '35487-0166',
#    'county_name': 'Tuscaloosa',
#    'county_fips': 1125,
#    'geo_longitude': -87.5463,
#    'geo_latitude': 33.20951,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1125,
#    'tract': 11200,
#    'puma': '1600',
#    'block_group': 1,
#    'geoid_block': '011250112001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 46220,
#    'cbsa_name': 'Tuscaloosa, AL',
#    'cbsa_type': 1,
#    'place_name': 'Tuscaloosa city',
#    'place_fips': 77256,
#    'geoid_place': '0177256',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '021',
#    'state_leg_district_upper': '01021',
#    'upper_chamber_name': 'State Senate District 21',
#    'lower_chamber': '063',
#    'state_leg_district_lower': '01063',
#    'lower_chamber_name': 'State House District 63',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100760,
#    'opeid': '100700',
#    'inst_name': 'Central Alabama Community College',
#    'address': '1675 Cherokee Rd',
#    'state_abbr': 'AL',
#    'zip': '35010',
#    'county_name': 'Tallapoosa',
#    'county_fips': 1123,
#    'geo_longitude': -85.94782,
#    'geo_latitude': 32.925,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1123,
#    'tract': 962300,
#    'puma': '1800',
#    'block_group': 4,
#    'geoid_block': '011239623004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 10760,
#    'cbsa_name': 'Alexander City, AL',
#    'cbsa_type': 2,
#    'place_name': 'Alexander City city',
#    'place_fips': 1132,
#    'geoid_place': '0101132',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '027',
#    'state_leg_district_upper': '01027',
#    'upper_chamber_name': 'State Senate District 27',
#    'lower_chamber': '081',
#    'state_leg_district_lower': '01081',
#    'lower_chamber_name': 'State House District 81',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100812,
#    'opeid': '100800',
#    'inst_name': 'Athens State University',
#    'address': '300 N Beaty St',
#    'state_abbr': 'AL',
#    'zip': '35611',
#    'county_name': 'Limestone',
#    'county_fips': 1083,
#    'geo_longitude': -86.967476,
#    'geo_latitude': 34.805523,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1083,
#    'tract': 20700,
#    'puma': '200',
#    'block_group': 1,
#    'geoid_block': '010830207001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': 'Athens city',
#    'place_fips': 2956,
#    'geoid_place': '0102956',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '002',
#    'state_leg_district_upper': '01002',
#    'upper_chamber_name': 'State Senate District 2',
#    'lower_chamber': '005',
#    'state_leg_district_lower': '01005',
#    'lower_chamber_name': 'State House District 5',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100830,
#    'opeid': '831000',
#    'inst_name': 'Auburn University at Montgomery',
#    'address': '7440 East Drive',
#    'state_abbr': 'AL',
#    'zip': '36117-3596',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.17507,
#    'geo_latitude': 32.366623,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 5407,
#    'puma': '2000',
#    'block_group': 2,
#    'geoid_block': '011010054072',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '075',
#    'state_leg_district_lower': '01075',
#    'lower_chamber_name': 'State House District 75',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100858,
#    'opeid': '100900',
#    'inst_name': 'Auburn University',
#    'address': 'Auburn, Alabama',
#    'state_abbr': 'AL',
#    'zip': '36849',
#    'county_name': 'Lee',
#    'county_fips': 1081,
#    'geo_longitude': -85.48789,
#    'geo_latitude': 32.599895,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1081,
#    'tract': 40700,
#    'puma': '1900',
#    'block_group': 2,
#    'geoid_block': '010810407002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 194,
#    'cbsa': 12220,
#    'cbsa_name': 'Auburn-Opelika, AL',
#    'cbsa_type': 1,
#    'place_name': 'Auburn city',
#    'place_fips': 3076,
#    'geoid_place': '0103076',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '027',
#    'state_leg_district_upper': '01027',
#    'upper_chamber_name': 'State Senate District 27',
#    'lower_chamber': '079',
#    'state_leg_district_lower': '01079',
#    'lower_chamber_name': 'State House District 79',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 100937,
#    'opeid': '101200',
#    'inst_name': 'Birmingham Southern College',
#    'address': '900 Arkadelphia Road',
#    'state_abbr': 'AL',
#    'zip': '35254',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.84998,
#    'geo_latitude': 33.51556,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 3001,
#    'puma': '1301',
#    'block_group': 1,
#    'geoid_block': '010730030011',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Birmingham city',
#    'place_fips': 7000,
#    'geoid_place': '0107000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '020',
#    'state_leg_district_upper': '01020',
#    'upper_chamber_name': 'State Senate District 20',
#    'lower_chamber': '060',
#    'state_leg_district_lower': '01060',
#    'lower_chamber_name': 'State House District 60',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101028,
#    'opeid': '1218200',
#    'inst_name': 'Chattahoochee Valley Community College',
#    'address': '2602 College Drive',
#    'state_abbr': 'AL',
#    'zip': '36869',
#    'county_name': 'Russell',
#    'county_fips': 1113,
#    'geo_longitude': -85.03123,
#    'geo_latitude': 32.42339,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1113,
#    'tract': 30600,
#    'puma': '2400',
#    'block_group': 2,
#    'geoid_block': '011130306002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 194,
#    'cbsa': 17980,
#    'cbsa_name': 'Columbus, GA-AL',
#    'cbsa_type': 1,
#    'place_name': 'Phenix City city',
#    'place_fips': 59472,
#    'geoid_place': '0159472',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '027',
#    'state_leg_district_upper': '01027',
#    'upper_chamber_name': 'State Senate District 27',
#    'lower_chamber': '080',
#    'state_leg_district_lower': '01080',
#    'lower_chamber_name': 'State House District 80',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101073,
#    'opeid': '1055400',
#    'inst_name': 'Concordia College Alabama',
#    'address': '1712 Broad Street',
#    'state_abbr': 'AL',
#    'zip': '36701',
#    'county_name': 'Dallas',
#    'county_fips': 1047,
#    'geo_longitude': -87.02423,
#    'geo_latitude': 32.422287,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1047,
#    'tract': 956400,
#    'puma': '1700',
#    'block_group': 1,
#    'geoid_block': '010479564001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 42820,
#    'cbsa_name': 'Selma, AL',
#    'cbsa_type': 2,
#    'place_name': 'Selma city',
#    'place_fips': 69120,
#    'geoid_place': '0169120',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '023',
#    'state_leg_district_upper': '01023',
#    'upper_chamber_name': 'State Senate District 23',
#    'lower_chamber': '067',
#    'state_leg_district_lower': '01067',
#    'lower_chamber_name': 'State House District 67',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101116,
#    'opeid': '1303906',
#    'inst_name': 'South University-Montgomery',
#    'address': '5355 Vaughn Rd',
#    'state_abbr': 'AL',
#    'zip': '36116',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.21648,
#    'geo_latitude': 32.34222,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 5410,
#    'puma': '2000',
#    'block_group': 4,
#    'geoid_block': '011010054104',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '073',
#    'state_leg_district_lower': '01073',
#    'lower_chamber_name': 'State House District 73',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101143,
#    'opeid': '101500',
#    'inst_name': 'Enterprise State Community College',
#    'address': '600 Plaza Drive',
#    'state_abbr': 'AL',
#    'zip': '36330-1300',
#    'county_name': 'Coffee',
#    'county_fips': 1031,
#    'geo_longitude': -85.834785,
#    'geo_latitude': 31.299177,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1031,
#    'tract': 11300,
#    'puma': '2300',
#    'block_group': 2,
#    'geoid_block': '010310113002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 222,
#    'cbsa': 21460,
#    'cbsa_name': 'Enterprise-Ozark, AL',
#    'cbsa_type': 2,
#    'place_name': 'Enterprise city',
#    'place_fips': 24184,
#    'geoid_place': '0124184',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '031',
#    'state_leg_district_upper': '01031',
#    'upper_chamber_name': 'State Senate District 31',
#    'lower_chamber': '091',
#    'state_leg_district_lower': '01091',
#    'lower_chamber_name': 'State House District 91',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101161,
#    'opeid': '106000',
#    'inst_name': 'James H Faulkner State Community College',
#    'address': '1900 US Hwy 31 S',
#    'state_abbr': 'AL',
#    'zip': '36507-2698',
#    'county_name': 'Baldwin',
#    'county_fips': 1003,
#    'geo_longitude': -87.77668,
#    'geo_latitude': 30.852615,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1003,
#    'tract': 10300,
#    'puma': '2600',
#    'block_group': 1,
#    'geoid_block': '010030103001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 380,
#    'cbsa': 19300,
#    'cbsa_name': 'Daphne-Fairhope-Foley, AL',
#    'cbsa_type': 2,
#    'place_name': 'Bay Minette city',
#    'place_fips': 4660,
#    'geoid_place': '0104660',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '022',
#    'state_leg_district_upper': '01022',
#    'upper_chamber_name': 'State Senate District 22',
#    'lower_chamber': '064',
#    'state_leg_district_lower': '01064',
#    'lower_chamber_name': 'State House District 64',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101189,
#    'opeid': '100300',
#    'inst_name': 'Faulkner University',
#    'address': '5345 Atlanta Hwy',
#    'state_abbr': 'AL',
#    'zip': '36109-3390',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.21768,
#    'geo_latitude': 32.381905,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 2600,
#    'puma': '2000',
#    'block_group': 4,
#    'geoid_block': '011010026004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '01074',
#    'lower_chamber_name': 'State House District 74',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101240,
#    'opeid': '101700',
#    'inst_name': 'Gadsden State Community College',
#    'address': '1001 George Wallace Dr',
#    'state_abbr': 'AL',
#    'zip': '35903',
#    'county_name': 'Etowah',
#    'county_fips': 1055,
#    'geo_longitude': -85.99097,
#    'geo_latitude': 33.996494,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1055,
#    'tract': 1600,
#    'puma': '900',
#    'block_group': 3,
#    'geoid_block': '010550016003',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 23460,
#    'cbsa_name': 'Gadsden, AL',
#    'cbsa_type': 1,
#    'place_name': 'Gadsden city',
#    'place_fips': 28696,
#    'geoid_place': '0128696',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '010',
#    'state_leg_district_upper': '01010',
#    'upper_chamber_name': 'State Senate District 10',
#    'lower_chamber': '028',
#    'state_leg_district_lower': '01028',
#    'lower_chamber_name': 'State House District 28',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101277,
#    'opeid': '4187200',
#    'inst_name': 'New Beginning College of Cosmetology',
#    'address': '421 Martling Road',
#    'state_abbr': 'AL',
#    'zip': '35951',
#    'county_name': 'Marshall',
#    'county_fips': 1095,
#    'geo_longitude': -86.19662,
#    'geo_latitude': 34.278534,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1095,
#    'tract': 30801,
#    'puma': '500',
#    'block_group': 3,
#    'geoid_block': '010950308013',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 10700,
#    'cbsa_name': 'Albertville, AL',
#    'cbsa_type': 2,
#    'place_name': 'Albertville city',
#    'place_fips': 988,
#    'geoid_place': '0100988',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '009',
#    'state_leg_district_upper': '01009',
#    'upper_chamber_name': 'State Senate District 9',
#    'lower_chamber': '026',
#    'state_leg_district_lower': '01026',
#    'lower_chamber_name': 'State House District 26',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101286,
#    'opeid': '101800',
#    'inst_name': 'George C Wallace State Community College-Dothan',
#    'address': '1141 Wallace Drive',
#    'state_abbr': 'AL',
#    'zip': '36303-9234',
#    'county_name': 'Dale',
#    'county_fips': 1045,
#    'geo_longitude': -85.468216,
#    'geo_latitude': 31.31537,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1045,
#    'tract': 21400,
#    'puma': '2500',
#    'block_group': 3,
#    'geoid_block': '010450214003',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 222,
#    'cbsa': 21460,
#    'cbsa_name': 'Enterprise-Ozark, AL',
#    'cbsa_type': 2,
#    'place_name': 'Dothan city',
#    'place_fips': 21184,
#    'geoid_place': '0121184',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '031',
#    'state_leg_district_upper': '01031',
#    'upper_chamber_name': 'State Senate District 31',
#    'lower_chamber': '093',
#    'state_leg_district_lower': '01093',
#    'lower_chamber_name': 'State House District 93',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101295,
#    'opeid': '787100',
#    'inst_name': 'George C Wallace State Community College-Hanceville',
#    'address': '801 Main St NW',
#    'state_abbr': 'AL',
#    'zip': '35077-2000',
#    'county_name': 'Cullman',
#    'county_fips': 1043,
#    'geo_longitude': -86.77928,
#    'geo_latitude': 34.07382,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1043,
#    'tract': 965401,
#    'puma': '700',
#    'block_group': 2,
#    'geoid_block': '010439654012',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 18980,
#    'cbsa_name': 'Cullman, AL',
#    'cbsa_type': 2,
#    'place_name': 'Hanceville city',
#    'place_fips': 32968,
#    'geoid_place': '0132968',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '004',
#    'state_leg_district_upper': '01004',
#    'upper_chamber_name': 'State Senate District 4',
#    'lower_chamber': '012',
#    'state_leg_district_lower': '01012',
#    'lower_chamber_name': 'State House District 12',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101301,
#    'opeid': '569900',
#    'inst_name': 'George C Wallace State Community College-Selma',
#    'address': '3000 Earl Goodwin Parkway',
#    'state_abbr': 'AL',
#    'zip': '36703-2808',
#    'county_name': 'Dallas',
#    'county_fips': 1047,
#    'geo_longitude': -87.01449,
#    'geo_latitude': 32.445175,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1047,
#    'tract': 956100,
#    'puma': '1700',
#    'block_group': 4,
#    'geoid_block': '010479561004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 42820,
#    'cbsa_name': 'Selma, AL',
#    'cbsa_type': 2,
#    'place_name': 'Selma city',
#    'place_fips': 69120,
#    'geoid_place': '0169120',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '023',
#    'state_leg_district_upper': '01023',
#    'upper_chamber_name': 'State Senate District 23',
#    'lower_chamber': '067',
#    'state_leg_district_lower': '01067',
#    'lower_chamber_name': 'State House District 67',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101365,
#    'opeid': '962107',
#    'inst_name': 'Herzing University-Birmingham',
#    'address': '280 West Valley Ave',
#    'state_abbr': 'AL',
#    'zip': '35209',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.832245,
#    'geo_latitude': 33.46807,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 5104,
#    'puma': '1301',
#    'block_group': 3,
#    'geoid_block': '010730051043',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Homewood city',
#    'place_fips': 35800,
#    'geoid_place': '0135800',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '018',
#    'state_leg_district_upper': '01018',
#    'upper_chamber_name': 'State Senate District 18',
#    'lower_chamber': '052',
#    'state_leg_district_lower': '01052',
#    'lower_chamber_name': 'State House District 52',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101435,
#    'opeid': '101900',
#    'inst_name': 'Huntingdon College',
#    'address': '1500 East Fairview Avenue',
#    'state_abbr': 'AL',
#    'zip': '36106-2148',
#    'county_name': 'Montgomery',
#    'county_fips': 1101,
#    'geo_longitude': -86.28532,
#    'geo_latitude': 32.352024,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1101,
#    'tract': 1400,
#    'puma': '2000',
#    'block_group': 2,
#    'geoid_block': '011010014002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': 'Montgomery city',
#    'place_fips': 51000,
#    'geoid_place': '0151000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '073',
#    'state_leg_district_lower': '01073',
#    'lower_chamber_name': 'State House District 73',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101453,
#    'opeid': '2199700',
#    'inst_name': 'Heritage Christian University',
#    'address': '3625 Helton Dr',
#    'state_abbr': 'AL',
#    'zip': '35630-9977',
#    'county_name': 'Lauderdale',
#    'county_fips': 1077,
#    'geo_longitude': -87.66206,
#    'geo_latitude': 34.854107,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1077,
#    'tract': 11501,
#    'puma': '100',
#    'block_group': 1,
#    'geoid_block': '010770115011',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 22520,
#    'cbsa_name': 'Florence-Muscle Shoals, AL',
#    'cbsa_type': 1,
#    'place_name': 'Florence city',
#    'place_fips': 26896,
#    'geoid_place': '0126896',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '001',
#    'state_leg_district_upper': '01001',
#    'upper_chamber_name': 'State Senate District 1',
#    'lower_chamber': '001',
#    'state_leg_district_lower': '01001',
#    'lower_chamber_name': 'State House District 1',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101462,
#    'opeid': '526000',
#    'inst_name': 'J F Drake State Community and Technical College',
#    'address': '3421 Meridian St N',
#    'state_abbr': 'AL',
#    'zip': '35811',
#    'county_name': 'Madison',
#    'county_fips': 1089,
#    'geo_longitude': -86.57251,
#    'geo_latitude': 34.771053,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1089,
#    'tract': 202,
#    'puma': '302',
#    'block_group': 1,
#    'geoid_block': '010890002021',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': 'Huntsville city',
#    'place_fips': 37000,
#    'geoid_place': '0137000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '007',
#    'state_leg_district_upper': '01007',
#    'upper_chamber_name': 'State Senate District 7',
#    'lower_chamber': '019',
#    'state_leg_district_lower': '01019',
#    'lower_chamber_name': 'State House District 19',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101471,
#    'opeid': '3002500',
#    'inst_name': 'J F Ingram State Technical College',
#    'address': '5375 Ingram Rd',
#    'state_abbr': 'AL',
#    'zip': '36022',
#    'county_name': 'Elmore',
#    'county_fips': 1051,
#    'geo_longitude': -86.39224,
#    'geo_latitude': 32.58422,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1051,
#    'tract': 30901,
#    'puma': '2100',
#    'block_group': 1,
#    'geoid_block': '010510309011',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 388,
#    'cbsa': 33860,
#    'cbsa_name': 'Montgomery, AL',
#    'cbsa_type': 1,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'cbsa_city': None,
#    'upper_chamber': '025',
#    'state_leg_district_upper': '01025',
#    'upper_chamber_name': 'State Senate District 25',
#    'lower_chamber': '075',
#    'state_leg_district_lower': '01075',
#    'lower_chamber_name': 'State House District 75',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101480,
#    'opeid': '102000',
#    'inst_name': 'Jacksonville State University',
#    'address': '700 Pelham Road North',
#    'state_abbr': 'AL',
#    'zip': '36265',
#    'county_name': 'Calhoun',
#    'county_fips': 1015,
#    'geo_longitude': -85.76405,
#    'geo_latitude': 33.82615,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1015,
#    'tract': 2101,
#    'puma': '1100',
#    'block_group': 1,
#    'geoid_block': '010150021011',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 11500,
#    'cbsa_name': 'Anniston-Oxford, AL',
#    'cbsa_type': 1,
#    'place_name': 'Jacksonville city',
#    'place_fips': 38272,
#    'geoid_place': '0138272',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '012',
#    'state_leg_district_upper': '01012',
#    'upper_chamber_name': 'State Senate District 12',
#    'lower_chamber': '040',
#    'state_leg_district_lower': '01040',
#    'lower_chamber_name': 'State House District 40',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101499,
#    'opeid': '102100',
#    'inst_name': 'Jefferson Davis Community College',
#    'address': '220 Alco Dr',
#    'state_abbr': 'AL',
#    'zip': '36426',
#    'county_name': 'Escambia',
#    'county_fips': 1053,
#    'geo_longitude': -87.083824,
#    'geo_latitude': 31.102123,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1053,
#    'tract': 969900,
#    'puma': '2200',
#    'block_group': 2,
#    'geoid_block': '010539699002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': None,
#    'cbsa_name': '',
#    'cbsa_type': None,
#    'place_name': 'Brewton city',
#    'place_fips': 9208,
#    'geoid_place': '0109208',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '022',
#    'state_leg_district_upper': '01022',
#    'upper_chamber_name': 'State Senate District 22',
#    'lower_chamber': '066',
#    'state_leg_district_lower': '01066',
#    'lower_chamber_name': 'State House District 66',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101505,
#    'opeid': '102200',
#    'inst_name': 'Jefferson State Community College',
#    'address': '2601 Carson Rd',
#    'state_abbr': 'AL',
#    'zip': '35215-3098',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.70978,
#    'geo_latitude': 33.648396,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 11209,
#    'puma': '1304',
#    'block_group': 1,
#    'geoid_block': '010730112091',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Birmingham city',
#    'place_fips': 7000,
#    'geoid_place': '0107000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '020',
#    'state_leg_district_upper': '01020',
#    'upper_chamber_name': 'State Senate District 20',
#    'lower_chamber': '044',
#    'state_leg_district_lower': '01044',
#    'lower_chamber_name': 'State House District 44',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101514,
#    'opeid': '101300',
#    'inst_name': 'John C Calhoun State Community College',
#    'address': '6250 U S Highway 31 N',
#    'state_abbr': 'AL',
#    'zip': '35671',
#    'county_name': 'Limestone',
#    'county_fips': 1083,
#    'geo_longitude': -86.95041,
#    'geo_latitude': 34.647106,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1083,
#    'tract': 21100,
#    'puma': '200',
#    'block_group': 4,
#    'geoid_block': '010830211004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'cbsa_city': None,
#    'upper_chamber': '002',
#    'state_leg_district_upper': '01002',
#    'upper_chamber_name': 'State Senate District 2',
#    'lower_chamber': '004',
#    'state_leg_district_lower': '01004',
#    'lower_chamber_name': 'State House District 4',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101541,
#    'opeid': '102300',
#    'inst_name': 'Judson College',
#    'address': '302 Bibb St',
#    'state_abbr': 'AL',
#    'zip': '36756',
#    'county_name': 'Perry',
#    'county_fips': 1105,
#    'geo_longitude': -87.316696,
#    'geo_latitude': 32.63005,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1105,
#    'tract': 687000,
#    'puma': '1700',
#    'block_group': 4,
#    'geoid_block': '011056870004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': None,
#    'cbsa_name': '',
#    'cbsa_type': None,
#    'place_name': 'Marion city',
#    'place_fips': 46768,
#    'geoid_place': '0146768',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '024',
#    'state_leg_district_upper': '01024',
#    'upper_chamber_name': 'State Senate District 24',
#    'lower_chamber': '072',
#    'state_leg_district_lower': '01072',
#    'lower_chamber_name': 'State House District 72',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101569,
#    'opeid': '105900',
#    'inst_name': 'Lawson State Community College-Birmingham Campus',
#    'address': '3060 Wilson Rd SW',
#    'state_abbr': 'AL',
#    'zip': '35221-1717',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.88883,
#    'geo_latitude': 33.449318,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 13100,
#    'puma': '1301',
#    'block_group': 4,
#    'geoid_block': '010730131004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Birmingham city',
#    'place_fips': 7000,
#    'geoid_place': '0107000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '019',
#    'state_leg_district_upper': '01019',
#    'upper_chamber_name': 'State Senate District 19',
#    'lower_chamber': '057',
#    'state_leg_district_lower': '01057',
#    'lower_chamber_name': 'State House District 57',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101587,
#    'opeid': '102400',
#    'inst_name': 'University of West Alabama',
#    'address': 'Station One',
#    'state_abbr': 'AL',
#    'zip': '35470',
#    'county_name': 'Sumter',
#    'county_fips': 1119,
#    'geo_longitude': -88.03496,
#    'geo_latitude': 32.504745,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1119,
#    'tract': 11300,
#    'puma': '1700',
#    'block_group': 2,
#    'geoid_block': '011190113002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': None,
#    'cbsa_name': '',
#    'cbsa_type': None,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'cbsa_city': None,
#    'upper_chamber': '024',
#    'state_leg_district_upper': '01024',
#    'upper_chamber_name': 'State Senate District 24',
#    'lower_chamber': '071',
#    'state_leg_district_lower': '01071',
#    'lower_chamber_name': 'State House District 71',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101602,
#    'opeid': '898800',
#    'inst_name': 'Lurleen B Wallace Community College',
#    'address': '1000 Dannelly Blvd.',
#    'state_abbr': 'AL',
#    'zip': '36420-1418',
#    'county_name': 'Covington',
#    'county_fips': 1039,
#    'geo_longitude': -86.45099,
#    'geo_latitude': 31.318735,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1039,
#    'tract': 962000,
#    'puma': '2300',
#    'block_group': 1,
#    'geoid_block': '010399620001',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': None,
#    'cbsa_name': '',
#    'cbsa_type': None,
#    'place_name': 'Andalusia city',
#    'place_fips': 1708,
#    'geoid_place': '0101708',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '031',
#    'state_leg_district_upper': '01031',
#    'upper_chamber_name': 'State Senate District 31',
#    'lower_chamber': '092',
#    'state_leg_district_lower': '01092',
#    'lower_chamber_name': 'State House District 92',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101648,
#    'opeid': '102600',
#    'inst_name': 'Marion Military Institute',
#    'address': '1101 Washington St',
#    'state_abbr': 'AL',
#    'zip': '36756-3207',
#    'county_name': 'Perry',
#    'county_fips': 1105,
#    'geo_longitude': -87.318245,
#    'geo_latitude': 32.623177,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1105,
#    'tract': 687000,
#    'puma': '1700',
#    'block_group': 4,
#    'geoid_block': '011056870004',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': None,
#    'cbsa_name': '',
#    'cbsa_type': None,
#    'place_name': 'Marion city',
#    'place_fips': 46768,
#    'geoid_place': '0146768',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '024',
#    'state_leg_district_upper': '01024',
#    'upper_chamber_name': 'State Senate District 24',
#    'lower_chamber': '072',
#    'state_leg_district_lower': '01072',
#    'lower_chamber_name': 'State House District 72',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101675,
#    'opeid': '102800',
#    'inst_name': 'Miles College',
#    'address': '5500 Myron Massey Blvd',
#    'state_abbr': 'AL',
#    'zip': '35064-2621',
#    'county_name': 'Jefferson',
#    'county_fips': 1073,
#    'geo_longitude': -86.907166,
#    'geo_latitude': 33.480648,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1073,
#    'tract': 10602,
#    'puma': '1301',
#    'block_group': 5,
#    'geoid_block': '010730106025',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': 'Fairfield city',
#    'place_fips': 25120,
#    'geoid_place': '0125120',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '019',
#    'state_leg_district_upper': '01019',
#    'upper_chamber_name': 'State Senate District 19',
#    'lower_chamber': '055',
#    'state_leg_district_lower': '01055',
#    'lower_chamber_name': 'State House District 55',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101693,
#    'opeid': '102900',
#    'inst_name': 'University of Mobile',
#    'address': '5735 College Parkway Drive',
#    'state_abbr': 'AL',
#    'zip': '36613-2842',
#    'county_name': 'Mobile',
#    'county_fips': 1097,
#    'geo_longitude': -88.12458,
#    'geo_latitude': 30.797369,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1097,
#    'tract': 6105,
#    'puma': '2703',
#    'block_group': 1,
#    'geoid_block': '010970061051',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 380,
#    'cbsa': 33660,
#    'cbsa_name': 'Mobile, AL',
#    'cbsa_type': 1,
#    'place_name': 'Prichard city',
#    'place_fips': 62496,
#    'geoid_place': '0162496',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '034',
#    'state_leg_district_upper': '01034',
#    'upper_chamber_name': 'State Senate District 34',
#    'lower_chamber': '098',
#    'state_leg_district_lower': '01098',
#    'lower_chamber_name': 'State House District 98',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101709,
#    'opeid': '100400',
#    'inst_name': 'University of Montevallo',
#    'address': 'Station 6001',
#    'state_abbr': 'AL',
#    'zip': '35115-6000',
#    'county_name': 'Shelby',
#    'county_fips': 1117,
#    'geo_longitude': -86.82062,
#    'geo_latitude': 33.16937,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1117,
#    'tract': 30604,
#    'puma': '1200',
#    'block_group': 1,
#    'geoid_block': '011170306041',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 142,
#    'cbsa': 13820,
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'cbsa_type': 1,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'cbsa_city': None,
#    'upper_chamber': '014',
#    'state_leg_district_upper': '01014',
#    'upper_chamber_name': 'State Senate District 14',
#    'lower_chamber': '041',
#    'state_leg_district_lower': '01041',
#    'lower_chamber_name': 'State House District 41',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101736,
#    'opeid': '569700',
#    'inst_name': 'Northwest-Shoals Community College',
#    'address': '800 George Wallace Blvd',
#    'state_abbr': 'AL',
#    'zip': '35661',
#    'county_name': 'Colbert',
#    'county_fips': 1033,
#    'geo_longitude': -87.67937,
#    'geo_latitude': 34.740017,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1033,
#    'tract': 20704,
#    'puma': '100',
#    'block_group': 1,
#    'geoid_block': '010330207041',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 22520,
#    'cbsa_name': 'Florence-Muscle Shoals, AL',
#    'cbsa_type': 1,
#    'place_name': 'Tuscumbia city',
#    'place_fips': 77280,
#    'geoid_place': '0177280',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '001',
#    'state_leg_district_upper': '01001',
#    'upper_chamber_name': 'State Senate District 1',
#    'lower_chamber': '003',
#    'state_leg_district_lower': '01003',
#    'lower_chamber_name': 'State House District 3',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101879,
#    'opeid': '101600',
#    'inst_name': 'University of North Alabama',
#    'address': 'One Harrison Plaza',
#    'state_abbr': 'AL',
#    'zip': '35632-0001',
#    'county_name': 'Lauderdale',
#    'county_fips': 1077,
#    'geo_longitude': -87.6801,
#    'geo_latitude': 34.808933,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1077,
#    'tract': 10100,
#    'puma': '100',
#    'block_group': 2,
#    'geoid_block': '010770101002',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 22520,
#    'cbsa_name': 'Florence-Muscle Shoals, AL',
#    'cbsa_type': 1,
#    'place_name': 'Florence city',
#    'place_fips': 26896,
#    'geoid_place': '0126896',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '001',
#    'state_leg_district_upper': '01001',
#    'upper_chamber_name': 'State Senate District 1',
#    'lower_chamber': '001',
#    'state_leg_district_lower': '01001',
#    'lower_chamber_name': 'State House District 1',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101897,
#    'opeid': '103100',
#    'inst_name': 'Northeast Alabama Community College',
#    'address': '138  Highway 35',
#    'state_abbr': 'AL',
#    'zip': '35986',
#    'county_name': 'Jackson',
#    'county_fips': 1071,
#    'geo_longitude': -85.848915,
#    'geo_latitude': 34.494946,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1049,
#    'tract': 960300,
#    'puma': '400',
#    'block_group': 5,
#    'geoid_block': '010499603005',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': None,
#    'cbsa': 22840,
#    'cbsa_name': 'Fort Payne, AL',
#    'cbsa_type': 2,
#    'place_name': 'Rainsville city',
#    'place_fips': 63336,
#    'geoid_place': '0163336',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '008',
#    'state_leg_district_upper': '01008',
#    'upper_chamber_name': 'State Senate District 8',
#    'lower_chamber': '024',
#    'state_leg_district_lower': '01024',
#    'lower_chamber_name': 'State House District 24',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101912,
#    'opeid': '103300',
#    'inst_name': 'Oakwood University',
#    'address': '7000 Adventist Blvd NW',
#    'state_abbr': 'AL',
#    'zip': '35896',
#    'county_name': 'Madison',
#    'county_fips': 1089,
#    'geo_longitude': -86.659996,
#    'geo_latitude': 34.754032,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 1,
#    'county_fips_geo': 1089,
#    'tract': 10622,
#    'puma': '301',
#    'block_group': 2,
#    'geoid_block': '010890106222',
#    'census_region': 3,
#    'census_division': 6,
#    'csa': 290,
#    'cbsa': 26620,
#    'cbsa_name': 'Huntsville, AL',
#    'cbsa_type': 1,
#    'place_name': 'Huntsville city',
#    'place_fips': 37000,
#    'geoid_place': '0137000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '002',
#    'state_leg_district_upper': '01002',
#    'upper_chamber_name': 'State Senate District 2',
#    'lower_chamber': '019',
#    'state_leg_district_lower': '01019',
#    'lower_chamber_name': 'State House District 19',
#    'lower_chamber_type': 3},
#   {'year': 2014,
#    'fips': 1,
#    'unitid': 101949,
#    'opeid': '103400',
#    'inst_name': 'Alabama Southern Community College',
#    'address': '2800 South Alabama Avenue',
#    'state_abbr': 'AL',
#    'zip': '36460',
#    'county_name': 'Monroe',
#    'county_fips': 1099,
#    'geo_longitude': -87.32547,
#    'geo_latitude': 31.487413,
#    'geocode_accuracy_detailed': -2,
# ...
#    'address': '1140 Galaxy Way Ste 400',
#    'state_abbr': 'CA',
#    'zip': '94520',
#    'county_name': 'Contra Costa',
#    'county_fips': 6013,
#    'geo_longitude': -122.0544,
#    'geo_latitude': 37.976944,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6013,
#    'tract': 327000,
#    'puma': '1303',
#    'block_group': 5,
#    'geoid_block': '060133270005',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 488,
#    'cbsa': 41860,
#    'cbsa_name': 'San Francisco-Oakland-Fremont, CA',
#    'cbsa_type': 1,
#    'place_name': 'Concord city',
#    'place_fips': 16000,
#    'geoid_place': '0616000',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '007',
#    'state_leg_district_upper': '06007',
#    'upper_chamber_name': 'State Senate District 7',
#    'lower_chamber': '011',
#    'state_leg_district_lower': '06011',
#    'lower_chamber_name': 'Assembly District 11',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 456588,
#    'opeid': '1309501',
#    'inst_name': 'Salon Success Academy-Fontana',
#    'address': '16803 Arrow Hwy',
#    'state_abbr': 'CA',
#    'zip': '92335',
#    'county_name': 'San Bernardino',
#    'county_fips': 6071,
#    'geo_longitude': -117.437836,
#    'geo_latitude': 34.099163,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6071,
#    'tract': 3000,
#    'puma': '7110',
#    'block_group': 2,
#    'geoid_block': '060710030002',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 40140,
#    'cbsa_name': 'Riverside-San Bernardino-Ontario, CA',
#    'cbsa_type': 1,
#    'place_name': 'Fontana city',
#    'place_fips': 24680,
#    'geoid_place': '0624680',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '032',
#    'state_leg_district_upper': '06032',
#    'upper_chamber_name': 'State Senate District 32',
#    'lower_chamber': '062',
#    'state_leg_district_lower': '06062',
#    'lower_chamber_name': 'Assembly District 62',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 456597,
#    'opeid': '1309502',
#    'inst_name': 'Salon Success Academy-Redlands',
#    'address': '1915 W Redlands Blvd Ste 111',
#    'state_abbr': 'CA',
#    'zip': '92373',
#    'county_name': 'San Bernardino',
#    'county_fips': 6071,
#    'geo_longitude': -117.21881,
#    'geo_latitude': 34.0629,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6071,
#    'tract': 7800,
#    'puma': '7105',
#    'block_group': 1,
#    'geoid_block': '060710078001',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 40140,
#    'cbsa_name': 'Riverside-San Bernardino-Ontario, CA',
#    'cbsa_type': 1,
#    'place_name': 'Redlands city',
#    'place_fips': 59962,
#    'geoid_place': '0659962',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '031',
#    'state_leg_district_upper': '06031',
#    'upper_chamber_name': 'State Senate District 31',
#    'lower_chamber': '063',
#    'state_leg_district_lower': '06063',
#    'lower_chamber_name': 'Assembly District 63',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 456852,
#    'opeid': '2120708',
#    'inst_name': 'San Joaquin Valley College-Hesperia',
#    'address': ' ',
#    'state_abbr': 'CA',
#    'zip': ' ',
#    'county_name': 'San Bernardino',
#    'county_fips': 6071,
#    'geo_longitude': -119.27023,
#    'geo_latitude': 36.374107,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6107,
#    'tract': 800,
#    'puma': '10703',
#    'block_group': 3,
#    'geoid_block': '061070008003',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 47300,
#    'cbsa_name': 'Visalia-Porterville, CA',
#    'cbsa_type': 1,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'cbsa_city': None,
#    'upper_chamber': '018',
#    'state_leg_district_upper': '06018',
#    'upper_chamber_name': 'State Senate District 18',
#    'lower_chamber': '034',
#    'state_leg_district_lower': '06034',
#    'lower_chamber_name': 'Assembly District 34',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457077,
#    'opeid': '3422302',
#    'inst_name': 'Milan Institute-Bakersfield',
#    'address': '2822 F Street, Ste H',
#    'state_abbr': 'CA',
#    'zip': '93301',
#    'county_name': 'Kern',
#    'county_fips': 6029,
#    'geo_longitude': -119.02344,
#    'geo_latitude': 35.385506,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6029,
#    'tract': 1600,
#    'puma': '2903',
#    'block_group': 2,
#    'geoid_block': '060290016002',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 12540,
#    'cbsa_name': 'Bakersfield-Delano, CA',
#    'cbsa_type': 1,
#    'place_name': 'Bakersfield city',
#    'place_fips': 3526,
#    'geoid_place': '0603526',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '018',
#    'state_leg_district_upper': '06018',
#    'upper_chamber_name': 'State Senate District 18',
#    'lower_chamber': '032',
#    'state_leg_district_lower': '06032',
#    'lower_chamber_name': 'Assembly District 32',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457086,
#    'opeid': '4149700',
#    'inst_name': 'Homestead Schools',
#    'address': '23800 Hawthorne Blvd.',
#    'state_abbr': 'CA',
#    'zip': '90505',
#    'county_name': 'Los Angeles',
#    'county_fips': 6037,
#    'geo_longitude': -118.350655,
#    'geo_latitude': 33.809017,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6037,
#    'tract': 651101,
#    'puma': '3761',
#    'block_group': 2,
#    'geoid_block': '060376511012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 31100,
#    'cbsa_name': 'Los Angeles-Long Beach-Santa Ana, CA',
#    'cbsa_type': 1,
#    'place_name': 'Torrance city',
#    'place_fips': 80000,
#    'geoid_place': '0680000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '028',
#    'state_leg_district_upper': '06028',
#    'upper_chamber_name': 'State Senate District 28',
#    'lower_chamber': '053',
#    'state_leg_district_lower': '06053',
#    'lower_chamber_name': 'Assembly District 53',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457208,
#    'opeid': '2559406',
#    'inst_name': 'InterCoast Colleges-Elk Grove',
#    'address': '9355 E. Stockton',
#    'state_abbr': 'CA',
#    'zip': '95624',
#    'county_name': 'Sacramento',
#    'county_fips': 6067,
#    'geo_longitude': -121.39183,
#    'geo_latitude': 38.417824,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6067,
#    'tract': 9308,
#    'puma': '6710',
#    'block_group': 2,
#    'geoid_block': '060670093082',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 472,
#    'cbsa': 40900,
#    'cbsa_name': 'Sacramento--Arden-Arcade--Roseville, CA',
#    'cbsa_type': 1,
#    'place_name': 'Elk Grove city',
#    'place_fips': 22020,
#    'geoid_place': '0622020',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '001',
#    'state_leg_district_upper': '06001',
#    'upper_chamber_name': 'State Senate District 1',
#    'lower_chamber': '015',
#    'state_leg_district_lower': '06015',
#    'lower_chamber_name': 'Assembly District 15',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457226,
#    'opeid': '4140500',
#    'inst_name': 'Horizon University',
#    'address': '5331 Mt. Alifan Drive',
#    'state_abbr': 'CA',
#    'zip': '92111-2622',
#    'county_name': 'San Diego',
#    'county_fips': 6073,
#    'geo_longitude': -117.18214,
#    'geo_latitude': 32.816757,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 8513,
#    'puma': '7315',
#    'block_group': 1,
#    'geoid_block': '060730085131',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'place_name': 'San Diego city',
#    'place_fips': 66000,
#    'geoid_place': '0666000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '039',
#    'state_leg_district_upper': '06039',
#    'upper_chamber_name': 'State Senate District 39',
#    'lower_chamber': '076',
#    'state_leg_district_lower': '06076',
#    'lower_chamber_name': 'Assembly District 76',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457244,
#    'opeid': '4145000',
#    'inst_name': 'San Diego Culinary Institute',
#    'address': '8024 La Mesa Blvd',
#    'state_abbr': 'CA',
#    'zip': '91942',
#    'county_name': 'San Diego',
#    'county_fips': 6073,
#    'geo_longitude': -117.02432,
#    'geo_latitude': 32.76356,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 14601,
#    'puma': '7314',
#    'block_group': 1,
#    'geoid_block': '060730146011',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'place_name': 'La Mesa city',
#    'place_fips': 40004,
#    'geoid_place': '0640004',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457253,
#    'opeid': '4148200',
#    'inst_name': 'Beyond 21st Century Beauty Academy',
#    'address': '13640 Imperial Hwy Ste 7',
#    'state_abbr': 'CA',
#    'zip': '90670',
#    'county_name': 'Los Angeles',
#    'county_fips': 6037,
#    'geo_longitude': -118.04094,
#    'geo_latitude': 33.916904,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6037,
#    'tract': 504102,
#    'puma': '3754',
#    'block_group': 1,
#    'geoid_block': '060375041021',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 31100,
#    'cbsa_name': 'Los Angeles-Long Beach-Santa Ana, CA',
#    'cbsa_type': 1,
#    'place_name': 'Santa Fe Springs city',
#    'place_fips': 69154,
#    'geoid_place': '0669154',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '030',
#    'state_leg_district_upper': '06030',
#    'upper_chamber_name': 'State Senate District 30',
#    'lower_chamber': '056',
#    'state_leg_district_lower': '06056',
#    'lower_chamber_name': 'Assembly District 56',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457271,
#    'opeid': '4155500',
#    'inst_name': 'Academy for Jewish Religion-California',
#    'address': '3250 Wilshire Boulevard, Suite 550',
#    'state_abbr': 'CA',
#    'zip': '90010',
#    'county_name': 'Los Angeles',
#    'county_fips': 6037,
#    'geo_longitude': -118.29327,
#    'geo_latitude': 34.06175,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6037,
#    'tract': 212303,
#    'puma': '3733',
#    'block_group': 1,
#    'geoid_block': '060372123031',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 31100,
#    'cbsa_name': 'Los Angeles-Long Beach-Santa Ana, CA',
#    'cbsa_type': 1,
#    'place_name': 'Los Angeles city',
#    'place_fips': 44000,
#    'geoid_place': '0644000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '026',
#    'state_leg_district_upper': '06026',
#    'upper_chamber_name': 'State Senate District 26',
#    'lower_chamber': '048',
#    'state_leg_district_lower': '06048',
#    'lower_chamber_name': 'Assembly District 48',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457280,
#    'opeid': '4158700',
#    'inst_name': 'Hollywood Beauty College',
#    'address': '1024 E March Ln',
#    'state_abbr': 'CA',
#    'zip': '95210',
#    'county_name': 'San Joaquin',
#    'county_fips': 6077,
#    'geo_longitude': -121.2937,
#    'geo_latitude': 38.001244,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6077,
#    'tract': 3407,
#    'puma': '7701',
#    'block_group': 2,
#    'geoid_block': '060770034072',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 44700,
#    'cbsa_name': 'Stockton, CA',
#    'cbsa_type': 1,
#    'place_name': 'Stockton city',
#    'place_fips': 75000,
#    'geoid_place': '0675000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '005',
#    'state_leg_district_upper': '06005',
#    'upper_chamber_name': 'State Senate District 5',
#    'lower_chamber': '017',
#    'state_leg_district_lower': '06017',
#    'lower_chamber_name': 'Assembly District 17',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457299,
#    'opeid': '4160400',
#    'inst_name': 'Angeles College',
#    'address': '3440 Wilshire Blvd Ste 310',
#    'state_abbr': 'CA',
#    'zip': '90010',
#    'county_name': 'Los Angeles',
#    'county_fips': 6037,
#    'geo_longitude': -118.29894,
#    'geo_latitude': 34.06173,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6037,
#    'tract': 212304,
#    'puma': '3733',
#    'block_group': 1,
#    'geoid_block': '060372123041',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 31100,
#    'cbsa_name': 'Los Angeles-Long Beach-Santa Ana, CA',
#    'cbsa_type': 1,
#    'place_name': 'Los Angeles city',
#    'place_fips': 44000,
#    'geoid_place': '0644000',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '026',
#    'state_leg_district_upper': '06026',
#    'upper_chamber_name': 'State Senate District 26',
#    'lower_chamber': '048',
#    'state_leg_district_lower': '06048',
#    'lower_chamber_name': 'Assembly District 48',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457314,
#    'opeid': '4164400',
#    'inst_name': 'Angeles Institute',
#    'address': '11688 SOUTH STREET, SUITE 205',
#    'state_abbr': 'CA',
#    'zip': '90701-6610',
#    'county_name': 'Los Angeles',
#    'county_fips': 6037,
#    'geo_longitude': -118.084785,
#    'geo_latitude': 33.85838,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6037,
#    'tract': 554900,
#    'puma': '3764',
#    'block_group': 5,
#    'geoid_block': '060375549005',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 31100,
#    'cbsa_name': 'Los Angeles-Long Beach-Santa Ana, CA',
#    'cbsa_type': 1,
#    'place_name': 'Artesia city',
#    'place_fips': 2896,
#    'geoid_place': '0602896',
#    'class_code': 1,
#    'cbsa_city': 0,
#    'upper_chamber': '027',
#    'state_leg_district_upper': '06027',
#    'upper_chamber_name': 'State Senate District 27',
#    'lower_chamber': '056',
#    'state_leg_district_lower': '06056',
#    'lower_chamber_name': 'Assembly District 56',
#    'lower_chamber_type': 7},
#   {'year': 2014,
#    'fips': 6,
#    'unitid': 457323,
#    'opeid': '4167000',
#    'inst_name': 'Paul Mitchell the School-Temecula',
#    'address': '27536 Ynez Rd Ste E-1',
#    'state_abbr': 'CA',
#    'zip': '92591',
#    'county_name': 'Riverside',
#    'county_fips': 6065,
#    'geo_longitude': -117.14994,
#    'geo_latitude': 33.505825,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6065,
#    'tract': 43216,
#    'puma': '6503',
#    'block_group': 1,
#    'geoid_block': '060650432161',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': 348,
#    'cbsa': 40140,
#    'cbsa_name': 'Riverside-San Bernardino-Ontario, CA',
#    'cbsa_type': 1,
#    'place_name': 'Temecula city',
#    'place_fips': 78120,
#    'geoid_place': '0678120',
#    'class_code': 1,
#    'cbsa_city': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '066',
#    'state_leg_district_lower': '06066',
#    'lower_chamber_name': 'Assembly District 66',
#    'lower_chamber_type': 7}]}

# %%
df = pd.DataFrame.from_dict(data)

# %%
dfdict = dict(df['results'])
df = pd.DataFrame.from_dict(dfdict, orient='index')

# %%
df
# Out:
#      year  fips  unitid    opeid                               inst_name  \
# 0    2014     1  100636  1230800      Community College of the Air Force
# 1    2014     1  100654   100200                Alabama A & M University
# 2    2014     1  100663   105200     University of Alabama at Birmingham
# 3    2014     1  100690  2503400                      Amridge University
# 4    2014     1  100706   105500     University of Alabama in Huntsville
# ..    ...   ...     ...      ...                                     ...
# 995  2014     6  457271  4155500  Academy for Jewish Religion-California
# 996  2014     6  457280  4158700                Hollywood Beauty College
# 997  2014     6  457299  4160400                         Angeles College
# 998  2014     6  457314  4164400                       Angeles Institute
# 999  2014     6  457323  4167000       Paul Mitchell the School-Temecula
#
#                                 address state_abbr         zip  county_name  \
# 0                     100 S Turner Blvd         AL  36114-3011   Montgomery
# 1                  4900 Meridian Street         AL       35762      Madison
# 2        Administration Bldg Suite 1070         AL  35294-0110    Jefferson
# 3                        1200 Taylor Rd         AL  36117-3553   Montgomery
# 4                       301 Sparkman Dr         AL       35899      Madison
# ..                                  ...        ...         ...          ...
# 995  3250 Wilshire Boulevard, Suite 550         CA       90010  Los Angeles
# 996                     1024 E March Ln         CA       95210  San Joaquin
# 997          3440 Wilshire Blvd Ste 310         CA       90010  Los Angeles
# 998       11688 SOUTH STREET, SUITE 205         CA  90701-6610  Los Angeles
# 999               27536 Ynez Rd Ste E-1         CA       92591    Riverside
#
#      county_fips  geo_longitude  geo_latitude  geocode_accuracy_detailed  \
# 0           1101     -86.244520     32.406143                         -2
# 1           1089     -86.572280     34.783787                         -2
# 2           1073     -86.812080     33.505920                         -2
# 3           1101     -86.171520     32.363990                         -2
# 4           1089     -86.644040     34.723490                         -2
# ..           ...            ...           ...                        ...
# 995         6037    -118.293270     34.061750                         -2
# 996         6077    -121.293700     38.001244                         -2
# 997         6037    -118.298940     34.061730                         -2
# 998         6037    -118.084785     33.858380                         -2
# 999         6065    -117.149940     33.505825                         -2
#
#      geocode_accuracy  state_fips_geo  county_fips_geo   tract  puma  \
# 0                  -2               1             1101    5301  2000
# 1                  -2               1             1089     202   302
# 2                  -2               1             1073    4500  1302
# 3                  -2               1             1101    5407  2000
# 4                  -2               1             1089    1500   301
# ..                ...             ...              ...     ...   ...
# 995                -2               6             6037  212303  3733
# 996                -2               6             6077    3407  7701
# 997                -2               6             6037  212304  3733
# 998                -2               6             6037  554900  3764
# 999                -2               6             6065   43216  6503
#
#      block_group   geoid_block  census_region  census_division    csa  \
# 0              1  011010053011              3                6  388.0
# 1              1  010890002021              3                6  290.0
# 2              1  010730045001              3                6  142.0
# 3              2  011010054072              3                6  388.0
# 4              3  010890015003              3                6  290.0
# ..           ...           ...            ...              ...    ...
# 995            1  060372123031              4                9  348.0
# 996            2  060770034072              4                9    NaN
# 997            1  060372123041              4                9  348.0
# 998            5  060375549005              4                9  348.0
# 999            1  060650432161              4                9  348.0
#
#         cbsa                             cbsa_name  cbsa_type  \
# 0    33860.0                        Montgomery, AL        1.0
# 1    26620.0                        Huntsville, AL        1.0
# 2    13820.0                 Birmingham-Hoover, AL        1.0
# 3    33860.0                        Montgomery, AL        1.0
# 4    26620.0                        Huntsville, AL        1.0
# ..       ...                                   ...        ...
# 995  31100.0  Los Angeles-Long Beach-Santa Ana, CA        1.0
# 996  44700.0                          Stockton, CA        1.0
# 997  31100.0  Los Angeles-Long Beach-Santa Ana, CA        1.0
# 998  31100.0  Los Angeles-Long Beach-Santa Ana, CA        1.0
# 999  40140.0  Riverside-San Bernardino-Ontario, CA        1.0
#
#            place_name  place_fips geoid_place  class_code  cbsa_city  \
# 0     Montgomery city     51000.0     0151000         1.0        1.0
# 1     Huntsville city     37000.0     0137000         1.0        1.0
# 2     Birmingham city      7000.0     0107000         1.0        1.0
# 3     Montgomery city     51000.0     0151000         1.0        1.0
# 4     Huntsville city     37000.0     0137000         1.0        1.0
# ..                ...         ...         ...         ...        ...
# 995  Los Angeles city     44000.0     0644000         1.0        1.0
# 996     Stockton city     75000.0     0675000         1.0        1.0
# 997  Los Angeles city     44000.0     0644000         1.0        1.0
# 998      Artesia city      2896.0     0602896         1.0        0.0
# 999     Temecula city     78120.0     0678120         1.0        1.0
#
#     upper_chamber state_leg_district_upper        upper_chamber_name  \
# 0             025                    01025  State Senate District 25
# 1             007                    01007   State Senate District 7
# 2             018                    01018  State Senate District 18
# 3             025                    01025  State Senate District 25
# 4             002                    01002   State Senate District 2
# ..            ...                      ...                       ...
# 995           026                    06026  State Senate District 26
# 996           005                    06005   State Senate District 5
# 997           026                    06026  State Senate District 26
# 998           027                    06027  State Senate District 27
# 999           036                    06036  State Senate District 36
#
#     lower_chamber state_leg_district_lower       lower_chamber_name  \
# 0             074                    01074  State House District 74
# 1             019                    01019  State House District 19
# 2             053                    01053  State House District 53
# 3             075                    01075  State House District 75
# 4             006                    01006   State House District 6
# ..            ...                      ...                      ...
# 995           048                    06048     Assembly District 48
# 996           017                    06017     Assembly District 17
# 997           048                    06048     Assembly District 48
# 998           056                    06056     Assembly District 56
# 999           066                    06066     Assembly District 66
#
#      lower_chamber_type
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3
# ..                  ...
# 995                   7
# 996                   7
# 997                   7
# 998                   7
# 999                   7
#
# [1000 rows x 38 columns]
