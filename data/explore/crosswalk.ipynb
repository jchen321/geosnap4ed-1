# %% [markdown]
# not sure what this is yet. downloaded from the bottom of [this page](https://edopportunity.org/get-the-data/seda-archive-downloads/)

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %%
df = pd.read_csv("../SEDA_files/SEDA_crosswalk_v30.csv", encoding="ISO-8859–1")
# Out:
# C:\Users\fiend\Anaconda2\envs\capstone\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5,11,13,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
#huge
# Out:
# (804913, 35)

# %%
df.head()
# Out:
#        ncessch  ncessch_orig  year  leaidO                leanameO   leaidC  \
# 0  10000200277   10000200277  2009  100002  ALABAMA YOUTH SERVICES  0100002
# 1  10000200277   10000200277  2010  100002  ALABAMA YOUTH SERVICES  0100002
# 2  10000200277   10000200277  2011  100002  ALABAMA YOUTH SERVICES  0100002
# 3  10000200277   10000200277  2012  100002  ALABAMA YOUTH SERVICES  0100002
# 4  10000200277   10000200277  2013  100002  ALABAMA YOUTH SERVICES  0100002
#
#                  leanameC change_type  leaid_orig  fips stateabb countyid  \
# 0  ALABAMA YOUTH SERVICES  no changes      100002     1       AL    01101
# 1  ALABAMA YOUTH SERVICES  no changes      100002     1       AL    01101
# 2  ALABAMA YOUTH SERVICES  no changes      100002     1       AL    01101
# 3  ALABAMA YOUTH SERVICES  no changes      100002     1       AL    01101
# 4  ALABAMA YOUTH SERVICES  no changes      100002     1       AL    01101
#
# ...
