# %%
from json import loads
from urllib.request import urlopen

# %%
root = "https://educationdata.urban.org/api/v1/"

# %%
colg = "college-university/"

# %% [markdown]
# options for layer are:
#
# `ipeds/` - lots of [subvariables](https://educationdata.urban.org/documentation/colleges.html#ipeds_directory) here.: "...Contains directory information for every institution in the IPEDS universe. This includes name, address, city, state, zip code, and various URL links to the institution's home page, admissions, financial aid offices, and the net price calculator. Identifies institutions as currently active and institutions that participate in Title IV federal financial aid programs for which IPEDS is mandatory. It also includes variables derived from the Institutional Characteristics survey, such as control and level of institution, highest level and highest degree offered and Carnegie classifications."
#
# `scorecard/`: "... Contains institutional characteristics for each college or university, primarily including flags for minority-serving institutions. To avoid duplication, we exclude data that College Scorecard sourced from IPEDS. For these data, you can see the other Institutional Characteristics and Directory endpoints. Notably, most of the information contained in this endpoint can be found in 2016 and aside from identification and year, only predominant degree awarded is available in other years."
#
# `nhgis/`: "...Contains geographic variables corresponding to 2010 Census geographies for each IPEDS institution. Geographies are merged on by latitude and longitude when available; when unavailable, latitudes and longitudes were obtained from address information using Urban's geocoder. The geocoder uses StreetMap Premium from Esri to perform accurate offline geocoding. Geocode accuracy variables indicate the degree of precision of this geocoding. Additional information on the match accuracy can be found [here](https://developers.arcgis.com/rest/geocode/api-reference/geocoding-service-output.htm). Geographies for older years of data or low-accuracy geocode matches should be used with caution.
#
# `fsa/`: "...Contains financial responsibility composites scores for for-profit and nonprofit institutions. These scores gauge an institution's financial health and help the Department of Education assess an institution's financial responsibility compliance. The scores are based on a primary reserve ratio, an equity ratio, and a net income ratio. They are collected at the OPEID level, but we report them at the UNITID level in order to facilitate merging with IPEDS data.
#
#
# `this cell does not reflect the extent of the datasets --update`

# %%
layer = "ipeds/"

# %%
sublayer = "directory/"

# %%
year = "2018/"

# %%
url = root + colg + layer + sublayer + year

# %%
url
# Out:
# 'https://educationdata.urban.org/api/v1/college-university/ipeds/directory/2018/'

# %%
response = urlopen(url)

data = loads(response.read())

# %%
data
# Out:
# {'count': 6857,
#  'next': 'https://educationdata.urban.org/api/v1/college-university/ipeds/directory/2018/?page=2',
#  'previous': None,
#  'results': [{'year': 2018,
#    'unitid': 100654,
#    'inst_name': 'Alabama A & M University',
#    'address': '4900 Meridian Street',
#    'state_abbr': 'AL',
#    'zip': '35762',
#    'phone_number': '2563725000',
#    'city': 'Normal',
#    'county_name': 'Madison County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Dr. Andrew Hugine, Jr.',
#    'chief_admin_title': 'President',
#    'hbcu': 1,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '636001109',
#    'urban_centric_locale': 12,
#    'opeid': '00100200',
#    'offering_highest_degree': 12,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '197216455',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.aamu.edu/',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 1,
#    'inst_size': 3,
#    'inst_alias': 'AAMU',
#    'url_fin_aid': 'www.aamu.edu/admissions/fincialaid/pages/default.aspx',
#    'url_application': 'https://www.aamu.edu/Admissions/UndergraduateAdmissions/Pages/Apply%20Today.aspx',
#    'cbsa': 26620,
#    'cbsa_type': 1,
#    'csa': 290,
#    'necta': -2,
#    'comparison_group': 119,
#    'longitude': -86.568504,
#    'latitude': 34.783367,
#    'county_fips': 1089,
#    'congress_district_id': 105,
#    'cc_basic_2010': 18,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 16,
#    'url_netprice': 'https://galileo.aamu.edu/NetPriceCalculator/npcalc.htm',
#    'comparison_group_custom': 1,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': 18,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 18,
#    'cc_instruc_undergrad_2018': 16,
#    'cc_instruc_grad_2018': 17,
#    'cc_undergrad_2018': 10,
#    'cc_enroll_2018': 4,
#    'cc_size_setting_2018': 14,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.aamu.edu/administrativeoffices/VADS/Pages/Disability-Services.aspx'},
#   {'year': 2018,
#    'unitid': 100663,
#    'inst_name': 'University of Alabama at Birmingham',
#    'address': 'Administration Bldg Suite 1070',
#    'state_abbr': 'AL',
#    'zip': '35294-0110',
#    'phone_number': '2059344011',
#    'city': 'Birmingham',
#    'county_name': 'Jefferson County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Ray L. Watts',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 1,
#    'medical_degree': 1,
#    'tribal_college': 0,
#    'ein': '636005396',
#    'urban_centric_locale': 12,
#    'opeid': '00105200',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '063690705',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.uab.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'The University of Alabama System',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 5,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.uab.edu/students/paying-for-college',
#    'url_application': 'https://idm.uab.edu/myuab/login?from=ugadmapp',
#    'cbsa': 13820,
#    'cbsa_type': 1,
#    'csa': 142,
#    'necta': -2,
#    'comparison_group': 105,
#    'longitude': -86.79935,
#    'latitude': 33.505695,
#    'county_fips': 1073,
#    'congress_district_id': 107,
#    'cc_basic_2010': 15,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 15,
#    'url_netprice': 'uab.studentaidcalculator.com/survey.aspx',
#    'comparison_group_custom': 1,
#    'url_veterans': 'www.uab.edu/students/veterans',
#    'url_athletes': 'www.uab.edu/registrar/students',
#    'cc_basic_2015': 15,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 15,
#    'cc_instruc_undergrad_2018': 17,
#    'cc_instruc_grad_2018': 17,
#    'cc_undergrad_2018': 9,
#    'cc_enroll_2018': 5,
#    'cc_size_setting_2018': 15,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.uab.edu/students/disability/'},
#   {'year': 2018,
#    'unitid': 100690,
#    'inst_name': 'Amridge University',
#    'address': '1200 Taylor Rd',
#    'state_abbr': 'AL',
#    'zip': '36117-3553',
#    'phone_number': '33438738777528',
#    'city': 'Montgomery',
#    'county_name': 'Montgomery County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 1,
#    'chief_admin_name': 'Michael C.Turner',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '237034324',
#    'urban_centric_locale': 12,
#    'opeid': '02503400',
#    'offering_highest_degree': 12,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '126307792',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.amridgeuniversity.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 1,
#    'inst_alias': 'Southern Christian University |Regions University',
#    'url_fin_aid': 'www.amridgeuniversity.edu/financialaid/',
#    'url_application': 'https://www2.amridgeuniversity.edu/Amridge/Login.aspx',
#    'cbsa': 33860,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 137,
#    'longitude': -86.17401,
#    'latitude': 32.36261,
#    'county_fips': 1101,
#    'congress_district_id': 102,
#    'cc_basic_2010': 21,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 51,
#    'url_netprice': 'www2.amridgeuniversity.edu:9091/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.amridgeuniversity.edu/admissions/military/',
#    'url_athletes': ' ',
#    'cc_basic_2015': 20,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 20,
#    'cc_instruc_undergrad_2018': 19,
#    'cc_instruc_grad_2018': 18,
#    'cc_undergrad_2018': 5,
#    'cc_enroll_2018': 5,
#    'cc_size_setting_2018': 6,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.amridgeuniversity.edu/pdf/Amridge%20University%20Academic%20Catalog%202017-2018.pdf'},
#   {'year': 2018,
#    'unitid': 100706,
#    'inst_name': 'University of Alabama in Huntsville',
#    'address': '301 Sparkman Dr',
#    'state_abbr': 'AL',
#    'zip': '35899',
#    'phone_number': '2568246120',
#    'city': 'Huntsville',
#    'county_name': 'Madison County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Robert A. Altenkirch',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630520830',
#    'urban_centric_locale': 12,
#    'opeid': '00105500',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '949687123',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.uah.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'The University of Alabama System',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 3,
#    'inst_alias': 'UAH |University of Alabama Huntsville',
#    'url_fin_aid': 'finaid.uah.edu/',
#    'url_application': 'register.uah.edu',
#    'cbsa': 26620,
#    'cbsa_type': 1,
#    'csa': 290,
#    'necta': -2,
#    'comparison_group': 109,
#    'longitude': -86.64045,
#    'latitude': 34.724556,
#    'county_fips': 1089,
#    'congress_district_id': 105,
#    'cc_basic_2010': 15,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 16,
#    'url_netprice': 'finaid.uah.edu/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.uah.edu/admissions/graduate/financial-aid/veterans',
#    'url_athletes': 'www.uah.edu/heoa',
#    'cc_basic_2015': 16,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 16,
#    'cc_instruc_undergrad_2018': 17,
#    'cc_instruc_grad_2018': 17,
#    'cc_undergrad_2018': 15,
#    'cc_enroll_2018': 4,
#    'cc_size_setting_2018': 12,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.uah.edu/health-and-wellness/disability-support'},
#   {'year': 2018,
#    'unitid': 100724,
#    'inst_name': 'Alabama State University',
#    'address': '915 S Jackson Street',
#    'state_abbr': 'AL',
#    'zip': '36104-0271',
#    'phone_number': '3342294100',
#    'city': 'Montgomery',
#    'county_name': 'Montgomery County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Quinton T. Ross',
#    'chief_admin_title': 'President',
#    'hbcu': 1,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '636001101',
#    'urban_centric_locale': 12,
#    'opeid': '00100500',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '040672685',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.alasu.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.alasu.edu/cost-aid/index.aspx',
#    'url_application': 'www.alasu.edu/admissions/undergrad-admissions/index.aspx',
#    'cbsa': 33860,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 127,
#    'longitude': -86.29568,
#    'latitude': 32.36432,
#    'county_fips': 1101,
#    'congress_district_id': 107,
#    'cc_basic_2010': 18,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 21,
#    'url_netprice': 'www.alasu.edu/cost-aid/forms/calculator/index.aspx',
#    'comparison_group_custom': 1,
#    'url_veterans': ' ',
#    'url_athletes': 'www.alasu.edu/search-results/index.aspx',
#    'cc_basic_2015': 19,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 19,
#    'cc_instruc_undergrad_2018': 13,
#    'cc_instruc_grad_2018': 13,
#    'cc_undergrad_2018': 10,
#    'cc_enroll_2018': 3,
#    'cc_size_setting_2018': 14,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.alasu.edu/about-asu/the-campus/disability-accessibility/index.aspx'},
#   {'year': 2018,
#    'unitid': 100733,
#    'inst_name': 'University of Alabama System Office',
#    'address': '500 University Blvd. East',
#    'state_abbr': 'AL',
#    'zip': '35401',
#    'phone_number': '2053485122',
#    'city': 'Tuscaloosa',
#    'county_name': 'Tuscaloosa County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 0,
#    'fips': 1,
#    'chief_admin_name': 'Finis St. John IV',
#    'chief_admin_title': 'Chancellor (Interim)',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': -2,
#    'tribal_college': 0,
#    'ein': '636001138',
#    'urban_centric_locale': 12,
#    'opeid': '00800400',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '808245794',
#    'title_iv_indicator': 2,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.uasystem.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'The University of Alabama System',
#    'reporting_method': -2,
#    'inst_category': -2,
#    'land_grant': 0,
#    'inst_size': -2,
#    'inst_alias': ' ',
#    'url_fin_aid': ' ',
#    'url_application': ' ',
#    'cbsa': 46220,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': -2,
#    'longitude': -87.529594,
#    'latitude': 33.207016,
#    'county_fips': 1125,
#    'congress_district_id': 107,
#    'cc_basic_2010': -2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': -2,
#    'url_netprice': 'www.uasystem.edu',
#    'comparison_group_custom': -2,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': -2,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': -2,
#    'cc_instruc_undergrad_2018': -2,
#    'cc_instruc_grad_2018': -2,
#    'cc_undergrad_2018': -2,
#    'cc_enroll_2018': -2,
#    'cc_size_setting_2018': -2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.uasystem.edu'},
#   {'year': 2018,
#    'unitid': 100751,
#    'inst_name': 'The University of Alabama',
#    'address': '739 University Blvd',
#    'state_abbr': 'AL',
#    'zip': '35487-0166',
#    'phone_number': '2053486010',
#    'city': 'Tuscaloosa',
#    'county_name': 'Tuscaloosa County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Dr. Stuart R. Bell',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '636001138',
#    'urban_centric_locale': 12,
#    'opeid': '00105100',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '045632635',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.ua.edu/',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'The University of Alabama System',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 5,
#    'inst_alias': ' ',
#    'url_fin_aid': 'financialaid.ua.edu',
#    'url_application': 'apply.ua.edu',
#    'cbsa': 46220,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 103,
#    'longitude': -87.545975,
#    'latitude': 33.211876,
#    'county_fips': 1125,
#    'congress_district_id': 107,
#    'cc_basic_2010': 16,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 15,
#    'url_netprice': 'financialaid.ua.edu/net-price-calculator/',
#    'comparison_group_custom': 1,
#    'url_veterans': 'https://vets.sa.ua.edu/',
#    'url_athletes': 'registrar.ua.edu/academics-policies/student-right-to-know/',
#    'cc_basic_2015': 16,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 15,
#    'cc_instruc_undergrad_2018': 17,
#    'cc_instruc_grad_2018': 15,
#    'cc_undergrad_2018': 14,
#    'cc_enroll_2018': 4,
#    'cc_size_setting_2018': 16,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'ods.ua.edu'},
#   {'year': 2018,
#    'unitid': 100760,
#    'inst_name': 'Central Alabama Community College',
#    'address': '1675 Cherokee Rd',
#    'state_abbr': 'AL',
#    'zip': '35010',
#    'phone_number': '2562346346',
#    'city': 'Alexander City',
#    'county_name': 'Tallapoosa County',
#    'offering_highest_level': 3,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 1,
#    'chief_admin_name': 'Dr. Susan Burrow',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '631022757',
#    'urban_centric_locale': 32,
#    'opeid': '00100700',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '874447246',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.cacc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Alabama Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'https://www.cacc.edu/financial-aid/',
#    'url_application': ' ',
#    'cbsa': 10760,
#    'cbsa_type': 2,
#    'csa': 142,
#    'necta': -2,
#    'comparison_group': 75,
#    'longitude': -85.94527,
#    'latitude': 32.92478,
#    'county_fips': 1123,
#    'congress_district_id': 103,
#    'cc_basic_2010': 2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'https://www.cacc.edu/net-price-calculator/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'https://www.cacc.edu/financial-aid/',
#    'url_athletes': 'https://www.cacc.edu/about/consumer-information/student-outcomes/',
#    'cc_basic_2015': 1,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 2,
#    'cc_instruc_undergrad_2018': 2,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.cacc.edu/about/consumer-information/general-institutional-information/DSO%20Website%20Info.pdf'},
#   {'year': 2018,
#    'unitid': 100812,
#    'inst_name': 'Athens State University',
#    'address': '300 N Beaty St',
#    'state_abbr': 'AL',
#    'zip': '35611',
#    'phone_number': '2562338100',
#    'city': 'Athens',
#    'county_name': 'Limestone County',
#    'offering_highest_level': 7,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Ron Ingle',
#    'chief_admin_title': 'Interim President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630701340',
#    'urban_centric_locale': 31,
#    'opeid': '00100800',
#    'offering_highest_degree': 20,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '040651853',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.athens.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.athens.edu/financial-aid/',
#    'url_application': 'www.athens.edu/apply',
#    'cbsa': 26620,
#    'cbsa_type': 1,
#    'csa': 290,
#    'necta': -2,
#    'comparison_group': 147,
#    'longitude': -86.9647,
#    'latitude': 34.806793,
#    'county_fips': 1083,
#    'congress_district_id': 105,
#    'cc_basic_2010': 22,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 32,
#    'url_netprice': ' ',
#    'comparison_group_custom': 1,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': 22,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 22,
#    'cc_instruc_undergrad_2018': 15,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 5,
#    'cc_enroll_2018': 3,
#    'cc_size_setting_2018': 9,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.athens.edu/disability-services/'},
#   {'year': 2018,
#    'unitid': 100830,
#    'inst_name': 'Auburn University at Montgomery',
#    'address': '7440 East Drive',
#    'state_abbr': 'AL',
#    'zip': '36117-3596',
#    'phone_number': '3342443000',
#    'city': 'Montgomery',
#    'county_name': 'Montgomery County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Carl A. Stockton',
#    'chief_admin_title': 'Chancellor',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '636000724',
#    'urban_centric_locale': 12,
#    'opeid': '00831000',
#    'offering_highest_degree': 12,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '183862119',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.aum.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Auburn University',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 3,
#    'inst_alias': 'AUM||Auburn University at Montgomery|Auburn Montgomery',
#    'url_fin_aid': 'www.aum.edu/admissions/scholarships-and-financial-aid/financial-aid',
#    'url_application': 'www.aum.edu/admissions/step-by-step-guide-to-apply',
#    'cbsa': 33860,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 120,
#    'longitude': -86.17754,
#    'latitude': 32.36736,
#    'county_fips': 1101,
#    'congress_district_id': 102,
#    'cc_basic_2010': 18,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 21,
#    'url_netprice': 'www.aum.edu/current-students/financial-information/net-price-calculator',
#    'comparison_group_custom': 1,
#    'url_veterans': 'www.aum.edu/admissions/financial-affairs/financial-aid/veteran-services',
#    'url_athletes': 'www.aum.edu/academics/institutional-effectiveness/consumer-information',
#    'cc_basic_2015': 18,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 18,
#    'cc_instruc_undergrad_2018': 16,
#    'cc_instruc_grad_2018': 4,
#    'cc_undergrad_2018': 9,
#    'cc_enroll_2018': 3,
#    'cc_size_setting_2018': 13,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.aum.edu/campus-life/student-affairs/center-for-disability-services'},
#   {'year': 2018,
#    'unitid': 100858,
#    'inst_name': 'Auburn University',
#    'address': ' ',
#    'state_abbr': 'AL',
#    'zip': '36849',
#    'phone_number': '3348444000',
#    'city': 'Auburn',
#    'county_name': 'Lee County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 4,
#    'sector': 1,
#    'fips': 1,
#    'chief_admin_name': 'Steven Leath',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 1,
#    'tribal_college': 0,
#    'ein': '636000724',
#    'urban_centric_locale': 13,
#    'opeid': '00100900',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '066470972',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.auburn.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Auburn University',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 1,
#    'inst_size': 5,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.auburn.edu/administration/business-finance/finaid/',
#    'url_application': 'www.auburn.edu/admissions/',
#    'cbsa': 12220,
#    'cbsa_type': 1,
#    'csa': 194,
#    'necta': -2,
#    'comparison_group': 104,
#    'longitude': -85.48826,
#    'latitude': 32.599377,
#    'county_fips': 1081,
#    'congress_district_id': 103,
#    'cc_basic_2010': 16,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 15,
#    'url_netprice': 'https://www.auburn.edu/admissions/costcalc/freshman.html',
#    'comparison_group_custom': 1,
#    'url_veterans': 'veterans.auburn.edu',
#    'url_athletes': 'https://auburn.edu/administration/ir/factbook/retention-performance/athlete-graduation-rates.html',
#    'cc_basic_2015': 16,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 15,
#    'cc_instruc_undergrad_2018': 17,
#    'cc_instruc_grad_2018': 14,
#    'cc_undergrad_2018': 14,
#    'cc_enroll_2018': 4,
#    'cc_size_setting_2018': 15,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'cws.auburn.edu/accessibility'},
#   {'year': 2018,
#    'unitid': 100937,
#    'inst_name': 'Birmingham Southern College',
#    'address': '900 Arkadelphia Road',
#    'state_abbr': 'AL',
#    'zip': '35254',
#    'phone_number': '2052264600',
#    'city': 'Birmingham',
#    'county_name': 'Jefferson County',
#    'offering_highest_level': 5,
#    'region': 5,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 1,
#    'chief_admin_name': 'Ms. Linda Flaherty-Goldsmith',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630708730',
#    'urban_centric_locale': 12,
#    'opeid': '00101200',
#    'offering_highest_degree': 30,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '067136580',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.bsc.edu/',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'https://www.bsc.edu/fp/index.html',
#    'url_application': 'https://www.bsc.edu/admission/apply.html/admission/apply.html',
#    'cbsa': 13820,
#    'cbsa_type': 1,
#    'csa': 142,
#    'necta': -2,
#    'comparison_group': 144,
#    'longitude': -86.850555,
#    'latitude': 33.513775,
#    'county_fips': 1073,
#    'congress_district_id': 107,
#    'cc_basic_2010': 21,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 31,
#    'url_netprice': 'www.bsc.edu/fp/np-calculator.cfm',
#    'comparison_group_custom': 1,
#    'url_veterans': 'https://www.bsc.edu/academics/catalog/index.html',
#    'url_athletes': ' ',
#    'cc_basic_2015': 21,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 21,
#    'cc_instruc_undergrad_2018': 9,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 14,
#    'cc_enroll_2018': 2,
#    'cc_size_setting_2018': 11,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.bsc.edu/campus/accomodations/index.html'},
#   {'year': 2018,
#    'unitid': 101028,
#    'inst_name': 'Chattahoochee Valley Community College',
#    'address': '2602 College Drive',
#    'state_abbr': 'AL',
#    'zip': '36869',
#    'phone_number': '3342914900',
#    'city': 'Phenix City',
#    'county_name': 'Russell County',
#    'offering_highest_level': 3,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 1,
#    'chief_admin_name': 'Jacqueline Screws',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630657380',
#    'urban_centric_locale': 41,
#    'opeid': '01218200',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '797414158',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.cv.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Alabama Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': 'CVCC',
#    'url_fin_aid': 'www.cv.edu/currentstudents/financialaid/',
#    'url_application': 'https://services.cv.edu:444/accws/isconlap.pgm',
#    'cbsa': 17980,
#    'cbsa_type': 1,
#    'csa': 194,
#    'necta': -2,
#    'comparison_group': 70,
#    'longitude': -85.03149,
#    'latitude': 32.42391,
#    'county_fips': 1113,
#    'congress_district_id': 103,
#    'cc_basic_2010': 2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www.cv.edu/about/consumer-information/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.cv.edu/futurestudents/military-veterans/',
#    'url_athletes': 'www.cv.edu/about/consumer-information/',
#    'cc_basic_2015': 1,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 1,
#    'cc_instruc_undergrad_2018': 2,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.cv.edu/about/consumer-information/'},
#   {'year': 2018,
#    'unitid': 101073,
#    'inst_name': 'Concordia College Alabama',
#    'address': '1712 Broad Street',
#    'state_abbr': 'AL',
#    'zip': '36701',
#    'phone_number': ' ',
#    'city': 'Selma',
#    'county_name': 'Dallas County',
#    'offering_highest_level': 5,
#    'region': 5,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 1,
#    'chief_admin_name': ' ',
#    'chief_admin_title': ' ',
#    'hbcu': 1,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': -2,
#    'tribal_college': 0,
#    'ein': '-1',
#    'urban_centric_locale': 32,
#    'opeid': '01055400',
#    'offering_highest_degree': 30,
#    'currently_active_ipeds': 0,
#    'date_closed': '06/08/2018',
#    'duns': ' ',
#    'title_iv_indicator': 5,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '4',
#    'newid': -2,
#    'year_deleted': 2018,
#    'url_school': ' ',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 3,
#    'postsec_public_active_title_iv': 9,
#    'inst_system_flag': -2,
#    'inst_system_name': '-2',
#    'reporting_method': -2,
#    'inst_category': -2,
#    'land_grant': 0,
#    'inst_size': -2,
#    'inst_alias': ' ',
#    'url_fin_aid': ' ',
#    'url_application': ' ',
#    'cbsa': 42820,
#    'cbsa_type': 2,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': -2,
#    'longitude': -87.01914,
#    'latitude': 32.425648,
#    'county_fips': 1047,
#    'congress_district_id': 107,
#    'cc_basic_2010': -2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': -2,
#    'url_netprice': ' ',
#    'comparison_group_custom': -2,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': 22,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 23,
#    'cc_instruc_undergrad_2018': 5,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 10,
#    'cc_enroll_2018': 2,
#    'cc_size_setting_2018': 8,
#    'cc_size_setting_2015': None,
#    'url_disability_services': ' '},
#   {'year': 2018,
#    'unitid': 101116,
#    'inst_name': 'South University-Montgomery',
#    'address': '5355 Vaughn Rd',
#    'state_abbr': 'AL',
#    'zip': '36116',
#    'phone_number': '3343958800',
#    'city': 'Montgomery',
#    'county_name': 'Montgomery County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 3,
#    'institution_level': 4,
#    'sector': 3,
#    'fips': 1,
#    'chief_admin_name': 'Victor Biebighauser',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630314610',
#    'urban_centric_locale': 12,
#    'opeid': '01303906',
#    'offering_highest_degree': 13,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '082151614',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.southuniversity.edu/montgomery#location=Montgomery,%20AL',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Education Management Corporation',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 1,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.southuniversity.edu/admissions/financial-aid',
#    'url_application': 'www.southuniversity.edu/admissions/admission-info/applying',
#    'cbsa': 33860,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 138,
#    'longitude': -86.21649,
#    'latitude': 32.342686,
#    'county_fips': 1101,
#    'congress_district_id': 102,
#    'cc_basic_2010': 23,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www.southuniversity.edu/montgomery/net-price-calculator',
#    'comparison_group_custom': 1,
#    'url_veterans': 'www.southuniversity.edu/Admissions/Military/military-faqs',
#    'url_athletes': ' ',
#    'cc_basic_2015': 22,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 20,
#    'cc_instruc_undergrad_2018': 17,
#    'cc_instruc_grad_2018': 8,
#    'cc_undergrad_2018': 7,
#    'cc_enroll_2018': 3,
#    'cc_size_setting_2018': 6,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'content.edmc.edu/assets/documents/su/disability-services-su.pdf'},
#   {'year': 2018,
#    'unitid': 101143,
#    'inst_name': 'Enterprise State Community College',
#    'address': '600 Plaza Drive',
#    'state_abbr': 'AL',
#    'zip': '36330-1300',
#    'phone_number': '3343472623',
#    'city': 'Enterprise',
#    'county_name': 'Coffee County',
#    'offering_highest_level': 3,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 1,
#    'chief_admin_name': 'Matthew Rodgers',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630504851',
#    'urban_centric_locale': 32,
#    'opeid': '00101500',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '091407742',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.escc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Alabama Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': 'Enterprise-Ozark Community College  |Enterprise State Junior College',
#    'url_fin_aid': 'www.escc.edu/students/financial-aid-students/',
#    'url_application': 'https://grace.escc.edu/cgi-bin/admonline.mbr/login',
#    'cbsa': 21460,
#    'cbsa_type': 2,
#    'csa': 222,
#    'necta': -2,
#    'comparison_group': 85,
#    'longitude': -85.83695,
#    'latitude': 31.297497,
#    'county_fips': 1031,
#    'congress_district_id': 102,
#    'cc_basic_2010': 2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'https://www.escc.edu/netprice/npcalc.htm',
#    'comparison_group_custom': 0,
#    'url_veterans': 'https://www.escc.edu/students/financial-aid-students/',
#    'url_athletes': 'www.escc.edu/consumer-information/',
#    'cc_basic_2015': 8,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 5,
#    'cc_instruc_undergrad_2018': 3,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.escc.edu'},
#   {'year': 2018,
#    'unitid': 101161,
#    'inst_name': 'Coastal Alabama Community College',
#    'address': '1900 U S Highway 31 South',
#    'state_abbr': 'AL',
#    'zip': '36507-2698',
#    'phone_number': '2515802100',
#    'city': 'Bay Minette',
#    'county_name': 'Baldwin County',
#    'offering_highest_level': 3,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 1,
#    'chief_admin_name': 'Gary Branch',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630501805',
#    'urban_centric_locale': 32,
#    'opeid': '00106000',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '034267638',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.coastalalabama.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Alabama Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 3,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.coastalalabama.edu',
#    'url_application': 'www.coastalalabama.edu',
#    'cbsa': 19300,
#    'cbsa_type': 1,
#    'csa': 380,
#    'necta': -2,
#    'comparison_group': 83,
#    'longitude': -87.77819,
#    'latitude': 30.851343,
#    'county_fips': 1003,
#    'congress_district_id': 101,
#    'cc_basic_2010': 5,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www.coastalalabama.edu',
#    'comparison_group_custom': 1,
#    'url_veterans': 'www.coastalalabama.edu',
#    'url_athletes': 'www.coastalalabama.edu',
#    'cc_basic_2015': 1,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 5,
#    'cc_instruc_undergrad_2018': 2,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 4,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.coastalalabama.edu'},
#   {'year': 2018,
#    'unitid': 101189,
#    'inst_name': 'Faulkner University',
#    'address': '5345 Atlanta Hwy',
#    'state_abbr': 'AL',
#    'zip': '36109-3390',
#    'phone_number': '3342725820',
#    'city': 'Montgomery',
#    'county_name': 'Montgomery County',
#    'offering_highest_level': 9,
#    'region': 5,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 1,
#    'chief_admin_name': 'Michael D. Williams',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630329409',
#    'urban_centric_locale': 12,
#    'opeid': '00100300',
#    'offering_highest_degree': 11,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '079109500',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.faulkner.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': 'Faulkner',
#    'url_fin_aid': 'www.faulkner.edu/undergrad/tuition-financial-aid/',
#    'url_application': 'applynow.myfaulkner.org/inquiryform',
#    'cbsa': 33860,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 129,
#    'longitude': -86.21641,
#    'latitude': 32.384182,
#    'county_fips': 1101,
#    'congress_district_id': 102,
#    'cc_basic_2010': 22,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 32,
#    'url_netprice': 'www.faulkner.edu/net-price-calculator-form/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.faulkner.edu/graduate/military-and-veterans-services-2/',
#    'url_athletes': 'https://www.faulkner.edu/undergrad/tuition-financial-aid/financial-aid-policies/student-rights-and-responsibilities/',
#    'cc_basic_2015': 20,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 19,
#    'cc_instruc_undergrad_2018': 19,
#    'cc_instruc_grad_2018': 13,
#    'cc_undergrad_2018': 7,
#    'cc_enroll_2018': 4,
#    'cc_size_setting_2018': 10,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.faulkner.edu/undergrad/student-life/living-on-campus/student-services/center-for-disability-services/'},
#   {'year': 2018,
#    'unitid': 101240,
#    'inst_name': 'Gadsden State Community College',
#    'address': '1001 George Wallace Dr',
#    'state_abbr': 'AL',
#    'zip': '35903',
#    'phone_number': '2565498200',
#    'city': 'Gadsden',
#    'county_name': 'Etowah County',
#    'offering_highest_level': 3,
#    'region': 5,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 1,
#    'chief_admin_name': 'Dr. Martha G. Lavender',
#    'chief_admin_title': 'President',
#    'hbcu': 1,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '630501425',
#    'urban_centric_locale': 13,
#    'opeid': '00101700',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '830976767',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.gadsdenstate.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Alabama Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': 'GSCC | Gadsden State | Gadsden Community College',
#    'url_fin_aid': 'www.gadsdenstate.edu/financial_aid/home',
#    'url_application': 'https://ssb.gadsdenstate.edu/PROD/bwskalog.P_DispLoginNon',
#    'cbsa': 23460,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 90,
#    'longitude': -85.99144,
#    'latitude': 33.994,
#    'county_fips': 1055,
#    'congress_district_id': 104,
#    'cc_basic_2010': 3,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www.gadsdenstate.edu/net-price-calculator',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.gadsdenstate.edu/financial_aid/veterans-education-benefits',
#    'url_athletes': 'www.gadsdenstate.edu/sites/default/files/u23/Athletics%20Student%20Right%20to%20Know%202017.pdf',
#    'cc_basic_2015': 8,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 7,
#    'cc_instruc_undergrad_2018': 3,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 3,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.gadsdenstate.edu/ada/home'},
#   {'year': 2018,
#    'unitid': 101277,
#    'inst_name': 'New Beginning College of Cosmetology',
#    'address': '421 Martling Road',
#    'state_abbr': 'AL',
#    'zip': '35951',
#    'phone_number': '2568786430',
#    'city': 'Albertville',
#    'county_name': 'Marshall County',
#    'offering_highest_level': 2,
#    'region': 5,
#    'inst_control': 3,
#    'institution_level': 1,
#    'sector': 9,
#    'fips': 1,
#    'chief_admin_name': 'Amanda Baugh',
#    'chief_admin_title': 'DIRECTOR',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '202711032',
#    'urban_centric_locale': 32,
#    'opeid': '04187200',
#    'offering_highest_degree': 0,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '004452546',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.nbccosmetology.com',
#    'degree_granting': 0,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 2,
#    'inst_category': 6,
#    'land_grant': 0,
#    'inst_size': 1,
#    'inst_alias': ' ',
#    'url_fin_aid': ' ',
#    'url_application': ' ',
#    'cbsa': 10700,
#    'cbsa_type': 2,
#    'csa': 290,
#    'necta': -2,
#    'comparison_group': 35,
#    'longitude': -86.19693,
#    'latitude': 34.27871,
# ...
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'illinoisstate.edu/',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 2,
#    'land_grant': 0,
#    'inst_size': 5,
#    'inst_alias': ' ',
#    'url_fin_aid': 'financialaid.illinoisstate.edu/',
#    'url_application': 'www.admissions.illinoisstate.edu/apply',
#    'cbsa': 14010,
#    'cbsa_type': 1,
#    'csa': 145,
#    'necta': -2,
#    'comparison_group': 107,
#    'longitude': -88.99006,
#    'latitude': 40.509403,
#    'county_fips': 17113,
#    'congress_district_id': 1713,
#    'cc_basic_2010': 17,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 16,
#    'url_netprice': 'financialaid.illinoisstate.edu/prospective/estimator',
#    'comparison_group_custom': 1,
#    'url_veterans': 'veterans.illinoisstate.edu/',
#    'url_athletes': 'www.goredbirds.com/',
#    'cc_basic_2015': 16,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 16,
#    'cc_instruc_undergrad_2018': 16,
#    'cc_instruc_grad_2018': 18,
#    'cc_undergrad_2018': 13,
#    'cc_enroll_2018': 3,
#    'cc_size_setting_2018': 16,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.studentaccess.illinoisstate.edu/'},
#   {'year': 2018,
#    'unitid': 145831,
#    'inst_name': 'Illinois Valley Community College',
#    'address': '815 N Orlando Smith Road',
#    'state_abbr': 'IL',
#    'zip': '61348-9692',
#    'phone_number': '8152242720',
#    'city': 'Oglesby',
#    'county_name': 'LaSalle County',
#    'offering_highest_level': 3,
#    'region': 3,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 17,
#    'chief_admin_name': 'Dr. Jerry Corcoran',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '362614257',
#    'urban_centric_locale': 41,
#    'opeid': '00170500',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '076886654',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'https://www.ivcc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': 'IVCC',
#    'url_fin_aid': 'https://www.ivcc.edu/financialaid/',
#    'url_application': 'https://www.ivcc.edu/admissions.aspx?id=1940',
#    'cbsa': 36860,
#    'cbsa_type': 2,
#    'csa': 176,
#    'necta': -2,
#    'comparison_group': 99,
#    'longitude': -89.10088,
#    'latitude': 41.30744,
#    'county_fips': 17099,
#    'congress_district_id': 1716,
#    'cc_basic_2010': 3,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'https://www.ivcc.edu/financialaid.aspx?id=19328',
#    'comparison_group_custom': 1,
#    'url_veterans': 'https://www.ivcc.edu/admissions.aspx?id=11522',
#    'url_athletes': 'https://www.ivcc.edu/businessservices.aspx?id=5340',
#    'cc_basic_2015': 9,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 9,
#    'cc_instruc_undergrad_2018': 3,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 1,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.ivcc.edu/disability/'},
#   {'year': 2018,
#    'unitid': 145886,
#    'inst_name': 'Institute for Clinical Social Work',
#    'address': '401 South State Street, Suite 822',
#    'state_abbr': 'IL',
#    'zip': '60605-1229',
#    'phone_number': '3129354242',
#    'city': 'Chicago',
#    'county_name': 'Cook County',
#    'offering_highest_level': 9,
#    'region': 3,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 17,
#    'chief_admin_name': 'Allan Hoffman',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '363157451',
#    'urban_centric_locale': 11,
#    'opeid': '02573700',
#    'offering_highest_degree': 12,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '103608170',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 0,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.icsw.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 1,
#    'land_grant': 0,
#    'inst_size': 1,
#    'inst_alias': ' ',
#    'url_fin_aid': 'icsw.edu',
#    'url_application': 'icsw.edu',
#    'cbsa': 16980,
#    'cbsa_type': 1,
#    'csa': 176,
#    'necta': -2,
#    'comparison_group': 175,
#    'longitude': -87.62722,
#    'latitude': 41.876064,
#    'county_fips': 17031,
#    'congress_district_id': 1707,
#    'cc_basic_2010': 26,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 53,
#    'url_netprice': 'icsw.edu',
#    'comparison_group_custom': 0,
#    'url_veterans': 'icsw.edu/admissions/student-financial-services/',
#    'url_athletes': ' ',
#    'cc_basic_2015': 26,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 26,
#    'cc_instruc_undergrad_2018': 0,
#    'cc_instruc_grad_2018': 13,
#    'cc_undergrad_2018': 0,
#    'cc_enroll_2018': 7,
#    'cc_size_setting_2018': 18,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'icsw.edu/'},
#   {'year': 2018,
#    'unitid': 146205,
#    'inst_name': 'John A Logan College',
#    'address': '700 Logan College Road',
#    'state_abbr': 'IL',
#    'zip': '62918-2500',
#    'phone_number': '6189853741',
#    'city': 'Carterville',
#    'county_name': 'Williamson County',
#    'offering_highest_level': 3,
#    'region': 3,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 17,
#    'chief_admin_name': 'Dr. Ron House',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '370905504',
#    'urban_centric_locale': 23,
#    'opeid': '00807600',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '080000136',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'https://www.jalc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Illinois Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'https://www.jalc.edu/financial-aid',
#    'url_application': 'https://www.jalc.edu/contact-us',
#    'cbsa': 16060,
#    'cbsa_type': 1,
#    'csa': -2,
#    'necta': -2,
#    'comparison_group': 98,
#    'longitude': -89.09021,
#    'latitude': 37.74745,
#    'county_fips': 17199,
#    'congress_district_id': 1712,
#    'cc_basic_2010': 3,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'https://www.jalc.edu/net-price-calculator',
#    'comparison_group_custom': 0,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': 9,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 9,
#    'cc_instruc_undergrad_2018': 3,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 3,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.jalc.edu/student-success-center/disability-support-services'},
#   {'year': 2018,
#    'unitid': 146241,
#    'inst_name': 'The John Marshall Law School',
#    'address': '315 S Plymouth Ct',
#    'state_abbr': 'IL',
#    'zip': '60604',
#    'phone_number': '3124272737',
#    'city': 'Chicago',
#    'county_name': 'Cook County',
#    'offering_highest_level': 9,
#    'region': 3,
#    'inst_control': 2,
#    'institution_level': 4,
#    'sector': 2,
#    'fips': 17,
#    'chief_admin_name': 'Darby Dickerson',
#    'chief_admin_title': 'Dean',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': 0,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '362371220',
#    'urban_centric_locale': 11,
#    'opeid': '00169800',
#    'offering_highest_degree': 13,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '076892579',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 0,
#    'offering_grad': 1,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.jmls.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 0,
#    'inst_system_name': '-2',
#    'reporting_method': 1,
#    'inst_category': 1,
#    'land_grant': 0,
#    'inst_size': 1,
#    'inst_alias': 'JMLS',
#    'url_fin_aid': 'www.jmls.edu/students/financial-aid/',
#    'url_application': 'www.jmls.edu/admission/jd/',
#    'cbsa': 16980,
#    'cbsa_type': 1,
#    'csa': 176,
#    'necta': -2,
#    'comparison_group': 186,
#    'longitude': -87.62857,
#    'latitude': 41.877968,
#    'county_fips': 17031,
#    'congress_district_id': 1707,
#    'cc_basic_2010': 31,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 57,
#    'url_netprice': 'www.jmls.edu/admission/jd/tuition.php',
#    'comparison_group_custom': 0,
#    'url_veterans': 'www.jmls.edu/admission/veterans/',
#    'url_athletes': ' ',
#    'cc_basic_2015': 31,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 31,
#    'cc_instruc_undergrad_2018': 0,
#    'cc_instruc_grad_2018': 11,
#    'cc_undergrad_2018': 0,
#    'cc_enroll_2018': 7,
#    'cc_size_setting_2018': 18,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.jmls.edu/students/disability-policy.php'},
#   {'year': 2018,
#    'unitid': 146278,
#    'inst_name': 'John Wood Community College',
#    'address': '1301 S 48th Street',
#    'state_abbr': 'IL',
#    'zip': '62305-8736',
#    'phone_number': '2172246500',
#    'city': 'Quincy',
#    'county_name': 'Adams County',
#    'offering_highest_level': 3,
#    'region': 3,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 17,
#    'chief_admin_name': 'Mr. Michael Elbe',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '421027794',
#    'urban_centric_locale': 41,
#    'opeid': '01281300',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': ' ',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.jwcc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Illinois Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 2,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.jwcc.edu/financial-aid/',
#    'url_application': 'https://solar.jwcc.edu/prod/bwskalog.P_DispLoginNon',
#    'cbsa': 39500,
#    'cbsa_type': 2,
#    'csa': 448,
#    'necta': -2,
#    'comparison_group': 95,
#    'longitude': -91.33583,
#    'latitude': 39.913742,
#    'county_fips': 17001,
#    'congress_district_id': 1718,
#    'cc_basic_2010': 2,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www.jwcc.edu/financial-aid/net-price-calculator/',
#    'comparison_group_custom': 0,
#    'url_veterans': 'https://www.jwcc.edu/admissions/military/tuition-and-financial-assistance/veterans-benefits/',
#    'url_athletes': 'https://www.jwcc.edu/consumer-information/academic-information/graduation-transfer-rates/',
#    'cc_basic_2015': 6,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 8,
#    'cc_instruc_undergrad_2018': 2,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 2,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 2,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'https://www.jwcc.edu/support-services/disability-services/'},
#   {'year': 2018,
#    'unitid': 146296,
#    'inst_name': 'Joliet Junior College',
#    'address': '1215 Houbolt Rd',
#    'state_abbr': 'IL',
#    'zip': '60431-8938',
#    'phone_number': '8157299020',
#    'city': 'Joliet',
#    'county_name': 'Will County',
#    'offering_highest_level': 3,
#    'region': 3,
#    'inst_control': 1,
#    'institution_level': 2,
#    'sector': 4,
#    'fips': 17,
#    'chief_admin_name': 'Dr. Judy Mitchell',
#    'chief_admin_title': 'President',
#    'hbcu': 0,
#    'primarily_postsecondary': 1,
#    'hospital': -2,
#    'medical_degree': 0,
#    'tribal_college': 0,
#    'ein': '362638684',
#    'urban_centric_locale': 21,
#    'opeid': '00169900',
#    'offering_highest_degree': 40,
#    'currently_active_ipeds': 1,
#    'date_closed': '-2',
#    'duns': '069959013',
#    'title_iv_indicator': 1,
#    'offering_undergrad': 1,
#    'offering_grad': 0,
#    'inst_status': '1',
#    'newid': -2,
#    'year_deleted': -2,
#    'url_school': 'www.jjc.edu',
#    'degree_granting': 1,
#    'open_public': 1,
#    'postsec_public_active': 1,
#    'postsec_public_active_title_iv': 1,
#    'inst_system_flag': 1,
#    'inst_system_name': 'Illinois Community College System',
#    'reporting_method': 1,
#    'inst_category': 4,
#    'land_grant': 0,
#    'inst_size': 4,
#    'inst_alias': ' ',
#    'url_fin_aid': 'www.jjc.edu/getting-started/pay-school/financial-aid',
#    'url_application': 'https://legacy.jjc.edu/admissions/pages/apply-now.aspx',
#    'cbsa': 16980,
#    'cbsa_type': 1,
#    'csa': 176,
#    'necta': -2,
#    'comparison_group': 83,
#    'longitude': -88.180984,
#    'latitude': 41.500534,
#    'county_fips': 17197,
#    'congress_district_id': 1711,
#    'cc_basic_2010': 4,
#    'cc_instruc_undergrad_2010': None,
#    'cc_instruc_grad_2010': None,
#    'cc_undergrad_2010': None,
#    'cc_enroll_2010': None,
#    'cc_size_setting_2010': None,
#    'cc_basic_2000': 40,
#    'url_netprice': 'www3.jjc.edu/NetPriceCalc/npcalc.htm',
#    'comparison_group_custom': 1,
#    'url_veterans': ' ',
#    'url_athletes': ' ',
#    'cc_basic_2015': 6,
#    'cc_instruc_undergrad_2015': None,
#    'cc_instruc_grad_2015': None,
#    'cc_undergrad_2015': None,
#    'cc_enroll_2015': None,
#    'cc_basic_2018': 5,
#    'cc_instruc_undergrad_2018': 2,
#    'cc_instruc_grad_2018': 0,
#    'cc_undergrad_2018': 1,
#    'cc_enroll_2018': 1,
#    'cc_size_setting_2018': 4,
#    'cc_size_setting_2015': None,
#    'url_disability_services': 'www.jjc.edu/student-resources/disability-services'}]}

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#      count                                               next previous  \
# 0     6857  https://educationdata.urban.org/api/v1/college...     None
# 1     6857  https://educationdata.urban.org/api/v1/college...     None
# 2     6857  https://educationdata.urban.org/api/v1/college...     None
# 3     6857  https://educationdata.urban.org/api/v1/college...     None
# 4     6857  https://educationdata.urban.org/api/v1/college...     None
# ..     ...                                                ...      ...
# 995   6857  https://educationdata.urban.org/api/v1/college...     None
# 996   6857  https://educationdata.urban.org/api/v1/college...     None
# 997   6857  https://educationdata.urban.org/api/v1/college...     None
# 998   6857  https://educationdata.urban.org/api/v1/college...     None
# 999   6857  https://educationdata.urban.org/api/v1/college...     None
#
#                                                results
# 0    {'year': 2018, 'unitid': 100654, 'inst_name': ...
# 1    {'year': 2018, 'unitid': 100663, 'inst_name': ...
# 2    {'year': 2018, 'unitid': 100690, 'inst_name': ...
# 3    {'year': 2018, 'unitid': 100706, 'inst_name': ...
# 4    {'year': 2018, 'unitid': 100724, 'inst_name': ...
# ..                                                 ...
# 995  {'year': 2018, 'unitid': 145886, 'inst_name': ...
# 996  {'year': 2018, 'unitid': 146205, 'inst_name': ...
# 997  {'year': 2018, 'unitid': 146241, 'inst_name': ...
# 998  {'year': 2018, 'unitid': 146278, 'inst_name': ...
# 999  {'year': 2018, 'unitid': 146296, 'inst_name': ...
#
# [1000 rows x 4 columns]

# %%
dfdict = dict(df['results'])
df = pd.DataFrame.from_dict(dfdict, orient='index')

# %%
df
# Out:
#      year  unitid                            inst_name  \
# 0    2018  100654             Alabama A & M University
# 1    2018  100663  University of Alabama at Birmingham
# 2    2018  100690                   Amridge University
# 3    2018  100706  University of Alabama in Huntsville
# 4    2018  100724             Alabama State University
# ..    ...     ...                                  ...
# 995  2018  145886   Institute for Clinical Social Work
# 996  2018  146205                 John A Logan College
# 997  2018  146241         The John Marshall Law School
# 998  2018  146278          John Wood Community College
# 999  2018  146296                Joliet Junior College
#
#                                address state_abbr         zip    phone_number  \
# 0                 4900 Meridian Street         AL       35762      2563725000
# 1       Administration Bldg Suite 1070         AL  35294-0110      2059344011
# 2                       1200 Taylor Rd         AL  36117-3553  33438738777528
# 3                      301 Sparkman Dr         AL       35899      2568246120
# 4                 915 S Jackson Street         AL  36104-0271      3342294100
# ..                                 ...        ...         ...             ...
# 995  401 South State Street, Suite 822         IL  60605-1229      3129354242
# 996             700 Logan College Road         IL  62918-2500      6189853741
# 997                  315 S Plymouth Ct         IL       60604      3124272737
# 998                 1301 S 48th Street         IL  62305-8736      2172246500
# 999                    1215 Houbolt Rd         IL  60431-8938      8157299020
#
#             city        county_name  offering_highest_level  region  \
# 0         Normal     Madison County                       9       5
# 1     Birmingham   Jefferson County                       9       5
# 2     Montgomery  Montgomery County                       9       5
# 3     Huntsville     Madison County                       9       5
# 4     Montgomery  Montgomery County                       9       5
# ..           ...                ...                     ...     ...
# 995      Chicago        Cook County                       9       3
# 996  Carterville  Williamson County                       3       3
# 997      Chicago        Cook County                       9       3
# 998       Quincy       Adams County                       3       3
# 999       Joliet        Will County                       3       3
#
#      inst_control  institution_level  sector  fips        chief_admin_name  \
# 0               1                  4       1     1  Dr. Andrew Hugine, Jr.
# 1               1                  4       1     1            Ray L. Watts
# 2               2                  4       2     1        Michael C.Turner
# 3               1                  4       1     1    Robert A. Altenkirch
# 4               1                  4       1     1         Quinton T. Ross
# ..            ...                ...     ...   ...                     ...
# 995             2                  4       2    17           Allan Hoffman
# 996             1                  2       4    17           Dr. Ron House
# 997             2                  4       2    17         Darby Dickerson
# 998             1                  2       4    17        Mr. Michael Elbe
# 999             1                  2       4    17       Dr. Judy Mitchell
#
#     chief_admin_title  hbcu  primarily_postsecondary  hospital  \
# 0           President     1                        1         0
# 1           President     0                        1         1
# 2           President     0                        1         0
# 3           President     0                        1         0
# 4           President     1                        1         0
# ..                ...   ...                      ...       ...
# 995         President     0                        1         0
# 996         President     0                        1        -2
# 997              Dean     0                        1         0
# 998         President     0                        1        -2
# 999         President     0                        1        -2
#
#      medical_degree  tribal_college        ein  urban_centric_locale  \
# 0                 0               0  636001109                    12
# 1                 1               0  636005396                    12
# 2                 0               0  237034324                    12
# 3                 0               0  630520830                    12
# 4                 0               0  636001101                    12
# ..              ...             ...        ...                   ...
# 995               0               0  363157451                    11
# 996               0               0  370905504                    23
# 997               0               0  362371220                    11
# 998               0               0  421027794                    41
# 999               0               0  362638684                    21
#
#         opeid  offering_highest_degree  currently_active_ipeds date_closed  \
# 0    00100200                       12                       1          -2
# 1    00105200                       11                       1          -2
# 2    02503400                       12                       1          -2
# 3    00105500                       11                       1          -2
# 4    00100500                       11                       1          -2
# ..        ...                      ...                     ...         ...
# 995  02573700                       12                       1          -2
# 996  00807600                       40                       1          -2
# 997  00169800                       13                       1          -2
# 998  01281300                       40                       1          -2
# 999  00169900                       40                       1          -2
#
#           duns  title_iv_indicator  offering_undergrad  offering_grad  \
# 0    197216455                   1                   1              1
# 1    063690705                   1                   1              1
# 2    126307792                   1                   1              1
# 3    949687123                   1                   1              1
# 4    040672685                   1                   1              1
# ..         ...                 ...                 ...            ...
# 995  103608170                   1                   0              1
# 996  080000136                   1                   1              0
# 997  076892579                   1                   0              1
# 998                              1                   1              0
# 999  069959013                   1                   1              0
#
#     inst_status  newid  year_deleted                 url_school  \
# 0             1     -2            -2              www.aamu.edu/
# 1             1     -2            -2                www.uab.edu
# 2             1     -2            -2  www.amridgeuniversity.edu
# 3             1     -2            -2                www.uah.edu
# 4             1     -2            -2              www.alasu.edu
# ..          ...    ...           ...                        ...
# 995           1     -2            -2               www.icsw.edu
# 996           1     -2            -2       https://www.jalc.edu
# 997           1     -2            -2               www.jmls.edu
# 998           1     -2            -2               www.jwcc.edu
# 999           1     -2            -2                www.jjc.edu
#
#      degree_granting  open_public  postsec_public_active  \
# 0                  1            1                      1
# 1                  1            1                      1
# 2                  1            1                      1
# 3                  1            1                      1
# 4                  1            1                      1
# ..               ...          ...                    ...
# 995                1            1                      1
# 996                1            1                      1
# 997                1            1                      1
# 998                1            1                      1
# 999                1            1                      1
#
#      postsec_public_active_title_iv  inst_system_flag  \
# 0                                 1                 0
# 1                                 1                 1
# 2                                 1                 0
# 3                                 1                 1
# 4                                 1                 0
# ..                              ...               ...
# 995                               1                 0
# 996                               1                 1
# 997                               1                 0
# 998                               1                 1
# 999                               1                 1
#
#                       inst_system_name  reporting_method  inst_category  \
# 0                                   -2                 1              2
# 1     The University of Alabama System                 1              2
# 2                                   -2                 1              2
# 3     The University of Alabama System                 1              2
# 4                                   -2                 1              2
# ..                                 ...               ...            ...
# 995                                 -2                 1              1
# 996  Illinois Community College System                 1              4
# 997                                 -2                 1              1
# 998  Illinois Community College System                 1              4
# 999  Illinois Community College System                 1              4
#
#      land_grant  inst_size                                         inst_alias  \
# 0             1          3                                               AAMU
# 1             0          5
# 2             0          1  Southern Christian University |Regions University
# 3             0          3              UAH |University of Alabama Huntsville
# 4             0          2
# ..          ...        ...                                                ...
# 995           0          1
# 996           0          2
# 997           0          1                                               JMLS
# 998           0          2
# 999           0          4
#
#                                            url_fin_aid  \
# 0    www.aamu.edu/admissions/fincialaid/pages/defau...
# 1              www.uab.edu/students/paying-for-college
# 2              www.amridgeuniversity.edu/financialaid/
# 3                                      finaid.uah.edu/
# 4                    www.alasu.edu/cost-aid/index.aspx
# ..                                                 ...
# 995                                           icsw.edu
# 996                 https://www.jalc.edu/financial-aid
# 997               www.jmls.edu/students/financial-aid/
# 998                        www.jwcc.edu/financial-aid/
# 999  www.jjc.edu/getting-started/pay-school/financi...
#
#                                        url_application   cbsa  cbsa_type  csa  \
# 0    https://www.aamu.edu/Admissions/UndergraduateA...  26620          1  290
# 1        https://idm.uab.edu/myuab/login?from=ugadmapp  13820          1  142
# 2    https://www2.amridgeuniversity.edu/Amridge/Log...  33860          1   -2
# 3                                     register.uah.edu  26620          1  290
# 4    www.alasu.edu/admissions/undergrad-admissions/...  33860          1   -2
# ..                                                 ...    ...        ...  ...
# 995                                           icsw.edu  16980          1  176
# 996                    https://www.jalc.edu/contact-us  16060          1   -2
# 997                         www.jmls.edu/admission/jd/  16980          1  176
# 998  https://solar.jwcc.edu/prod/bwskalog.P_DispLog...  39500          2  448
# 999  https://legacy.jjc.edu/admissions/pages/apply-...  16980          1  176
#
#      necta  comparison_group  longitude   latitude  county_fips  \
# 0       -2               119 -86.568504  34.783367         1089
# 1       -2               105 -86.799350  33.505695         1073
# 2       -2               137 -86.174010  32.362610         1101
# 3       -2               109 -86.640450  34.724556         1089
# 4       -2               127 -86.295680  32.364320         1101
# ..     ...               ...        ...        ...          ...
# 995     -2               175 -87.627220  41.876064        17031
# 996     -2                98 -89.090210  37.747450        17199
# 997     -2               186 -87.628570  41.877968        17031
# 998     -2                95 -91.335830  39.913742        17001
# 999     -2                83 -88.180984  41.500534        17197
#
#      congress_district_id  cc_basic_2010 cc_instruc_undergrad_2010  \
# 0                     105             18                      None
# 1                     107             15                      None
# 2                     102             21                      None
# 3                     105             15                      None
# 4                     107             18                      None
# ..                    ...            ...                       ...
# 995                  1707             26                      None
# 996                  1712              3                      None
# 997                  1707             31                      None
# 998                  1718              2                      None
# 999                  1711              4                      None
#
#     cc_instruc_grad_2010 cc_undergrad_2010 cc_enroll_2010  \
# 0                   None              None           None
# 1                   None              None           None
# 2                   None              None           None
# 3                   None              None           None
# 4                   None              None           None
# ..                   ...               ...            ...
# 995                 None              None           None
# 996                 None              None           None
# 997                 None              None           None
# 998                 None              None           None
# 999                 None              None           None
#
#     cc_size_setting_2010  cc_basic_2000  \
# 0                   None             16
# 1                   None             15
# 2                   None             51
# 3                   None             16
# 4                   None             21
# ..                   ...            ...
# 995                 None             53
# 996                 None             40
# 997                 None             57
# 998                 None             40
# 999                 None             40
#
#                                           url_netprice  \
# 0    https://galileo.aamu.edu/NetPriceCalculator/np...
# 1             uab.studentaidcalculator.com/survey.aspx
# 2                     www2.amridgeuniversity.edu:9091/
# 3                                      finaid.uah.edu/
# 4    www.alasu.edu/cost-aid/forms/calculator/index....
# ..                                                 ...
# 995                                           icsw.edu
# 996          https://www.jalc.edu/net-price-calculator
# 997              www.jmls.edu/admission/jd/tuition.php
# 998   www.jwcc.edu/financial-aid/net-price-calculator/
# 999               www3.jjc.edu/NetPriceCalc/npcalc.htm
#
#      comparison_group_custom  \
# 0                          1
# 1                          1
# 2                          0
# 3                          0
# 4                          1
# ..                       ...
# 995                        0
# 996                        0
# 997                        0
# 998                        0
# 999                        1
#
#                                           url_veterans  \
# 0
# 1                        www.uab.edu/students/veterans
# 2       www.amridgeuniversity.edu/admissions/military/
# 3    www.uah.edu/admissions/graduate/financial-aid/...
# 4
# ..                                                 ...
# 995    icsw.edu/admissions/student-financial-services/
# 996
# 997                   www.jmls.edu/admission/veterans/
# 998  https://www.jwcc.edu/admissions/military/tuiti...
# 999
#
#                                           url_athletes  cc_basic_2015  \
# 0                                                                  18
# 1                       www.uab.edu/registrar/students             15
# 2                                                                  20
# 3                                     www.uah.edu/heoa             16
# 4              www.alasu.edu/search-results/index.aspx             19
# ..                                                 ...            ...
# 995                                                                26
# 996                                                                 9
# 997                                                                31
# 998  https://www.jwcc.edu/consumer-information/acad...              6
# 999                                                                 6
#
#     cc_instruc_undergrad_2015 cc_instruc_grad_2015 cc_undergrad_2015  \
# 0                        None                 None              None
# 1                        None                 None              None
# 2                        None                 None              None
# 3                        None                 None              None
# 4                        None                 None              None
# ..                        ...                  ...               ...
# 995                      None                 None              None
# 996                      None                 None              None
# 997                      None                 None              None
# 998                      None                 None              None
# 999                      None                 None              None
#
#     cc_enroll_2015  cc_basic_2018  cc_instruc_undergrad_2018  \
# 0             None             18                         16
# 1             None             15                         17
# 2             None             20                         19
# 3             None             16                         17
# 4             None             19                         13
# ..             ...            ...                        ...
# 995           None             26                          0
# 996           None              9                          3
# 997           None             31                          0
# 998           None              8                          2
# 999           None              5                          2
#
#      cc_instruc_grad_2018  cc_undergrad_2018  cc_enroll_2018  \
# 0                      17                 10               4
# 1                      17                  9               5
# 2                      18                  5               5
# 3                      17                 15               4
# 4                      13                 10               3
# ..                    ...                ...             ...
# 995                    13                  0               7
# 996                     0                  2               1
# 997                    11                  0               7
# 998                     0                  2               1
# 999                     0                  1               1
#
#      cc_size_setting_2018 cc_size_setting_2015  \
# 0                      14                 None
# 1                      15                 None
# 2                       6                 None
# 3                      12                 None
# 4                      14                 None
# ..                    ...                  ...
# 995                    18                 None
# 996                     3                 None
# 997                    18                 None
# 998                     2                 None
# 999                     4                 None
#
#                                url_disability_services
# 0    www.aamu.edu/administrativeoffices/VADS/Pages/...
# 1                     www.uab.edu/students/disability/
# 2    www.amridgeuniversity.edu/pdf/Amridge%20Univer...
# 3    www.uah.edu/health-and-wellness/disability-sup...
# 4    www.alasu.edu/about-asu/the-campus/disability-...
# ..                                                 ...
# 995                                          icsw.edu/
# 996  https://www.jalc.edu/student-success-center/di...
# 997  https://www.jmls.edu/students/disability-polic...
# 998  https://www.jwcc.edu/support-services/disabili...
# 999  www.jjc.edu/student-resources/disability-services
#
# [1000 rows x 82 columns]
