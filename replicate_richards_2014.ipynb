# %% [markdown]
# Identify data and document sources for the following variables at the most detailed geography:
#
# - school capacity
# - race by age by unit (unit is block, block group, tract)
# - actual school catchment (boundaries)

# %% [markdown]
# # School capactiy (enrollment)

# %% [markdown]
# the CCD provides [data for the 2018-2019 school year](https://nces.ed.gov/ccd/files.asp#Fiscal:2,LevelId:7,SchoolYearId:33,Page:1) containing the count of students in a school broken down by **grade, race, and sex** for 2018-2019 ([direct download link](https://nces.ed.gov/ccd/data/zip/ccd_sch_052_1819_l_1a_091019.zip)). These counts can be summed to get the total enrollment in a school. The schools are identified by their name, their LEAID and their NCESSCHID, which can all be used to match to other datasets.
#
# **Extract the csv to `data` and rename to `ccd_enrollment_1819`**

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_column', 200)

# %%
df = pd.read_csv("data/ccd_enrollment_1819.csv")
# over 2GB, be sure to gitignore this out

# %%
df.columns
# Out:
# Index(['SCHOOL_YEAR', 'FIPST', 'STATENAME', 'ST', 'SCH_NAME',
#        'STATE_AGENCY_NO', 'UNION', 'ST_LEAID', 'LEAID', 'ST_SCHID', 'NCESSCH',
#        'SCHID', 'GRADE', 'RACE_ETHNICITY', 'SEX', 'STUDENT_COUNT',
#        'TOTAL_INDICATOR', 'DMS_FLAG'],
#       dtype='object')

# %%
df.shape
# almost 12 million
# Out:
# (11948167, 18)

# %%
df.head(25)
# Out:
#    SCHOOL_YEAR  FIPST STATENAME  ST                   SCH_NAME  \
# 0    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 1    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 2    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 3    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 4    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 5    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 6    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 7    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 8    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 9    2018-2019      1   ALABAMA  AL  Albertville Middle School
# 10   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 11   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 12   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 13   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 14   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 15   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 16   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 17   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 18   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 19   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 20   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 21   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 22   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 23   2018-2019      1   ALABAMA  AL  Albertville Middle School
# 24   2018-2019      1   ALABAMA  AL  Albertville Middle School
#
#     STATE_AGENCY_NO  UNION ST_LEAID   LEAID     ST_SCHID      NCESSCH   SCHID  \
# 0                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 1                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 2                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 3                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 4                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 5                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 6                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 7                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 8                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 9                 1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 10                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 11                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 12                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 13                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 14                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 15                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 16                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 17                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 18                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 19                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 20                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 21                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 22                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 23                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
# 24                1    NaN   AL-101  100005  AL-101-0010  10000500870  100870
#
#       GRADE                             RACE_ETHNICITY            SEX  \
# 0   Grade 7           American Indian or Alaska Native         Female
# 1   Grade 7           American Indian or Alaska Native           Male
# 2   Grade 7                                      Asian         Female
# 3   Grade 7                                      Asian           Male
# 4   Grade 7                  Black or African American         Female
# 5   Grade 7                  Black or African American           Male
# 6   Grade 7                            Hispanic/Latino         Female
# 7   Grade 7                            Hispanic/Latino           Male
# 8   Grade 7  Native Hawaiian or Other Pacific Islander         Female
# 9   Grade 7  Native Hawaiian or Other Pacific Islander           Male
# 10  Grade 7                              Not Specified  Not Specified
# 11  Grade 7                          Two or more races         Female
# 12  Grade 7                          Two or more races           Male
# 13  Grade 7                                      White         Female
# 14  Grade 7                                      White           Male
# 15  Grade 8           American Indian or Alaska Native         Female
# 16  Grade 8           American Indian or Alaska Native           Male
# 17  Grade 8                                      Asian         Female
# 18  Grade 8                                      Asian           Male
# 19  Grade 8                  Black or African American         Female
# 20  Grade 8                  Black or African American           Male
# 21  Grade 8                            Hispanic/Latino         Female
# 22  Grade 8                            Hispanic/Latino           Male
# 23  Grade 8  Native Hawaiian or Other Pacific Islander         Female
# 24  Grade 8  Native Hawaiian or Other Pacific Islander           Male
#
#     STUDENT_COUNT                                 TOTAL_INDICATOR  DMS_FLAG
# 0             0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 1             0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 2             1.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 3             0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 4             9.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 5             7.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 6           101.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 7           103.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 8             0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 9             0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 10            0.0  Category Set A - By Race/Ethnicity; Sex; Grade   Derived
# 11            6.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 12            4.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 13           76.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 14          104.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 15            0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 16            0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 17            0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 18            2.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 19           11.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 20            5.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 21           88.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 22          110.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 23            0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported
# 24            0.0  Category Set A - By Race/Ethnicity; Sex; Grade  Reported

# %%
df['TOTAL_INDICATOR'].unique()
# not sure if this matters
# Out:
# array(['Category Set A - By Race/Ethnicity; Sex; Grade',
#        'Derived - Education Unit Total minus Adult Education Count',
#        'Derived - Subtotal by Race/Ethnicity and Sex minus Adult Education Count',
#        'Education Unit Total', 'Subtotal 4 - By Grade'], dtype=object)

# %% [markdown]
# We want to squish all the categories of students down so that we have one row per school indicating total enrollment.

# %%
# test = df.groupby(by=df.columns, axis=1).sum()

# this operation should squish it down
# but the file is large, so executing 
# blue screened my computer!

# %% [markdown]
# ### Alternate source: Urban Institute

# %% [markdown]
# The enrollment data can also be obtained through the Urban Institute API, assuming we have geographic data of the schools indexed by the school's `LEAID`

# %% [markdown]
# This may prove more or less convinient/reliable. Urban has presumably processed data from the CCD, which could cause problems for merging. On the other hand it might be more convinient to pull/organize the data programatically through the API.

# %%
from json import loads
from urllib.request import urlopen

# %%
url = "https://educationdata.urban.org/api/v1/school-districts/ccd/enrollment/2018/grade-8/"

# %%
response = urlopen(url)
data = loads(response.read())
data = pd.DataFrame.from_dict(data)
dfdict = dict(data['results'])
data = pd.DataFrame.from_dict(dfdict, orient='index')
# clean this up later

# %%
data.head()
# Out:
#    year    leaid  fips  grade  race  sex  enrollment
# 0  2018  0100002     1      8    99   99         NaN
# 1  2018  0100005     1      8    99   99       403.0
# 2  2018  0100006     1      8    99   99       463.0
# 3  2018  0100007     1      8    99   99      1076.0
# 4  2018  0100008     1      8    99   99       900.0

# %% [markdown]
# # Catchment (attendance boundaries)

# %%
import geopandas as gpd

# %% [markdown]
# come courtesy of the [School Attendance Boundary Survey (SABS)](https://nces.ed.gov/programs/edge/SABS)

# %%
attbound = gpd.read_file("data/nces_att_bound/SABS_1516/SABS_1516.shp")
# 15-16 (not the same data year)

# %%
attbound.head()
# Out:
#   SrcName       ncessch                       schnam    leaid gslo gshi  \
# 0    None  010000500870        Ala Avenue Middle Sch  0100005   07   08
# 1    None  010000500871         Albertville High Sch  0100005   09   12
# 2    None  010000500879               Evans Elem Sch  0100005   05   06
# 3    None  010000500889         Albertville Elem Sch  0100005   03   04
# 4    None  010000501616  Big Spring Lake Kinderg Sch  0100005   KG   KG
#
#   defacto stAbbrev openEnroll     Shape_Leng    Shape_Area level MultiBdy  \
# 0       1       AL          0  146828.793028  1.012552e+08     2        0
# 1       1       AL          0  146828.793028  1.012552e+08     3        0
# 2       1       AL          0  146828.793028  1.012552e+08     2        0
# 3       1       AL          0  146828.793028  1.012552e+08     1        0
# 4       1       AL          0  146828.793028  1.012552e+08     1        0
#
#                                             geometry
# 0  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 1  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 2  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 3  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 4  MULTIPOLYGON (((-9601421.827 4062780.032, -960...

# %%
attbound.plot()
# Out:
# <AxesSubplot:>

# %%
attbound.shape
# Out:
# (75128, 14)

# %%
attbound.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# # School geolocation

# %% [markdown]
# NCES also publishes a Education Demographics and Geographic Estimates (EDGE) page, which contains a dataset with the addresses of schools as reported by the CCD as a shapefile. School year 18-19 is the most recent data year. [download location](https://nces.ed.gov/programs/edge/Geographic/SchoolLocations)

# %% [markdown]
# **Save the shapefile directory in `data/edge_geocode/Shapefile_SCH/` (gitignored).**

# %%
gdf = gpd.read_file("data/edge_geocode/Shapefile_SCH/EDGE_GEOCODE_PUBLICSCH_1819.shp")

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands.  British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.head()
# Albertville on top again
# Out:
#         NCESSCH    LEAID                                 NAME OPSTFIPS  \
# 0  010000500870  0100005            Albertville Middle School       01
# 1  010000500871  0100005              Albertville High School       01
# 2  010000500879  0100005              Evans Elementary School       01
# 3  010000500889  0100005        Albertville Elementary School       01
# 4  010000501616  0100005  Big Spring Lake Kindergarten School       01
#
#                 STREET         CITY STATE    ZIP STFIP   CNTY  \
# 0    600 E Alabama Ave  Albertville    AL  35950    01  01095
# 1     402 E McCord Ave  Albertville    AL  35950    01  01095
# 2   901 W McKinney Ave  Albertville    AL  35950    01  01095
# 3   145 West End Drive  Albertville    AL  35950    01  01095
# 4  257 Country Club Rd  Albertville    AL  35951    01  01095
#
#             NMCNTY LOCALE        LAT        LON   CBSA           NMCBSA  \
# 0  Marshall County     32  34.260194 -86.206174  10700  Albertville, AL
# 1  Marshall County     32  34.262226 -86.204884  10700  Albertville, AL
# 2  Marshall County     32  34.273318 -86.220144  10700  Albertville, AL
# 3  Marshall County     32  34.252700 -86.221806  10700  Albertville, AL
# 4  Marshall County     32  34.289849 -86.193289  10700  Albertville, AL
#
#   CBSATYPE  CSA                               NMCSA NECTA NMNECTA    CD  \
# 0        2  290  Huntsville-Decatur-Albertville, AL     N       N  0104
# 1        2  290  Huntsville-Decatur-Albertville, AL     N       N  0104
# 2        2  290  Huntsville-Decatur-Albertville, AL     N       N  0104
# 3        2  290  Huntsville-Decatur-Albertville, AL     N       N  0104
# 4        2  290  Huntsville-Decatur-Albertville, AL     N       N  0104
#
#     SLDL   SLDU SCHOOLYEAR                    geometry
# 0  01026  01009  2018-2019  POINT (-86.20617 34.26019)
# 1  01026  01009  2018-2019  POINT (-86.20488 34.26223)
# 2  01026  01009  2018-2019  POINT (-86.22014 34.27332)
# 3  01026  01009  2018-2019  POINT (-86.22181 34.25270)
# 4  01026  01009  2018-2019  POINT (-86.19329 34.28985)
