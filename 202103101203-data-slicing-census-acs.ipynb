# %% [markdown]
# # American Community Survey  2017-2013 [5-year]
#
# [ACS 2017-2013](https://www.census.gov/data/developers/data-sets/acs-5year/2017.html)
#
# [Census Data API User Guide](https://www.census.gov/content/dam/Census/data/developers/api-user-guide/api-guide.pdf)

# %%
import pandas as pd

# %%
from urllib.request import urlopen
from json import loads

# %%
# url = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_004E&for=block%20group:*&in=state:06%20county:*"

# for all counties in California
# B01001_004E = Total Male Estimates 5-9 years in California counties

# %%
directory = "https://api.census.gov/data/2017/acs/acs5.html"

# %% [markdown]
# ## Dataframe for Total Male Estimates 5 - 9 years
#
# B01001_004E = Estimate!!Total!!Male!!5 to 9 years

# %%
url4 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_004E&for=block%20group:*&in=state:06%20county:073"

# San Diego County = 073
# in url B01001_004E = Estimate!!Total!!Male!!5 to 9 years

response = urlopen(url)
data = loads(response.read())

data
# Out:
# {'count': 761,
#  'next': None,
#  'previous': None,
#  'results': [{'year': 2016,
#    'fips': 6,
#    'ncessch': '060210000091',
#    'school_id': '00091',
#    'school_name': 'Alpine Elementary',
#    'leaid': '0602100',
#    'street_mailing': '1850 Alpine Blvd.',
#    'city_mailing': 'Alpine',
#    'state_mailing': 'CA',
#    'zip_mailing': '91901',
#    'street_location': '1850 Alpine Blvd.',
#    'city_location': 'Alpine',
#    'state_location': 'CA',
#    'zip_location': '91901',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 602100,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 21205,
#    'puma': '7302',
#    'block_group': 3,
#    'longitude': -116.774237,
#    'latitude': 32.838093,
#    'geo_longitude': -116.77449,
#    'geo_latitude': 32.837513,
#    'geoid_block': '060730212053',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Alpine CDP',
#    'place_fips': 1192,
#    'geoid_place': '0601192',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060210000092',
#    'school_id': '00092',
#    'school_name': 'Joan MacQueen Middle',
#    'leaid': '0602100',
#    'street_mailing': '2001 Tavern Rd.',
#    'city_mailing': 'Alpine',
#    'state_mailing': 'CA',
#    'zip_mailing': '91901',
#    'street_location': '2001 Tavern Rd.',
#    'city_location': 'Alpine',
#    'state_location': 'CA',
#    'zip_location': '91901',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 602100,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 21205,
#    'puma': '7302',
#    'block_group': 2,
#    'longitude': -116.774327,
#    'latitude': 32.824465,
#    'geo_longitude': -116.7754,
#    'geo_latitude': 32.82456,
#    'geoid_block': '060730212052',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Alpine CDP',
#    'place_fips': 1192,
#    'geoid_place': '0601192',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060142600516',
#    'school_id': '00516',
#    'school_name': 'Bonsall Elementary',
#    'leaid': '0601426',
#    'street_mailing': '31555 Old River Rd.',
#    'city_mailing': 'Bonsall',
#    'state_mailing': 'CA',
#    'zip_mailing': '92003',
#    'street_location': '31555 Old River Rd.',
#    'city_location': 'Bonsall',
#    'state_location': 'CA',
#    'zip_location': '92003',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 601426,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 18803,
#    'puma': '7302',
#    'block_group': 3,
#    'longitude': -117.219221,
#    'latitude': 33.28717,
#    'geo_longitude': -117.22077,
#    'geo_latitude': 33.287067,
#    'geoid_block': '060730188033',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Bonsall CDP',
#    'place_fips': 7498,
#    'geoid_place': '0607498',
#    'class_code': 70,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '066',
#    'state_leg_district_lower': '06066',
#    'lower_chamber_name': 'Assembly District 66',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060570000517',
#    'school_id': '00517',
#    'school_name': 'Borrego Springs Elementary',
#    'leaid': '0605700',
#    'street_mailing': '1315 Palm Canyon Dr.',
#    'city_mailing': 'Borrego Springs',
#    'state_mailing': 'CA',
#    'zip_mailing': '92004',
#    'street_location': '1315 Palm Canyon Dr.',
#    'city_location': 'Borrego Springs',
#    'state_location': 'CA',
#    'zip_location': '92004',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 605700,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 21000,
#    'puma': '7302',
#    'block_group': 4,
#    'longitude': -116.3472,
#    'latitude': 33.256197,
#    'geo_longitude': -116.34686,
#    'geo_latitude': 33.256832,
#    'geoid_block': '060730210004',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Borrego Springs CDP',
#    'place_fips': 7596,
#    'geoid_place': '0607596',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060570000518',
#    'school_id': '00518',
#    'school_name': 'Borrego Springs High',
#    'leaid': '0605700',
#    'street_mailing': '1315 Palm Canyon Dr.',
#    'city_mailing': 'Borrego Springs',
#    'state_mailing': 'CA',
#    'zip_mailing': '92004',
#    'street_location': '2281 Diegueno Rd.',
#    'city_location': 'Borrego Springs',
#    'state_location': 'CA',
#    'zip_location': '92004',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 605700,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 21000,
#    'puma': '7302',
#    'block_group': 2,
#    'longitude': -116.382811,
#    'latitude': 33.264957,
#    'geo_longitude': -116.38374,
#    'geo_latitude': 33.270626,
#    'geoid_block': '060730210002',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Borrego Springs CDP',
#    'place_fips': 7596,
#    'geoid_place': '0607596',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000603',
#    'school_id': '00603',
#    'school_name': 'Anza Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1005 S. Anza St.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '1005 S. Anza St.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15404,
#    'puma': '7313',
#    'block_group': 1,
#    'longitude': -116.947286,
#    'latitude': 32.781477,
#    'geo_longitude': -116.94816,
#    'geo_latitude': 32.78217,
#    'geoid_block': '060730154041',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000604',
#    'school_id': '00604',
#    'school_name': 'Avocado Elementary',
#    'leaid': '0606810',
#    'street_mailing': '3845 Avocado Sch Rd.',
#    'city_mailing': 'La Mesa',
#    'state_mailing': 'CA',
#    'zip_mailing': '91941',
#    'street_location': '3845 Avocado Sch Rd.',
#    'city_location': 'La Mesa',
#    'state_location': 'CA',
#    'zip_location': '91941',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 13606,
#    'puma': '7319',
#    'block_group': 1,
#    'longitude': -116.959841,
#    'latitude': 32.750641,
#    'geo_longitude': -116.96073,
#    'geo_latitude': 32.750286,
#    'geoid_block': '060730136061',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Casa de Oro-Mount Helix CDP',
#    'place_fips': 11691,
#    'geoid_place': '0611691',
#    'class_code': 71,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '078',
#    'state_leg_district_lower': '06078',
#    'lower_chamber_name': 'Assembly District 78',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000606',
#    'school_id': '00606',
#    'school_name': 'Bostonia Language Academy',
#    'leaid': '0606810',
#    'street_mailing': '1390 E. BRd.way',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '1390 E. BRd.way',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16401,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.931497,
#    'latitude': 32.808881,
#    'geo_longitude': -116.94443,
#    'geo_latitude': 32.80149,
#    'geoid_block': '060730164012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000607',
#    'school_id': '00607',
#    'school_name': 'Cajon Valley Middle',
#    'leaid': '0606810',
#    'street_mailing': '550 Park Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '550 Park Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16301,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.956072,
#    'latitude': 32.799683,
#    'geo_longitude': -116.95554,
#    'geo_latitude': 32.79841,
#    'geoid_block': '060730163012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000608',
#    'school_id': '00608',
#    'school_name': 'Chase Avenue Elementary',
#    'leaid': '0606810',
#    'street_mailing': '195 E. Chase Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '195 E. Chase Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15302,
#    'puma': '7313',
#    'block_group': 1,
#    'longitude': -116.960396,
#    'latitude': 32.779486,
#    'geo_longitude': -116.960045,
#    'geo_latitude': 32.780327,
#    'geoid_block': '060730153021',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000609',
#    'school_id': '00609',
#    'school_name': 'Crest Elementary',
#    'leaid': '0606810',
#    'street_mailing': '2000 Suncrest Blvd.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '2000 Suncrest Blvd.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15501,
#    'puma': '7307',
#    'block_group': 3,
#    'longitude': -116.866037,
#    'latitude': 32.805201,
#    'geo_longitude': -116.865395,
#    'geo_latitude': 32.80587,
#    'geoid_block': '060730155013',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Crest CDP',
#    'place_fips': 17106,
#    'geoid_place': '0617106',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000612',
#    'school_id': '00612',
#    'school_name': 'Emerald Middle',
#    'leaid': '0606810',
#    'street_mailing': '1221 S. Emerald Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '1221 S. Emerald Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15302,
#    'puma': '7313',
#    'block_group': 1,
#    'longitude': -116.967864,
#    'latitude': 32.778944,
#    'geo_longitude': -116.968704,
#    'geo_latitude': 32.778954,
#    'geoid_block': '060730153021',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000613',
#    'school_id': '00613',
#    'school_name': 'Flying Hills Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1251 Finch St.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '1251 Finch St.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16201,
#    'puma': '7313',
#    'block_group': 1,
#    'longitude': -116.981853,
#    'latitude': 32.812304,
#    'geo_longitude': -116.98242,
#    'geo_latitude': 32.81179,
#    'geoid_block': '060730162011',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000614',
#    'school_id': '00614',
#    'school_name': 'Fuerte Elementary',
#    'leaid': '0606810',
#    'street_mailing': '11625 Fuerte Dr.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '11625 Fuerte Dr.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 13605,
#    'puma': '7319',
#    'block_group': 2,
#    'longitude': -116.94652,
#    'latitude': 32.761526,
#    'geo_longitude': -116.9468,
#    'geo_latitude': 32.76217,
#    'geoid_block': '060730136052',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Rancho San Diego CDP',
#    'place_fips': 59550,
#    'geoid_place': '0659550',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000615',
#    'school_id': '00615',
#    'school_name': 'Greenfield Middle',
#    'leaid': '0606810',
#    'street_mailing': '1495 Greenfield Dr.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '1495 Greenfield Dr.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16401,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.928814,
#    'latitude': 32.810296,
#    'geo_longitude': -116.928825,
#    'geo_latitude': 32.81129,
#    'geoid_block': '060730164012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000616',
#    'school_id': '00616',
#    'school_name': 'W. D. Hall Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1376 Pepper Dr.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '1376 Pepper Dr.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16806,
#    'puma': '7307',
#    'block_group': 3,
#    'longitude': -116.930678,
#    'latitude': 32.821424,
#    'geo_longitude': -116.93103,
#    'geo_latitude': 32.820885,
#    'geoid_block': '060730168063',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Winter Gardens CDP',
#    'place_fips': 85992,
#    'geoid_place': '0685992',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000617',
#    'school_id': '00617',
#    'school_name': 'Johnson Elementary',
#    'leaid': '0606810',
#    'street_mailing': '500 W. Madison',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92020',
#    'street_location': '500 W. Madison',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92020',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16202,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.968927,
#    'latitude': 32.80119,
#    'geo_longitude': -116.96831,
#    'geo_latitude': 32.80045,
#    'geoid_block': '060730162022',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000618',
#    'school_id': '00618',
#    'school_name': 'Lexington Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1145 Redwood Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92019',
#    'street_location': '1145 Redwood Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92019',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15704,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.944118,
#    'latitude': 32.790236,
#    'geo_longitude': -116.94218,
#    'geo_latitude': 32.791233,
#    'geoid_block': '060730157042',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000619',
#    'school_id': '00619',
#    'school_name': 'Madison Avenue Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1615 E. Madison Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92019',
#    'street_location': '1615 E. Madison Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92019',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15602,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.920744,
#    'latitude': 32.799881,
#    'geo_longitude': -116.92198,
#    'geo_latitude': 32.800087,
#    'geoid_block': '060730156022',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000620',
#    'school_id': '00620',
#    'school_name': 'Magnolia Elementary',
#    'leaid': '0606810',
#    'street_mailing': '650 Greenfield Dr.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '650 Greenfield Dr.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16504,
#    'puma': '7313',
#    'block_group': 1,
#    'longitude': -116.954277,
#    'latitude': 32.81421,
#    'geo_longitude': -116.95425,
#    'geo_latitude': 32.813377,
#    'geoid_block': '060730165041',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000621',
#    'school_id': '00621',
#    'school_name': 'Meridian Elementary',
#    'leaid': '0606810',
#    'street_mailing': '651 S. Third St.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92019',
#    'street_location': '651 S. Third St.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92019',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15601,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.926199,
#    'latitude': 32.78854,
#    'geo_longitude': -116.926865,
#    'geo_latitude': 32.788845,
#    'geoid_block': '060730156012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000622',
#    'school_id': '00622',
#    'school_name': 'Montgomery Middle',
#    'leaid': '0606810',
#    'street_mailing': '1570 Melody Ln.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92019',
#    'street_location': '1570 Melody Ln.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92019',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15602,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.921008,
#    'latitude': 32.797185,
#    'geo_longitude': -116.92281,
#    'geo_latitude': 32.79654,
#    'geoid_block': '060730156022',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000623',
#    'school_id': '00623',
#    'school_name': 'Naranca Elementary',
#    'leaid': '0606810',
#    'street_mailing': '1030 Naranca Ave.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '1030 Naranca Ave.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16302,
#    'puma': '7313',
#    'block_group': 3,
#    'longitude': -116.947588,
#    'latitude': 32.804944,
#    'geo_longitude': -116.9464,
#    'geo_latitude': 32.803963,
#    'geoid_block': '060730163023',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060681000624',
#    'school_id': '00624',
#    'school_name': 'Rios Elementary',
#    'leaid': '0606810',
#    'street_mailing': '14314 Rios Canyon Rd.',
#    'city_mailing': 'El Cajon',
#    'state_mailing': 'CA',
#    'zip_mailing': '92021',
#    'street_location': '14314 Rios Canyon Rd.',
#    'city_location': 'El Cajon',
#    'state_location': 'CA',
#    'zip_location': '92021',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 15501,
#    'puma': '7307',
#    'block_group': 2,
#    'longitude': -116.872694,
#    'latitude': 32.840784,
#    'geo_longitude': -116.875786,
#    'geo_latitude': 32.840137,
#    'geoid_block': '060730155012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Harbison Canyon CDP',
#    'place_fips': 32044,
#    'geoid_place': '0632044',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060747000706',
#    'school_id': '00706',
#    'school_name': 'Ada W. Harris Elementary',
#    'leaid': '0607470',
#    'street_mailing': '1508 Windsor Rd.',
#    'city_mailing': 'Cardiff-by-the-Sea',
#    'state_mailing': 'CA',
#    'zip_mailing': '92007',
#    'street_location': '1508 Windsor Rd.',
#    'city_location': 'Cardiff-by-the-Sea',
#    'state_location': 'CA',
#    'zip_location': '92007',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607470,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17404,
#    'puma': '7309',
#    'block_group': 1,
#    'longitude': -117.274662,
#    'latitude': 33.031151,
#    'geo_longitude': -117.27347,
#    'geo_latitude': 33.031292,
#    'geoid_block': '060730174041',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Encinitas city',
#    'place_fips': 22678,
#    'geoid_place': '0622678',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060747000707',
#    'school_id': '00707',
#    'school_name': 'Cardiff Elementary',
#    'leaid': '0607470',
#    'street_mailing': '1888 Montgomery Ave.',
#    'city_mailing': 'Cardiff-by-the-Sea',
#    'state_mailing': 'CA',
#    'zip_mailing': '92007',
#    'street_location': '1888 Montgomery Ave.',
#    'city_location': 'Cardiff-by-the-Sea',
#    'state_location': 'CA',
#    'zip_location': '92007',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607470,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17401,
#    'puma': '7309',
#    'block_group': 1,
#    'longitude': -117.283818,
#    'latitude': 33.025119,
#    'geo_longitude': -117.28249,
#    'geo_latitude': 33.025173,
#    'geoid_block': '060730174011',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Encinitas city',
#    'place_fips': 22678,
#    'geoid_place': '0622678',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000708',
#    'school_id': '00708',
#    'school_name': 'Buena Vista Elementary',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '1330 Buena Vista Way',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17801,
#    'puma': '7304',
#    'block_group': 2,
#    'longitude': -117.342622,
#    'latitude': 33.169819,
#    'geo_longitude': -117.342514,
#    'geo_latitude': 33.16891,
#    'geoid_block': '060730178012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000709',
#    'school_id': '00709',
#    'school_name': 'Carlsbad High',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '3557 Monroe St.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17801,
#    'puma': '7304',
#    'block_group': 3,
#    'longitude': -117.329296,
#    'latitude': 33.163664,
#    'geo_longitude': -117.32739,
#    'geo_latitude': 33.16302,
#    'geoid_block': '060730178013',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000710',
#    'school_id': '00710',
#    'school_name': 'Jefferson Elementary',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '3743 Jefferson St.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17900,
#    'puma': '7304',
#    'block_group': 4,
#    'longitude': -117.339284,
#    'latitude': 33.152333,
#    'geo_longitude': -117.33924,
#    'geo_latitude': 33.15325,
#    'geoid_block': '060730179004',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000711',
#    'school_id': '00711',
#    'school_name': 'Kelly Elementary',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '4885 Kelly Dr.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17810,
#    'puma': '7304',
#    'block_group': 2,
#    'longitude': -117.312154,
#    'latitude': 33.147292,
#    'geo_longitude': -117.31099,
#    'geo_latitude': 33.14737,
#    'geoid_block': '060730178102',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000712',
#    'school_id': '00712',
#    'school_name': 'Carlsbad Village Academy',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '3557 Monroe St.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17900,
#    'puma': '7304',
#    'block_group': 4,
#    'longitude': -117.340704,
#    'latitude': 33.157068,
#    'geo_longitude': -117.32739,
#    'geo_latitude': 33.16302,
#    'geoid_block': '060730179004',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000713',
#    'school_id': '00713',
#    'school_name': 'Magnolia Elementary',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '1905 Magnolia Ave.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17809,
#    'puma': '7304',
#    'block_group': 1,
#    'longitude': -117.326516,
#    'latitude': 33.159452,
#    'geo_longitude': -117.32752,
#    'geo_latitude': 33.1597,
#    'geoid_block': '060730178091',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060750000715',
#    'school_id': '00715',
#    'school_name': 'Valley Middle',
#    'leaid': '0607500',
#    'street_mailing': '6225 El Camino Real',
#    'city_mailing': 'Carlsbad',
#    'state_mailing': 'CA',
#    'zip_mailing': '92009',
#    'street_location': '1645 Magnolia Ave.',
#    'city_location': 'Carlsbad',
#    'state_location': 'CA',
#    'zip_location': '92008',
#    'county_code': 6073,
#    'congress_district_id': 649,
#    'gleaid': 607500,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 17809,
#    'puma': '7304',
#    'block_group': 1,
#    'longitude': -117.329381,
#    'latitude': 33.157874,
#    'geo_longitude': -117.33136,
#    'geo_latitude': 33.157894,
#    'geoid_block': '060730178091',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'Carlsbad city',
#    'place_fips': 11194,
#    'geoid_place': '0611194',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060861000855',
#    'school_id': '00855',
#    'school_name': 'Allen (Ella B.) Elementary',
#    'leaid': '0608610',
#    'street_mailing': '4300 Allen Sch Rd.',
#    'city_mailing': 'Bonita',
#    'state_mailing': 'CA',
#    'zip_mailing': '91902',
#    'street_location': '4300 Allen Sch Rd.',
#    'city_location': 'Bonita',
#    'state_location': 'CA',
#    'zip_location': '91902',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 608610,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 13412,
#    'puma': '7320',
#    'block_group': 1,
#    'longitude': -117.033212,
#    'latitude': 32.656437,
#    'geo_longitude': -117.03354,
#    'geo_latitude': 32.656742,
#    'geoid_block': '060730134121',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Chula Vista city',
#    'place_fips': 13392,
#    'geoid_place': '0613392',
#    'class_code': 1,
#    'upper_chamber': '040',
#    'state_leg_district_upper': '06040',
#    'upper_chamber_name': 'State Senate District 40',
#    'lower_chamber': '078',
#    'state_leg_district_lower': '06078',
#    'lower_chamber_name': 'Assembly District 78',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060861000856',
#    'school_id': '00856',
#    'school_name': 'Castle Park Elementary',
#    'leaid': '0608610',
#    'street_mailing': '25 Emerson St.',
#    'city_mailing': 'Chula Vista',
#    'state_mailing': 'CA',
#    'zip_mailing': '91910',
#    'street_location': '25 Emerson St.',
#    'city_location': 'Chula Vista',
#    'state_location': 'CA',
#    'zip_location': '91910',
#    'county_code': 6073,
#    'congress_district_id': 651,
#    'gleaid': 608610,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 13102,
#    'puma': '7321',
#    'block_group': 2,
#    'longitude': -117.057098,
#    'latitude': 32.614249,
#    'geo_longitude': -117.05656,
#    'geo_latitude': 32.61521,
#    'geoid_block': '060730131022',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Chula Vista city',
#    'place_fips': 13392,
#    'geoid_place': '0613392',
#    'class_code': 1,
#    'upper_chamber': '040',
#    'state_leg_district_upper': '06040',
#    'upper_chamber_name': 'State Senate District 40',
#    'lower_chamber': '079',
#    'state_leg_district_lower': '06079',
#    'lower_chamber_name': 'Assembly District 79',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060861000857',
#    'school_id': '00857',
#    'school_name': 'Cook (Hazel Goes) Elementary',
#    'leaid': '0608610',
#    'street_mailing': '875 Cuyamaca Ave.',
#    'city_mailing': 'Chula Vista',
#    'state_mailing': 'CA',
#    'zip_mailing': '91911',
#    'street_location': '875 Cuyamaca Ave.',
#    'city_location': 'Chula Vista',
#    'state_location': 'CA',
#    'zip_location': '91911',
#    'county_code': 6073,
# ...
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 606810,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 16201,
#    'puma': '7313',
#    'block_group': 2,
#    'longitude': -116.980663,
#    'latitude': 32.817276,
#    'geo_longitude': -116.979706,
#    'geo_latitude': 32.816883,
#    'geoid_block': '060730162012',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'El Cajon city',
#    'place_fips': 21712,
#    'geoid_place': '0621712',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '063432013916',
#    'school_id': '13916',
#    'school_name': 'Jonas Salk Elementary',
#    'leaid': '0634320',
#    'street_mailing': '7825 Flanders Dr.',
#    'city_mailing': 'San Diego',
#    'state_mailing': 'CA',
#    'zip_mailing': '92126',
#    'street_location': '7825 Flanders Dr.',
#    'city_location': 'San Diego',
#    'state_location': 'CA',
#    'zip_location': '92126',
#    'county_code': 6073,
#    'congress_district_id': 652,
#    'gleaid': 634320,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 8350,
#    'puma': '7311',
#    'block_group': 2,
#    'longitude': -117.155612,
#    'latitude': 32.905384,
#    'geo_longitude': -117.15533,
#    'geo_latitude': 32.906765,
#    'geoid_block': '060730083502',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Diego city',
#    'place_fips': 66000,
#    'geoid_place': '0666000',
#    'class_code': 1,
#    'upper_chamber': '039',
#    'state_leg_district_upper': '06039',
#    'upper_chamber_name': 'State Senate District 39',
#    'lower_chamber': '075',
#    'state_leg_district_lower': '06075',
#    'lower_chamber_name': 'Assembly District 75',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '063432013917',
#    'school_id': '13917',
#    'school_name': 'Ingenuity Charter',
#    'leaid': '0634320',
#    'street_mailing': '6130 Skyline Dr.',
#    'city_mailing': 'San Diego',
#    'state_mailing': 'CA',
#    'zip_mailing': '92114',
#    'street_location': '6130 Skyline Dr.',
#    'city_location': 'San Diego',
#    'state_location': 'CA',
#    'zip_location': '92114',
#    'county_code': 6073,
#    'congress_district_id': 651,
#    'gleaid': 634320,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 3112,
#    'puma': '7318',
#    'block_group': 2,
#    'longitude': -117.064841,
#    'latitude': 32.70254,
#    'geo_longitude': -117.06477,
#    'geo_latitude': 32.701447,
#    'geoid_block': '060730031122',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Diego city',
#    'place_fips': 66000,
#    'geoid_place': '0666000',
#    'class_code': 1,
#    'upper_chamber': '039',
#    'state_leg_district_upper': '06039',
#    'upper_chamber_name': 'State Senate District 39',
#    'lower_chamber': '078',
#    'state_leg_district_lower': '06078',
#    'lower_chamber_name': 'Assembly District 78',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060004213918',
#    'school_id': '13918',
#    'school_name': 'California Pacific Charter Schools - San Diego',
#    'leaid': '0600042',
#    'street_mailing': '1200 Quail St. Ste 175',
#    'city_mailing': 'Newport Beach',
#    'state_mailing': 'CA',
#    'zip_mailing': '92660',
#    'street_location': '30951 Highway 79',
#    'city_location': 'Warner Springs',
#    'state_location': 'CA',
#    'zip_location': '92086',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 600042,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 20903,
#    'puma': '7302',
#    'block_group': 3,
#    'longitude': -116.643105,
#    'latitude': 33.274332,
#    'geo_longitude': -116.643005,
#    'geo_latitude': 33.275127,
#    'geoid_block': '060730209033',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': None,
#    'place_name': '',
#    'place_fips': None,
#    'geoid_place': '',
#    'class_code': None,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '066',
#    'state_leg_district_lower': '06066',
#    'lower_chamber_name': 'Assembly District 66',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '062025013954',
#    'school_id': '13954',
#    'school_name': 'La Mesa-Spring Valley Home Independent Study',
#    'leaid': '0620250',
#    'street_mailing': '4811 Glen St.',
#    'city_mailing': 'La Mesa',
#    'state_mailing': 'CA',
#    'zip_mailing': '91942',
#    'street_location': '4811 Glen St.',
#    'city_location': 'La Mesa',
#    'state_location': 'CA',
#    'zip_location': '91942',
#    'county_code': 6073,
#    'congress_district_id': 653,
#    'gleaid': 620250,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 14901,
#    'puma': '7314',
#    'block_group': 1,
#    'longitude': -117.008163,
#    'latitude': 32.76629,
#    'geo_longitude': -117.00882,
#    'geo_latitude': 32.76645,
#    'geoid_block': '060730149011',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'La Mesa city',
#    'place_fips': 40004,
#    'geoid_place': '0640004',
#    'class_code': 1,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060142613961',
#    'school_id': '13961',
#    'school_name': 'Pathways Academy Charter',
#    'leaid': '0601426',
#    'street_mailing': '1782 La Costa Meadows Dr. Ste. 102',
#    'city_mailing': 'San Marcos',
#    'state_mailing': 'CA',
#    'zip_mailing': '92078',
#    'street_location': '31505 Old River Rd.',
#    'city_location': 'Bonsall',
#    'state_location': 'CA',
#    'zip_location': '92003',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 601426,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 18803,
#    'puma': '7302',
#    'block_group': 3,
#    'longitude': -117.219281,
#    'latitude': 33.28701,
#    'geo_longitude': -117.22076,
#    'geo_latitude': 33.286945,
#    'geoid_block': '060730188033',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Bonsall CDP',
#    'place_fips': 7498,
#    'geoid_place': '0607498',
#    'class_code': 70,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '066',
#    'state_leg_district_lower': '06066',
#    'lower_chamber_name': 'Assembly District 66',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '063488013965',
#    'school_id': '13965',
#    'school_name': 'Double Peak',
#    'leaid': '0634880',
#    'street_mailing': '111 San Elijo Rd.',
#    'city_mailing': 'San Marcos',
#    'state_mailing': 'CA',
#    'zip_mailing': '92069',
#    'street_location': '111 San Elijo Rd.',
#    'city_location': 'San Marcos',
#    'state_location': 'CA',
#    'zip_location': '92069',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 634880,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 20027,
#    'puma': '7305',
#    'block_group': 1,
#    'longitude': -117.166058,
#    'latitude': 33.106094,
#    'geo_longitude': -117.173485,
#    'geo_latitude': 33.10682,
#    'geoid_block': '060730200271',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Marcos city',
#    'place_fips': 68196,
#    'geoid_place': '0668196',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060142914021',
#    'school_id': '14021',
#    'school_name': 'Thrive Public',
#    'leaid': '0601429',
#    'street_mailing': 'No Street Address',
#    'city_mailing': 'San Diego',
#    'state_mailing': 'CA',
#    'zip_mailing': '92115',
#    'street_location': '4260 54th St.',
#    'city_location': 'San Diego',
#    'state_location': 'CA',
#    'zip_location': '92115',
#    'county_code': 6073,
#    'congress_district_id': 651,
#    'gleaid': 634320,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 2708,
#    'puma': '7317',
#    'block_group': 1,
#    'longitude': -117.080001,
#    'latitude': 32.75406,
#    'geo_longitude': -117.079445,
#    'geo_latitude': 32.75405,
#    'geoid_block': '060730027081',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Diego city',
#    'place_fips': 66000,
#    'geoid_place': '0666000',
#    'class_code': 1,
#    'upper_chamber': '039',
#    'state_leg_district_upper': '06039',
#    'upper_chamber_name': 'State Senate District 39',
#    'lower_chamber': '078',
#    'state_leg_district_lower': '06078',
#    'lower_chamber_name': 'Assembly District 78',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060144114028',
#    'school_id': '14028',
#    'school_name': 'Audeo Charter II',
#    'leaid': '0601441',
#    'street_mailing': 'No Street Address',
#    'city_mailing': 'San Diego',
#    'state_mailing': 'CA',
#    'zip_mailing': '92121',
#    'street_location': '10170 Huennekens St.',
#    'city_location': 'San Diego',
#    'state_location': 'CA',
#    'zip_location': '92121',
#    'county_code': 6073,
#    'congress_district_id': 652,
#    'gleaid': 634320,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 8350,
#    'puma': '7311',
#    'block_group': 2,
#    'longitude': -117.184081,
#    'latitude': 32.90276,
#    'geo_longitude': -117.18392,
#    'geo_latitude': 32.902897,
#    'geoid_block': '060730083502',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Diego city',
#    'place_fips': 66000,
#    'geoid_place': '0666000',
#    'class_code': 1,
#    'upper_chamber': '039',
#    'state_leg_district_upper': '06039',
#    'upper_chamber_name': 'State Senate District 39',
#    'lower_chamber': '075',
#    'state_leg_district_lower': '06075',
#    'lower_chamber_name': 'Assembly District 75',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '061288014029',
#    'school_id': '14029',
#    'school_name': 'Epiphany Prep Charter',
#    'leaid': '0612880',
#    'street_mailing': '1065 Orangewood Dr.',
#    'city_mailing': 'Escondido',
#    'state_mailing': 'CA',
#    'zip_mailing': '92025',
#    'street_location': '725 N. Escondido Blvd.',
#    'city_location': 'Escondido',
#    'state_location': 'CA',
#    'zip_location': '82025',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 612880,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 20214,
#    'puma': '7306',
#    'block_group': 1,
#    'longitude': -117.090132,
#    'latitude': 33.127679,
#    'geo_longitude': -117.08891,
#    'geo_latitude': 33.127914,
#    'geoid_block': '060730202141',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Escondido city',
#    'place_fips': 22804,
#    'geoid_place': '0622804',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060570014037',
#    'school_id': '14037',
#    'school_name': 'San Diego Workforce Innovation High',
#    'leaid': '0605700',
#    'street_mailing': '2 Euclid Ave Ste. A',
#    'city_mailing': 'National City',
#    'state_mailing': 'CA',
#    'zip_mailing': '91950',
#    'street_location': '2281 Diegueno Rd.',
#    'city_location': 'Borrego Springs',
#    'state_location': 'CA',
#    'zip_location': '92004',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 605700,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 21000,
#    'puma': '7302',
#    'block_group': 2,
#    'longitude': -116.381531,
#    'latitude': 33.26548,
#    'geo_longitude': -116.38374,
#    'geo_latitude': 33.270626,
#    'geoid_block': '060730210002',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 0,
#    'place_name': 'Borrego Springs CDP',
#    'place_fips': 7596,
#    'geoid_place': '0607596',
#    'class_code': 70,
#    'upper_chamber': '036',
#    'state_leg_district_upper': '06036',
#    'upper_chamber_name': 'State Senate District 36',
#    'lower_chamber': '077',
#    'state_leg_district_lower': '06077',
#    'lower_chamber_name': 'Assembly District 77',
#    'lower_chamber_type': 7},
#   {'year': 2016,
#    'fips': 6,
#    'ncessch': '060000114062',
#    'school_id': '14062',
#    'school_name': 'Pathways Academy Charter School Adult Education',
#    'leaid': '0600001',
#    'street_mailing': '1782 La Costa Meadows Dr. Ste.',
#    'city_mailing': 'San Marcos',
#    'state_mailing': 'CA',
#    'zip_mailing': '92078',
#    'street_location': '1782 La Costa Meadows Dr. Ste.',
#    'city_location': 'San Marcos',
#    'state_location': 'CA',
#    'zip_location': '92078',
#    'county_code': 6073,
#    'congress_district_id': 650,
#    'gleaid': 634880,
#    'geocode_accuracy_detailed': -2,
#    'geocode_accuracy': -2,
#    'state_fips_geo': 6,
#    'county_fips_geo': 6073,
#    'tract': 20027,
#    'puma': '7305',
#    'block_group': 3,
#    'longitude': -117.218724,
#    'latitude': 33.104648,
#    'geo_longitude': -117.219246,
#    'geo_latitude': 33.104,
#    'geoid_block': '060730200273',
#    'census_region': 4,
#    'census_division': 9,
#    'csa': None,
#    'cbsa': 41740,
#    'cbsa_name': 'San Diego-Carlsbad-San Marcos, CA',
#    'cbsa_type': 1,
#    'cbsa_city': 1,
#    'place_name': 'San Marcos city',
#    'place_fips': 68196,
#    'geoid_place': '0668196',
#    'class_code': 1,
#    'upper_chamber': '038',
#    'state_leg_district_upper': '06038',
#    'upper_chamber_name': 'State Senate District 38',
#    'lower_chamber': '074',
#    'state_leg_district_lower': '06074',
#    'lower_chamber_name': 'Assembly District 74',
#    'lower_chamber_type': 7}]}

# %%
df4 = pd.DataFrame.from_dict(data)
df4
# Out:
#      count  next previous                                            results
# 0      761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06021000...
# 1      761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06021000...
# 2      761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06014260...
# 3      761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06057000...
# 4      761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06057000...
# ..     ...   ...      ...                                                ...
# 756    761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06014291...
# 757    761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06014411...
# 758    761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06128801...
# 759    761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06057001...
# 760    761  None     None  {'year': 2016, 'fips': 6, 'ncessch': '06000011...
#
# [761 rows x 4 columns]

# %%
df4.columns = df4.iloc[0]

#set first row as the column names in the dataframe

df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __repr__(self)
#     678         else:
#     679             width = None
# --> 680         self.to_string(
#     681             buf=buf,
#     682             max_rows=max_rows,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     912         encoding: Optional[str] = None,
#     913     ) -> Optional[str]:
# --> 914         return self.get_result(buf=buf, encoding=encoding)
#     915
#     916     def to_latex(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     519         """
#     520         with self.get_buffer(buf, encoding=encoding) as f:
# --> 521             self.write_result(buf=f)
#     522             if buf is None:
#     523                 return f.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#     821         else:
#     822
# --> 823             strcols = self._to_str_columns()
#     824             if self.line_width is None:  # no need to wrap around just print
#     825                 # the whole frame
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     745                 str_columns = [[label] for label in self.header]
#     746             else:
# --> 747                 str_columns = self._get_formatted_column_labels(frame)
#     748
#     749             if self.show_row_idx_names:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatted_column_labels(self, frame)
#    1018             dtypes = self.frame.dtypes
#    1019             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
# -> 1020             str_columns = [
#    1021                 [" " + x if not self._get_formatter(i) and need_leadsp[x] else x]
#    1022                 for i, (col, x) in enumerate(zip(columns, fmt_columns))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1019             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
#    1020             str_columns = [
# -> 1021                 [" " + x if not self._get_formatter(i) and need_leadsp[x] else x]
#    1022                 for i, (col, x) in enumerate(zip(columns, fmt_columns))
#    1023             ]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     472             if is_integer(i) and i not in self.columns:
#     473                 i = self.columns[i]
# --> 474             return self.formatters.get(i, None)
#     475
#     476     @contextmanager
#
# TypeError: unhashable type: 'dict'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980
#     981         Klass = NotebookFormatter if notebook else HTMLFormatter
# --> 982         return Klass(self, classes=classes, border=border).get_result(
#     983             buf=buf, encoding=encoding
#     984         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     519         """
#     520         with self.get_buffer(buf, encoding=encoding) as f:
# --> 521             self.write_result(buf=f)
#     522             if buf is None:
#     523                 return f.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     945     def _format_col(self, i: int) -> List[str]:
#     946         frame = self.tr_frame
# --> 947         formatter = self._get_formatter(i)
#     948         return format_array(
#     949             frame.iloc[:, i]._values,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     472             if is_integer(i) and i not in self.columns:
#     473                 i = self.columns[i]
# --> 474             return self.formatters.get(i, None)
#     475
#     476     @contextmanager
#
# TypeError: unhashable type: 'dict'

# %%
df4 = df4.iloc[1:]
df4

#delete row 0 after renaming columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __repr__(self)
#     678         else:
#     679             width = None
# --> 680         self.to_string(
#     681             buf=buf,
#     682             max_rows=max_rows,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     912         encoding: Optional[str] = None,
#     913     ) -> Optional[str]:
# --> 914         return self.get_result(buf=buf, encoding=encoding)
#     915
#     916     def to_latex(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     519         """
#     520         with self.get_buffer(buf, encoding=encoding) as f:
# --> 521             self.write_result(buf=f)
#     522             if buf is None:
#     523                 return f.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#     821         else:
#     822
# --> 823             strcols = self._to_str_columns()
#     824             if self.line_width is None:  # no need to wrap around just print
#     825                 # the whole frame
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     745                 str_columns = [[label] for label in self.header]
#     746             else:
# --> 747                 str_columns = self._get_formatted_column_labels(frame)
#     748
#     749             if self.show_row_idx_names:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatted_column_labels(self, frame)
#    1018             dtypes = self.frame.dtypes
#    1019             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
# -> 1020             str_columns = [
#    1021                 [" " + x if not self._get_formatter(i) and need_leadsp[x] else x]
#    1022                 for i, (col, x) in enumerate(zip(columns, fmt_columns))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1019             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
#    1020             str_columns = [
# -> 1021                 [" " + x if not self._get_formatter(i) and need_leadsp[x] else x]
#    1022                 for i, (col, x) in enumerate(zip(columns, fmt_columns))
#    1023             ]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     472             if is_integer(i) and i not in self.columns:
#     473                 i = self.columns[i]
# --> 474             return self.formatters.get(i, None)
#     475
#     476     @contextmanager
#
# TypeError: unhashable type: 'dict'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980
#     981         Klass = NotebookFormatter if notebook else HTMLFormatter
# --> 982         return Klass(self, classes=classes, border=border).get_result(
#     983             buf=buf, encoding=encoding
#     984         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     519         """
#     520         with self.get_buffer(buf, encoding=encoding) as f:
# --> 521             self.write_result(buf=f)
#     522             if buf is None:
#     523                 return f.getvalue()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     945     def _format_col(self, i: int) -> List[str]:
#     946         frame = self.tr_frame
# --> 947         formatter = self._get_formatter(i)
#     948         return format_array(
#     949             frame.iloc[:, i]._values,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     472             if is_integer(i) and i not in self.columns:
#     473                 i = self.columns[i]
# --> 474             return self.formatters.get(i, None)
#     475
#     476     @contextmanager
#
# TypeError: unhashable type: 'dict'

# %%
df4.NAME
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3295d3407f23> in <module>
# ----> 1 df4.NAME
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'NAME'

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Male Estimates 10 - 14 years
#
# B01001_005E = Estimate!!Total!!Male!!10 to 14 years

# %%
url5 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_005E&for=block%20group:*&in=state:06%20county:073"

# B01001_005E added to url 

response = urlopen(url5)
data = loads(response.read())

data

# %%
df5 = pd.DataFrame.from_dict(data)

df5.columns = df5.iloc[0]

#set first row as the column names in the dataframe

df5

# %%
df5 = df5.iloc[1:]
df5

#delete row 0 after renaming columns

# %%
df5.NAME

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Female Estimates 5 - 9 years
#
# B01001_028E = Estimate!!Total!!Female!!5 to 9 years

# %%
url28 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_028E&for=block%20group:*&in=state:06%20county:073"

# B01001_028E added to url

response = urlopen(url28)
data = loads(response.read())

data

# %%
df28 = pd.DataFrame.from_dict(data)

df28.columns = df28.iloc[0]

#set first row as the column names in the dataframe

df28

# %%
df28 = df28.iloc[1:]
df28

#delete row 0 after renaming columns

# %%
df28.NAME

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Female Estimates 10 - 14 years
#
# B01001_029E = Estimate!!Total!!Female!!10 to 14 years

# %%
url29 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_029E&for=block%20group:*&in=state:06%20county:073"

#B01001_029E added to url

response = urlopen(url29)
data = loads(response.read())

data

# %%
df29 = pd.DataFrame.from_dict(data)

df29.columns = df29.iloc[0]

#set first row as the column names in the dataframe

df29

# %%
df29 = df29.iloc[1:]
df29

#delete row 0 after renaming columns

# %%
df29.NAME

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# # Geographic Unit Variables from Urban

# %%
from urllib.request import urlopen
from json import loads
url = "https://educationdata.urban.org/api/v1/schools/nhgis/census-2010/2016/?state_mailing=CA&fips=06&county_fips_geo=06073"
response = urlopen(url)
data = loads(response.read())

# county_fips_geo = 06073 (San Diego)
# years available: 1986 - 2016 
# year = 2016

# %%
geo = pd.json_normalize(data, 'results')

geo

# %% [markdown]
# # Catchment (attendance boundaries)
#
# come courtesy of the [School Attendance Boundary Survey (SABS)](https://nces.ed.gov/programs/edge/SABS)

# %%
#pip install geopandas

# %%
import geopandas as gpd

# %%
attbound = gpd.read_file("data/nces_att_bound/SABS_1516/SABS_1516.shp")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: data/nces_att_bound/SABS_1516/SABS_1516.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-45-1b1b0c0a0d70> in <module>
# ----> 1 attbound = gpd.read_file("data/nces_att_bound/SABS_1516/SABS_1516.shp")
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     158
#     159     with fiona_env():
# --> 160         with reader(path_or_bytes, **kwargs) as features:
#     161
#     162             # In a future Fiona release the crs attribute of features will
#
# /opt/anaconda3/lib/python3.8/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# /opt/anaconda3/lib/python3.8/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     254
#     255         if mode in ('a', 'r'):
# --> 256             c = Collection(path, mode, driver=driver, encoding=encoding,
#     257                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     258         elif mode == 'w':
#
# /opt/anaconda3/lib/python3.8/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: data/nces_att_bound/SABS_1516/SABS_1516.shp: No such file or directory
