# %% [markdown]
# # American Community Survey  2017-2013 [5-year]
#
# [ACS 2017-2013](https://www.census.gov/data/developers/data-sets/acs-5year/2017.html)
#
# [Census Data API User Guide](https://www.census.gov/content/dam/Census/data/developers/api-user-guide/api-guide.pdf)

# %%
import pandas as pd

# %%
from urllib.request import urlopen
from json import loads

# %%
# url = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_004E&for=block%20group:*&in=state:06%20county:*"

# for all counties in California
# B01001_004E = Total Male Estimates 5-9 years in California counties

# %%
directory = "https://api.census.gov/data/2017/acs/acs5.html"

# %% [markdown]
# ## Dataframe for Total Male Estimates 5 - 9 years
#
# B01001_004E = Estimate!!Total!!Male!!5 to 9 years

# %%
url4 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_004E&for=block%20group:*&in=state:06%20county:073"

# San Diego County = 073
# in url B01001_004E = Estimate!!Total!!Male!!5 to 9 years

response = urlopen(url4)
data = loads(response.read())

data
# Out:
# [['NAME', 'B01001_004E', 'state', 'county', 'tract', 'block group'],
#  ['Block Group 2, Census Tract 178.08, San Diego County, California',
#   '82',
#   '06',
#   '073',
#   '017808',
#   '2'],
#  ['Block Group 4, Census Tract 178.08, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '017808',
#   '4'],
#  ['Block Group 3, Census Tract 178.08, San Diego County, California',
#   '49',
#   '06',
#   '073',
#   '017808',
#   '3'],
#  ['Block Group 1, Census Tract 178.08, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017808',
#   '1'],
#  ['Block Group 1, Census Tract 191.01, San Diego County, California',
#   '95',
#   '06',
#   '073',
#   '019101',
#   '1'],
#  ['Block Group 2, Census Tract 191.01, San Diego County, California',
#   '55',
#   '06',
#   '073',
#   '019101',
#   '2'],
#  ['Block Group 3, Census Tract 191.01, San Diego County, California',
#   '200',
#   '06',
#   '073',
#   '019101',
#   '3'],
#  ['Block Group 3, Census Tract 170.15, San Diego County, California',
#   '165',
#   '06',
#   '073',
#   '017015',
#   '3'],
#  ['Block Group 2, Census Tract 83.10, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008310',
#   '2'],
#  ['Block Group 3, Census Tract 83.10, San Diego County, California',
#   '86',
#   '06',
#   '073',
#   '008310',
#   '3'],
#  ['Block Group 1, Census Tract 83.29, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '008329',
#   '1'],
#  ['Block Group 1, Census Tract 83.40, San Diego County, California',
#   '135',
#   '06',
#   '073',
#   '008340',
#   '1'],
#  ['Block Group 2, Census Tract 83.40, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008340',
#   '2'],
#  ['Block Group 1, Census Tract 83.41, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '008341',
#   '1'],
#  ['Block Group 1, Census Tract 83.50, San Diego County, California',
#   '96',
#   '06',
#   '073',
#   '008350',
#   '1'],
#  ['Block Group 2, Census Tract 83.50, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '008350',
#   '2'],
#  ['Block Group 3, Census Tract 83.50, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '008350',
#   '3'],
#  ['Block Group 1, Census Tract 83.58, San Diego County, California',
#   '20',
#   '06',
#   '073',
#   '008358',
#   '1'],
#  ['Block Group 2, Census Tract 83.58, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008358',
#   '2'],
#  ['Block Group 3, Census Tract 83.58, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '008358',
#   '3'],
#  ['Block Group 4, Census Tract 83.58, San Diego County, California',
#   '96',
#   '06',
#   '073',
#   '008358',
#   '4'],
#  ['Block Group 3, Census Tract 86, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008600',
#   '3'],
#  ['Block Group 2, Census Tract 86, San Diego County, California',
#   '51',
#   '06',
#   '073',
#   '008600',
#   '2'],
#  ['Block Group 1, Census Tract 86, San Diego County, California',
#   '125',
#   '06',
#   '073',
#   '008600',
#   '1'],
#  ['Block Group 2, Census Tract 90, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009000',
#   '2'],
#  ['Block Group 1, Census Tract 90, San Diego County, California',
#   '89',
#   '06',
#   '073',
#   '009000',
#   '1'],
#  ['Block Group 2, Census Tract 91.02, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '009102',
#   '2'],
#  ['Block Group 1, Census Tract 91.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009102',
#   '1'],
#  ['Block Group 4, Census Tract 93.01, San Diego County, California',
#   '55',
#   '06',
#   '073',
#   '009301',
#   '4'],
#  ['Block Group 1, Census Tract 93.01, San Diego County, California',
#   '9',
#   '06',
#   '073',
#   '009301',
#   '1'],
#  ['Block Group 2, Census Tract 93.01, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '009301',
#   '2'],
#  ['Block Group 1, Census Tract 139.03, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '013903',
#   '1'],
#  ['Block Group 2, Census Tract 139.03, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '013903',
#   '2'],
#  ['Block Group 1, Census Tract 139.07, San Diego County, California',
#   '96',
#   '06',
#   '073',
#   '013907',
#   '1'],
#  ['Block Group 2, Census Tract 139.07, San Diego County, California',
#   '142',
#   '06',
#   '073',
#   '013907',
#   '2'],
#  ['Block Group 3, Census Tract 146.02, San Diego County, California',
#   '106',
#   '06',
#   '073',
#   '014602',
#   '3'],
#  ['Block Group 2, Census Tract 146.02, San Diego County, California',
#   '85',
#   '06',
#   '073',
#   '014602',
#   '2'],
#  ['Block Group 1, Census Tract 146.02, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '014602',
#   '1'],
#  ['Block Group 2, Census Tract 148.03, San Diego County, California',
#   '92',
#   '06',
#   '073',
#   '014803',
#   '2'],
#  ['Block Group 3, Census Tract 148.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '014803',
#   '3'],
#  ['Block Group 3, Census Tract 92.01, San Diego County, California',
#   '11',
#   '06',
#   '073',
#   '009201',
#   '3'],
#  ['Block Group 2, Census Tract 92.01, San Diego County, California',
#   '139',
#   '06',
#   '073',
#   '009201',
#   '2'],
#  ['Block Group 4, Census Tract 92.01, San Diego County, California',
#   '74',
#   '06',
#   '073',
#   '009201',
#   '4'],
#  ['Block Group 1, Census Tract 92.01, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '009201',
#   '1'],
#  ['Block Group 5, Census Tract 97.06, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '009706',
#   '5'],
#  ['Block Group 6, Census Tract 97.06, San Diego County, California',
#   '38',
#   '06',
#   '073',
#   '009706',
#   '6'],
#  ['Block Group 1, Census Tract 97.06, San Diego County, California',
#   '128',
#   '06',
#   '073',
#   '009706',
#   '1'],
#  ['Block Group 3, Census Tract 97.06, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '009706',
#   '3'],
#  ['Block Group 4, Census Tract 97.06, San Diego County, California',
#   '56',
#   '06',
#   '073',
#   '009706',
#   '4'],
#  ['Block Group 7, Census Tract 97.06, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009706',
#   '7'],
#  ['Block Group 2, Census Tract 97.06, San Diego County, California',
#   '59',
#   '06',
#   '073',
#   '009706',
#   '2'],
#  ['Block Group 2, Census Tract 100.10, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '010010',
#   '2'],
#  ['Block Group 3, Census Tract 100.10, San Diego County, California',
#   '58',
#   '06',
#   '073',
#   '010010',
#   '3'],
#  ['Block Group 1, Census Tract 100.10, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '010010',
#   '1'],
#  ['Block Group 2, Census Tract 101.04, San Diego County, California',
#   '108',
#   '06',
#   '073',
#   '010104',
#   '2'],
#  ['Block Group 1, Census Tract 101.04, San Diego County, California',
#   '11',
#   '06',
#   '073',
#   '010104',
#   '1'],
#  ['Block Group 1, Census Tract 101.06, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '010106',
#   '1'],
#  ['Block Group 3, Census Tract 101.06, San Diego County, California',
#   '69',
#   '06',
#   '073',
#   '010106',
#   '3'],
#  ['Block Group 2, Census Tract 101.06, San Diego County, California',
#   '125',
#   '06',
#   '073',
#   '010106',
#   '2'],
#  ['Block Group 4, Census Tract 103, San Diego County, California',
#   '10',
#   '06',
#   '073',
#   '010300',
#   '4'],
#  ['Block Group 2, Census Tract 103, San Diego County, California',
#   '100',
#   '06',
#   '073',
#   '010300',
#   '2'],
#  ['Block Group 1, Census Tract 103, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '010300',
#   '1'],
#  ['Block Group 3, Census Tract 168.07, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '016807',
#   '3'],
#  ['Block Group 4, Census Tract 168.07, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '016807',
#   '4'],
#  ['Block Group 1, Census Tract 168.07, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '016807',
#   '1'],
#  ['Block Group 1, Census Tract 170.20, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '017020',
#   '1'],
#  ['Block Group 2, Census Tract 170.20, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '017020',
#   '2'],
#  ['Block Group 1, Census Tract 175.01, San Diego County, California',
#   '7',
#   '06',
#   '073',
#   '017501',
#   '1'],
#  ['Block Group 2, Census Tract 175.01, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '017501',
#   '2'],
#  ['Block Group 3, Census Tract 175.01, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '017501',
#   '3'],
#  ['Block Group 2, Census Tract 97.03, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '009703',
#   '2'],
#  ['Block Group 3, Census Tract 97.03, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '009703',
#   '3'],
#  ['Block Group 1, Census Tract 97.03, San Diego County, California',
#   '53',
#   '06',
#   '073',
#   '009703',
#   '1'],
#  ['Block Group 1, Census Tract 83.11, San Diego County, California',
#   '9',
#   '06',
#   '073',
#   '008311',
#   '1'],
#  ['Block Group 2, Census Tract 136.06, San Diego County, California',
#   '5',
#   '06',
#   '073',
#   '013606',
#   '2'],
#  ['Block Group 3, Census Tract 136.06, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '013606',
#   '3'],
#  ['Block Group 1, Census Tract 136.06, San Diego County, California',
#   '30',
#   '06',
#   '073',
#   '013606',
#   '1'],
#  ['Block Group 1, Census Tract 138.02, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '013802',
#   '1'],
#  ['Block Group 2, Census Tract 139.05, San Diego County, California',
#   '22',
#   '06',
#   '073',
#   '013905',
#   '2'],
#  ['Block Group 3, Census Tract 139.05, San Diego County, California',
#   '9',
#   '06',
#   '073',
#   '013905',
#   '3'],
#  ['Block Group 1, Census Tract 139.05, San Diego County, California',
#   '59',
#   '06',
#   '073',
#   '013905',
#   '1'],
#  ['Block Group 3, Census Tract 142, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '014200',
#   '3'],
#  ['Block Group 1, Census Tract 142, San Diego County, California',
#   '88',
#   '06',
#   '073',
#   '014200',
#   '1'],
#  ['Block Group 2, Census Tract 142, San Diego County, California',
#   '65',
#   '06',
#   '073',
#   '014200',
#   '2'],
#  ['Block Group 4, Census Tract 142, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '014200',
#   '4'],
#  ['Block Group 1, Census Tract 143, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '014300',
#   '1'],
#  ['Block Group 2, Census Tract 143, San Diego County, California',
#   '102',
#   '06',
#   '073',
#   '014300',
#   '2'],
#  ['Block Group 4, Census Tract 152, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '015200',
#   '4'],
#  ['Block Group 1, Census Tract 152, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '015200',
#   '1'],
#  ['Block Group 3, Census Tract 152, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '015200',
#   '3'],
#  ['Block Group 2, Census Tract 152, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '015200',
#   '2'],
#  ['Block Group 2, Census Tract 153.01, San Diego County, California',
#   '57',
#   '06',
#   '073',
#   '015301',
#   '2'],
#  ['Block Group 1, Census Tract 33.03, San Diego County, California',
#   '162',
#   '06',
#   '073',
#   '003303',
#   '1'],
#  ['Block Group 2, Census Tract 33.03, San Diego County, California',
#   '96',
#   '06',
#   '073',
#   '003303',
#   '2'],
#  ['Block Group 3, Census Tract 39.02, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '003902',
#   '3'],
#  ['Block Group 2, Census Tract 39.02, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '003902',
#   '2'],
#  ['Block Group 3, Census Tract 174.01, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '017401',
#   '3'],
#  ['Block Group 3, Census Tract 132.06, San Diego County, California',
#   '55',
#   '06',
#   '073',
#   '013206',
#   '3'],
#  ['Block Group 2, Census Tract 132.06, San Diego County, California',
#   '20',
#   '06',
#   '073',
#   '013206',
#   '2'],
#  ['Block Group 1, Census Tract 132.06, San Diego County, California',
#   '116',
#   '06',
#   '073',
#   '013206',
#   '1'],
#  ['Block Group 1, Census Tract 134.19, San Diego County, California',
#   '334',
#   '06',
#   '073',
#   '013419',
#   '1'],
#  ['Block Group 2, Census Tract 134.19, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '013419',
#   '2'],
#  ['Block Group 1, Census Tract 154.06, San Diego County, California',
#   '72',
#   '06',
#   '073',
#   '015406',
#   '1'],
#  ['Block Group 1, Census Tract 174.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017403',
#   '1'],
#  ['Block Group 4, Census Tract 174.03, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '017403',
#   '4'],
#  ['Block Group 2, Census Tract 174.03, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '017403',
#   '2'],
#  ['Block Group 3, Census Tract 174.03, San Diego County, California',
#   '55',
#   '06',
#   '073',
#   '017403',
#   '3'],
#  ['Block Group 1, Census Tract 52, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '005200',
#   '1'],
#  ['Block Group 2, Census Tract 52, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '005200',
#   '2'],
#  ['Block Group 3, Census Tract 60, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '006000',
#   '3'],
#  ['Block Group 3, Census Tract 103, San Diego County, California',
#   '39',
#   '06',
#   '073',
#   '010300',
#   '3'],
#  ['Block Group 2, Census Tract 35.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '003501',
#   '2'],
#  ['Block Group 2, Census Tract 196.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019601',
#   '2'],
#  ['Block Group 4, Census Tract 196.01, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '019601',
#   '4'],
#  ['Block Group 1, Census Tract 82, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008200',
#   '1'],
#  ['Block Group 2, Census Tract 82, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008200',
#   '2'],
#  ['Block Group 3, Census Tract 82, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '008200',
#   '3'],
#  ['Block Group 3, Census Tract 83.01, San Diego County, California',
#   '49',
#   '06',
#   '073',
#   '008301',
#   '3'],
#  ['Block Group 1, Census Tract 83.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008301',
#   '1'],
#  ['Block Group 2, Census Tract 83.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008301',
#   '2'],
#  ['Block Group 4, Census Tract 39.02, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '003902',
#   '4'],
#  ['Block Group 1, Census Tract 39.02, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '003902',
#   '1'],
#  ['Block Group 2, Census Tract 53, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005300',
#   '2'],
#  ['Block Group 4, Census Tract 53, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005300',
#   '4'],
#  ['Block Group 1, Census Tract 53, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005300',
#   '1'],
#  ['Block Group 3, Census Tract 53, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005300',
#   '3'],
#  ['Block Group 1, Census Tract 54, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005400',
#   '1'],
#  ['Block Group 2, Census Tract 54, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005400',
#   '2'],
#  ['Block Group 3, Census Tract 54, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005400',
#   '3'],
#  ['Block Group 1, Census Tract 57, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005700',
#   '1'],
#  ['Block Group 1, Census Tract 83.05, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008305',
#   '1'],
#  ['Block Group 2, Census Tract 83.07, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '008307',
#   '2'],
#  ['Block Group 3, Census Tract 83.07, San Diego County, California',
#   '4',
#   '06',
#   '073',
#   '008307',
#   '3'],
#  ['Block Group 1, Census Tract 83.07, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '008307',
#   '1'],
#  ['Block Group 1, Census Tract 83.24, San Diego County, California',
#   '181',
#   '06',
#   '073',
#   '008324',
#   '1'],
#  ['Block Group 3, Census Tract 83.24, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '008324',
#   '3'],
#  ['Block Group 2, Census Tract 83.24, San Diego County, California',
#   '175',
#   '06',
#   '073',
#   '008324',
#   '2'],
#  ['Block Group 4, Census Tract 83.24, San Diego County, California',
#   '44',
#   '06',
#   '073',
#   '008324',
#   '4'],
#  ['Block Group 1, Census Tract 83.39, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '008339',
#   '1'],
#  ['Block Group 3, Census Tract 83.47, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '008347',
#   '3'],
#  ['Block Group 1, Census Tract 83.47, San Diego County, California',
#   '121',
#   '06',
#   '073',
#   '008347',
#   '1'],
#  ['Block Group 2, Census Tract 83.47, San Diego County, California',
#   '65',
#   '06',
#   '073',
#   '008347',
#   '2'],
#  ['Block Group 3, Census Tract 85.03, San Diego County, California',
#   '60',
#   '06',
#   '073',
#   '008503',
#   '3'],
#  ['Block Group 4, Census Tract 85.03, San Diego County, California',
#   '109',
#   '06',
#   '073',
#   '008503',
#   '4'],
#  ['Block Group 2, Census Tract 85.03, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '008503',
#   '2'],
#  ['Block Group 1, Census Tract 85.03, San Diego County, California',
#   '67',
#   '06',
#   '073',
#   '008503',
#   '1'],
#  ['Block Group 3, Census Tract 85.06, San Diego County, California',
#   '10',
#   '06',
#   '073',
#   '008506',
#   '3'],
#  ['Block Group 1, Census Tract 85.06, San Diego County, California',
#   '48',
#   '06',
#   '073',
#   '008506',
#   '1'],
#  ['Block Group 2, Census Tract 85.06, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '008506',
#   '2'],
#  ['Block Group 3, Census Tract 89.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008901',
#   '3'],
#  ['Block Group 2, Census Tract 89.01, San Diego County, California',
#   '60',
#   '06',
#   '073',
#   '008901',
#   '2'],
#  ['Block Group 1, Census Tract 89.01, San Diego County, California',
#   '98',
#   '06',
#   '073',
#   '008901',
#   '1'],
#  ['Block Group 4, Census Tract 89.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008901',
#   '4'],
#  ['Block Group 1, Census Tract 91.07, San Diego County, California',
#   '116',
#   '06',
#   '073',
#   '009107',
#   '1'],
#  ['Block Group 2, Census Tract 91.07, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009107',
#   '2'],
#  ['Block Group 1, Census Tract 101.09, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '010109',
#   '1'],
#  ['Block Group 2, Census Tract 111, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '011100',
#   '2'],
#  ['Block Group 3, Census Tract 111, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '011100',
#   '3'],
#  ['Block Group 1, Census Tract 111, San Diego County, California',
#   '62',
#   '06',
#   '073',
#   '011100',
#   '1'],
#  ['Block Group 1, Census Tract 121.01, San Diego County, California',
#   '78',
#   '06',
#   '073',
#   '012101',
#   '1'],
#  ['Block Group 2, Census Tract 200.25, San Diego County, California',
#   '53',
#   '06',
#   '073',
#   '020025',
#   '2'],
#  ['Block Group 3, Census Tract 200.25, San Diego County, California',
#   '48',
#   '06',
#   '073',
#   '020025',
#   '3'],
#  ['Block Group 1, Census Tract 192.08, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019208',
#   '1'],
#  ['Block Group 2, Census Tract 192.08, San Diego County, California',
#   '8',
#   '06',
#   '073',
#   '019208',
#   '2'],
#  ['Block Group 1, Census Tract 194.04, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '019404',
#   '1'],
#  ['Block Group 2, Census Tract 194.04, San Diego County, California',
#   '71',
#   '06',
#   '073',
#   '019404',
#   '2'],
#  ['Block Group 2, Census Tract 20.02, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '002002',
#   '2'],
#  ['Block Group 1, Census Tract 20.02, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '002002',
#   '1'],
#  ['Block Group 2, Census Tract 57, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005700',
#   '2'],
#  ['Block Group 1, Census Tract 58, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '005800',
#   '1'],
#  ['Block Group 2, Census Tract 178.10, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '017810',
#   '2'],
#  ['Block Group 1, Census Tract 178.10, San Diego County, California',
#   '27',
#   '06',
#   '073',
#   '017810',
#   '1'],
#  ['Block Group 2, Census Tract 180, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '018000',
#   '2'],
#  ['Block Group 1, Census Tract 180, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '018000',
#   '1'],
#  ['Block Group 3, Census Tract 180, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '018000',
#   '3'],
#  ['Block Group 2, Census Tract 182, San Diego County, California',
#   '108',
#   '06',
#   '073',
#   '018200',
#   '2'],
#  ['Block Group 5, Census Tract 182, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '018200',
#   '5'],
#  ['Block Group 4, Census Tract 182, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '018200',
#   '4'],
#  ['Block Group 3, Census Tract 182, San Diego County, California',
#   '138',
#   '06',
#   '073',
#   '018200',
#   '3'],
#  ['Block Group 1, Census Tract 182, San Diego County, California',
#   '45',
#   '06',
#   '073',
#   '018200',
#   '1'],
#  ['Block Group 1, Census Tract 185.07, San Diego County, California',
#   '84',
#   '06',
#   '073',
#   '018507',
#   '1'],
#  ['Block Group 3, Census Tract 185.07, San Diego County, California',
#   '8',
#   '06',
#   '073',
#   '018507',
#   '3'],
#  ['Block Group 2, Census Tract 185.07, San Diego County, California',
#   '93',
#   '06',
#   '073',
#   '018507',
#   '2'],
#  ['Block Group 4, Census Tract 185.07, San Diego County, California',
#   '27',
#   '06',
#   '073',
#   '018507',
#   '4'],
#  ['Block Group 1, Census Tract 30.03, San Diego County, California',
#   '127',
#   '06',
#   '073',
#   '003003',
#   '1'],
#  ['Block Group 2, Census Tract 30.03, San Diego County, California',
#   '181',
#   '06',
#   '073',
#   '003003',
#   '2'],
#  ['Block Group 3, Census Tract 30.03, San Diego County, California',
#   '10',
#   '06',
#   '073',
#   '003003',
#   '3'],
#  ['Block Group 3, Census Tract 93.01, San Diego County, California',
#   '45',
#   '06',
#   '073',
#   '009301',
#   '3'],
#  ['Block Group 2, Census Tract 95.07, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '009507',
#   '2'],
#  ['Block Group 3, Census Tract 204.04, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '020404',
#   '3'],
#  ['Block Group 2, Census Tract 204.04, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '020404',
#   '2'],
#  ['Block Group 1, Census Tract 204.04, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '020404',
#   '1'],
#  ['Block Group 1, Census Tract 207.09, San Diego County, California',
#   '121',
#   '06',
#   '073',
#   '020709',
#   '1'],
#  ['Block Group 3, Census Tract 207.09, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '020709',
#   '3'],
#  ['Block Group 2, Census Tract 207.09, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '020709',
#   '2'],
#  ['Block Group 2, Census Tract 78, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007800',
#   '2'],
#  ['Block Group 3, Census Tract 78, San Diego County, California',
#   '75',
#   '06',
#   '073',
#   '007800',
#   '3'],
#  ['Block Group 1, Census Tract 78, San Diego County, California',
#   '63',
#   '06',
#   '073',
#   '007800',
#   '1'],
#  ['Block Group 5, Census Tract 78, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '007800',
#   '5'],
#  ['Block Group 4, Census Tract 78, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007800',
#   '4'],
#  ['Block Group 1, Census Tract 80.02, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '008002',
#   '1'],
#  ['Block Group 3, Census Tract 80.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008002',
#   '3'],
#  ['Block Group 2, Census Tract 80.02, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '008002',
#   '2'],
#  ['Block Group 1, Census Tract 83.49, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '008349',
#   '1'],
#  ['Block Group 2, Census Tract 83.49, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '008349',
#   '2'],
#  ['Block Group 2, Census Tract 83.53, San Diego County, California',
#   '95',
#   '06',
#   '073',
#   '008353',
#   '2'],
#  ['Block Group 3, Census Tract 83.53, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008353',
#   '3'],
#  ['Block Group 1, Census Tract 83.53, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '008353',
#   '1'],
#  ['Block Group 2, Census Tract 83.57, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '008357',
#   '2'],
#  ['Block Group 3, Census Tract 83.57, San Diego County, California',
#   '63',
#   '06',
#   '073',
#   '008357',
#   '3'],
#  ['Block Group 1, Census Tract 83.57, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '008357',
#   '1'],
#  ['Block Group 1, Census Tract 79.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007903',
#   '1'],
#  ['Block Group 2, Census Tract 79.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007903',
#   '2'],
#  ['Block Group 3, Census Tract 79.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007903',
#   '3'],
#  ['Block Group 3, Census Tract 169.01, San Diego County, California',
#   '116',
#   '06',
#   '073',
#   '016901',
#   '3'],
#  ['Block Group 4, Census Tract 169.01, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '016901',
#   '4'],
#  ['Block Group 1, Census Tract 169.01, San Diego County, California',
#   '58',
#   '06',
#   '073',
#   '016901',
#   '1'],
#  ['Block Group 2, Census Tract 169.01, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '016901',
#   '2'],
#  ['Block Group 1, Census Tract 174.01, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '017401',
#   '1'],
#  ['Block Group 2, Census Tract 174.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017401',
#   '2'],
#  ['Block Group 3, Census Tract 32.01, San Diego County, California',
#   '88',
#   '06',
#   '073',
#   '003201',
#   '3'],
#  ['Block Group 2, Census Tract 32.09, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '003209',
#   '2'],
#  ['Block Group 3, Census Tract 32.09, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '003209',
#   '3'],
#  ['Block Group 2, Census Tract 163.01, San Diego County, California',
#   '111',
#   '06',
#   '073',
#   '016301',
#   '2'],
#  ['Block Group 3, Census Tract 166.05, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '016605',
#   '3'],
#  ['Block Group 1, Census Tract 166.05, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '016605',
#   '1'],
#  ['Block Group 4, Census Tract 166.05, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '016605',
#   '4'],
#  ['Block Group 2, Census Tract 166.05, San Diego County, California',
#   '70',
#   '06',
#   '073',
#   '016605',
#   '2'],
#  ['Block Group 1, Census Tract 166.06, San Diego County, California',
#   '166',
#   '06',
#   '073',
#   '016606',
#   '1'],
#  ['Block Group 1, Census Tract 166.07, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '016607',
#   '1'],
#  ['Block Group 2, Census Tract 166.07, San Diego County, California',
#   '96',
#   '06',
#   '073',
#   '016607',
#   '2'],
#  ['Block Group 1, Census Tract 166.12, San Diego County, California',
#   '77',
#   '06',
#   '073',
#   '016612',
#   '1'],
#  ['Block Group 2, Census Tract 166.12, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '016612',
#   '2'],
#  ['Block Group 2, Census Tract 168.02, San Diego County, California',
#   '74',
#   '06',
#   '073',
#   '016802',
#   '2'],
#  ['Block Group 3, Census Tract 186.11, San Diego County, California',
#   '39',
#   '06',
#   '073',
#   '018611',
#   '3'],
#  ['Block Group 1, Census Tract 186.11, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '018611',
#   '1'],
#  ['Block Group 2, Census Tract 186.11, San Diego County, California',
#   '220',
#   '06',
#   '073',
#   '018611',
#   '2'],
#  ['Block Group 1, Census Tract 192.03, San Diego County, California',
#   '21',
#   '06',
#   '073',
#   '019203',
#   '1'],
#  ['Block Group 2, Census Tract 192.03, San Diego County, California',
#   '74',
#   '06',
#   '073',
#   '019203',
#   '2'],
#  ['Block Group 1, Census Tract 195.01, San Diego County, California',
#   '164',
#   '06',
#   '073',
#   '019501',
#   '1'],
#  ['Block Group 2, Census Tract 195.01, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '019501',
#   '2'],
#  ['Block Group 2, Census Tract 198.04, San Diego County, California',
#   '52',
#   '06',
#   '073',
#   '019804',
#   '2'],
#  ['Block Group 3, Census Tract 198.04, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '019804',
#   '3'],
#  ['Block Group 1, Census Tract 198.04, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '019804',
#   '1'],
#  ['Block Group 2, Census Tract 198.05, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '019805',
#   '2'],
#  ['Block Group 1, Census Tract 198.05, San Diego County, California',
#   '75',
#   '06',
#   '073',
#   '019805',
#   '1'],
#  ['Block Group 3, Census Tract 198.05, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '019805',
#   '3'],
#  ['Block Group 4, Census Tract 200.18, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '020018',
#   '4'],
#  ['Block Group 2, Census Tract 200.18, San Diego County, California',
#   '99',
#   '06',
#   '073',
#   '020018',
#   '2'],
#  ['Block Group 1, Census Tract 200.18, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '020018',
#   '1'],
#  ['Block Group 3, Census Tract 200.18, San Diego County, California',
#   '252',
#   '06',
#   '073',
#   '020018',
#   '3'],
#  ['Block Group 4, Census Tract 201.08, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '020108',
#   '4'],
#  ['Block Group 1, Census Tract 201.08, San Diego County, California',
#   '27',
#   '06',
#   '073',
#   '020108',
#   '1'],
#  ['Block Group 3, Census Tract 201.08, San Diego County, California',
#   '99',
#   '06',
#   '073',
#   '020108',
#   '3'],
#  ['Block Group 3, Census Tract 95.07, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '009507',
#   '3'],
#  ['Block Group 1, Census Tract 95.07, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '009507',
#   '1'],
#  ['Block Group 3, Census Tract 96.03, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '009603',
#   '3'],
#  ['Block Group 2, Census Tract 96.03, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009603',
#   '2'],
#  ['Block Group 4, Census Tract 96.03, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '009603',
#   '4'],
#  ['Block Group 1, Census Tract 96.03, San Diego County, California',
#   '30',
#   '06',
#   '073',
#   '009603',
#   '1'],
#  ['Block Group 2, Census Tract 201.08, San Diego County, California',
#   '80',
#   '06',
#   '073',
#   '020108',
#   '2'],
#  ['Block Group 1, Census Tract 204.01, San Diego County, California',
#   '8',
#   '06',
#   '073',
#   '020401',
#   '1'],
#  ['Block Group 1, Census Tract 200.20, San Diego County, California',
#   '110',
#   '06',
#   '073',
#   '020020',
#   '1'],
#  ['Block Group 2, Census Tract 200.20, San Diego County, California',
#   '190',
#   '06',
#   '073',
#   '020020',
#   '2'],
#  ['Block Group 1, Census Tract 72, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '007200',
#   '1'],
#  ['Block Group 2, Census Tract 153.02, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '015302',
#   '2'],
#  ['Block Group 1, Census Tract 153.02, San Diego County, California',
#   '82',
#   '06',
#   '073',
#   '015302',
#   '1'],
#  ['Block Group 1, Census Tract 164.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '016401',
#   '1'],
#  ['Block Group 2, Census Tract 164.01, San Diego County, California',
#   '45',
#   '06',
#   '073',
#   '016401',
#   '2'],
#  ['Block Group 3, Census Tract 164.01, San Diego County, California',
#   '52',
#   '06',
#   '073',
#   '016401',
#   '3'],
#  ['Block Group 1, Census Tract 166.13, San Diego County, California',
#   '6',
#   '06',
#   '073',
#   '016613',
#   '1'],
#  ['Block Group 2, Census Tract 166.13, San Diego County, California',
#   '45',
#   '06',
#   '073',
#   '016613',
#   '2'],
#  ['Block Group 3, Census Tract 83.12, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008312',
#   '3'],
#  ['Block Group 1, Census Tract 83.12, San Diego County, California',
#   '9',
#   '06',
#   '073',
#   '008312',
#   '1'],
#  ['Block Group 2, Census Tract 83.12, San Diego County, California',
#   '12',
#   '06',
#   '073',
#   '008312',
#   '2'],
#  ['Block Group 4, Census Tract 83.12, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '008312',
#   '4'],
#  ['Block Group 1, Census Tract 213.04, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '021304',
#   '1'],
#  ['Block Group 2, Census Tract 213.04, San Diego County, California',
#   '4',
#   '06',
#   '073',
#   '021304',
#   '2'],
#  ['Block Group 1, Census Tract 194.03, San Diego County, California',
#   '163',
#   '06',
#   '073',
#   '019403',
#   '1'],
#  ['Block Group 2, Census Tract 194.03, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '019403',
#   '2'],
#  ['Block Group 3, Census Tract 195.03, San Diego County, California',
#   '58',
#   '06',
#   '073',
#   '019503',
#   '3'],
#  ['Block Group 1, Census Tract 195.03, San Diego County, California',
#   '70',
#   '06',
#   '073',
#   '019503',
#   '1'],
#  ['Block Group 2, Census Tract 195.03, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '019503',
#   '2'],
#  ['Block Group 1, Census Tract 197.02, San Diego County, California',
#   '6',
#   '06',
#   '073',
#   '019702',
#   '1'],
#  ['Block Group 4, Census Tract 197.02, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '019702',
#   '4'],
#  ['Block Group 3, Census Tract 197.02, San Diego County, California',
#   '57',
#   '06',
#   '073',
#   '019702',
#   '3'],
#  ['Block Group 2, Census Tract 197.02, San Diego County, California',
#   '27',
#   '06',
#   '073',
#   '019702',
#   '2'],
#  ['Block Group 2, Census Tract 198.06, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019806',
#   '2'],
#  ['Block Group 1, Census Tract 198.06, San Diego County, California',
#   '103',
#   '06',
#   '073',
#   '019806',
#   '1'],
#  ['Block Group 1, Census Tract 197.01, San Diego County, California',
#   '50',
#   '06',
#   '073',
#   '019701',
#   '1'],
#  ['Block Group 2, Census Tract 197.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019701',
#   '2'],
#  ['Block Group 3, Census Tract 197.01, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '019701',
#   '3'],
#  ['Block Group 2, Census Tract 198.03, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '019803',
#   '2'],
#  ['Block Group 1, Census Tract 198.03, San Diego County, California',
#   '60',
#   '06',
#   '073',
#   '019803',
#   '1'],
#  ['Block Group 2, Census Tract 199.03, San Diego County, California',
#   '116',
#   '06',
#   '073',
#   '019903',
#   '2'],
#  ['Block Group 1, Census Tract 199.03, San Diego County, California',
#   '127',
#   '06',
#   '073',
#   '019903',
#   '1'],
#  ['Block Group 1, Census Tract 170.15, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '017015',
#   '1'],
#  ['Block Group 4, Census Tract 170.15, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017015',
#   '4'],
#  ['Block Group 1, Census Tract 108, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '010800',
#   '1'],
#  ['Block Group 2, Census Tract 108, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '010800',
#   '2'],
#  ['Block Group 1, Census Tract 117, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '011700',
#   '1'],
#  ['Block Group 3, Census Tract 117, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '011700',
#   '3'],
#  ['Block Group 4, Census Tract 117, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '011700',
#   '4'],
#  ['Block Group 2, Census Tract 117, San Diego County, California',
#   '61',
#   '06',
#   '073',
#   '011700',
#   '2'],
#  ['Block Group 1, Census Tract 121.02, San Diego County, California',
#   '107',
#   '06',
#   '073',
#   '012102',
#   '1'],
#  ['Block Group 2, Census Tract 121.02, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '012102',
#   '2'],
#  ['Block Group 1, Census Tract 123.03, San Diego County, California',
#   '36',
#   '06',
#   '073',
#   '012303',
#   '1'],
#  ['Block Group 2, Census Tract 123.03, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '012303',
#   '2'],
#  ['Block Group 1, Census Tract 126, San Diego County, California',
#   '85',
#   '06',
#   '073',
#   '012600',
#   '1'],
#  ['Block Group 4, Census Tract 126, San Diego County, California',
#   '75',
#   '06',
#   '073',
#   '012600',
#   '4'],
#  ['Block Group 3, Census Tract 126, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '012600',
#   '3'],
#  ['Block Group 2, Census Tract 126, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '012600',
#   '2'],
#  ['Block Group 2, Census Tract 131.03, San Diego County, California',
#   '56',
#   '06',
#   '073',
#   '013103',
#   '2'],
#  ['Block Group 1, Census Tract 131.03, San Diego County, California',
#   '63',
#   '06',
#   '073',
#   '013103',
#   '1'],
#  ['Block Group 3, Census Tract 133.11, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '013311',
#   '3'],
#  ['Block Group 4, Census Tract 133.11, San Diego County, California',
#   '21',
#   '06',
#   '073',
#   '013311',
#   '4'],
#  ['Block Group 2, Census Tract 133.11, San Diego County, California',
#   '59',
#   '06',
#   '073',
#   '013311',
#   '2'],
#  ['Block Group 1, Census Tract 133.11, San Diego County, California',
#   '186',
#   '06',
#   '073',
#   '013311',
#   '1'],
#  ['Block Group 2, Census Tract 134.12, San Diego County, California',
#   '171',
#   '06',
#   '073',
#   '013412',
#   '2'],
#  ['Block Group 1, Census Tract 134.12, San Diego County, California',
#   '48',
#   '06',
#   '073',
#   '013412',
#   '1'],
#  ['Block Group 1, Census Tract 134.09, San Diego County, California',
#   '30',
#   '06',
#   '073',
#   '013409',
#   '1'],
#  ['Block Group 3, Census Tract 134.09, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '013409',
#   '3'],
#  ['Block Group 1, Census Tract 140.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '014001',
#   '1'],
#  ['Block Group 2, Census Tract 140.01, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '014001',
#   '2'],
#  ['Block Group 3, Census Tract 140.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '014001',
#   '3'],
#  ['Block Group 4, Census Tract 140.01, San Diego County, California',
#   '84',
#   '06',
#   '073',
#   '014001',
#   '4'],
#  ['Block Group 1, Census Tract 144, San Diego County, California',
#   '198',
#   '06',
#   '073',
#   '014400',
#   '1'],
#  ['Block Group 2, Census Tract 144, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '014400',
#   '2'],
#  ['Block Group 2, Census Tract 145, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '014500',
#   '2'],
#  ['Block Group 1, Census Tract 145, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '014500',
#   '1'],
#  ['Block Group 3, Census Tract 145, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '014500',
#   '3'],
#  ['Block Group 2, Census Tract 150, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '015000',
#   '2'],
#  ['Block Group 3, Census Tract 150, San Diego County, California',
#   '41',
#   '06',
#   '073',
#   '015000',
#   '3'],
#  ['Block Group 4, Census Tract 150, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '015000',
#   '4'],
#  ['Block Group 1, Census Tract 150, San Diego County, California',
#   '11',
#   '06',
#   '073',
#   '015000',
#   '1'],
#  ['Block Group 3, Census Tract 19, San Diego County, California',
#   '7',
#   '06',
#   '073',
#   '001900',
#   '3'],
#  ['Block Group 3, Census Tract 21, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '002100',
#   '3'],
#  ['Block Group 4, Census Tract 21, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '002100',
#   '4'],
#  ['Block Group 5, Census Tract 21, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '002100',
#   '5'],
#  ['Block Group 2, Census Tract 21, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '002100',
#   '2'],
#  ['Block Group 1, Census Tract 21, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '002100',
#   '1'],
#  ['Block Group 3, Census Tract 35.01, San Diego County, California',
#   '39',
#   '06',
#   '073',
#   '003501',
#   '3'],
#  ['Block Group 1, Census Tract 35.01, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '003501',
#   '1'],
#  ['Block Group 1, Census Tract 91.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009101',
#   '1'],
#  ['Block Group 4, Census Tract 91.01, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '009101',
#   '4'],
#  ['Block Group 2, Census Tract 91.01, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '009101',
#   '2'],
#  ['Block Group 3, Census Tract 31.01, San Diego County, California',
#   '147',
#   '06',
#   '073',
#   '003101',
#   '3'],
#  ['Block Group 2, Census Tract 31.01, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '003101',
#   '2'],
#  ['Block Group 1, Census Tract 31.01, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '003101',
#   '1'],
#  ['Block Group 2, Census Tract 31.11, San Diego County, California',
#   '57',
#   '06',
#   '073',
#   '003111',
#   '2'],
#  ['Block Group 3, Census Tract 31.11, San Diego County, California',
#   '89',
#   '06',
#   '073',
#   '003111',
#   '3'],
#  ['Block Group 1, Census Tract 31.11, San Diego County, California',
#   '94',
#   '06',
#   '073',
#   '003111',
#   '1'],
#  ['Block Group 1, Census Tract 31.14, San Diego County, California',
#   '22',
#   '06',
#   '073',
#   '003114',
#   '1'],
#  ['Block Group 2, Census Tract 32.12, San Diego County, California',
#   '55',
#   '06',
#   '073',
#   '003212',
#   '2'],
#  ['Block Group 1, Census Tract 32.12, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '003212',
#   '1'],
#  ['Block Group 1, Census Tract 68.01, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '006801',
#   '1'],
#  ['Block Group 2, Census Tract 100.12, San Diego County, California',
#   '134',
#   '06',
#   '073',
#   '010012',
#   '2'],
#  ['Block Group 1, Census Tract 100.12, San Diego County, California',
#   '27',
#   '06',
#   '073',
#   '010012',
#   '1'],
#  ['Block Group 1, Census Tract 118.02, San Diego County, California',
#   '146',
#   '06',
#   '073',
#   '011802',
#   '1'],
#  ['Block Group 2, Census Tract 118.02, San Diego County, California',
#   '115',
#   '06',
#   '073',
#   '011802',
#   '2'],
#  ['Block Group 2, Census Tract 209.04, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '020904',
#   '2'],
#  ['Block Group 1, Census Tract 83.27, San Diego County, California',
#   '86',
#   '06',
#   '073',
#   '008327',
#   '1'],
#  ['Block Group 2, Census Tract 83.27, San Diego County, California',
#   '56',
#   '06',
#   '073',
#   '008327',
#   '2'],
#  ['Block Group 4, Census Tract 85.02, San Diego County, California',
#   '11',
#   '06',
#   '073',
#   '008502',
#   '4'],
#  ['Block Group 1, Census Tract 85.02, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '008502',
#   '1'],
#  ['Block Group 5, Census Tract 85.02, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '008502',
#   '5'],
#  ['Block Group 3, Census Tract 85.02, San Diego County, California',
#   '44',
#   '06',
#   '073',
#   '008502',
#   '3'],
#  ['Block Group 2, Census Tract 85.02, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '008502',
#   '2'],
#  ['Block Group 1, Census Tract 85.07, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '008507',
#   '1'],
#  ['Block Group 3, Census Tract 85.07, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008507',
#   '3'],
#  ['Block Group 2, Census Tract 85.07, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008507',
#   '2'],
#  ['Block Group 5, Census Tract 85.07, San Diego County, California',
#   '112',
#   '06',
#   '073',
#   '008507',
#   '5'],
#  ['Block Group 6, Census Tract 85.07, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '008507',
#   '6'],
#  ['Block Group 4, Census Tract 85.07, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008507',
#   '4'],
#  ['Block Group 1, Census Tract 27.05, San Diego County, California',
#   '140',
#   '06',
#   '073',
#   '002705',
#   '1'],
#  ['Block Group 2, Census Tract 27.05, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '002705',
#   '2'],
#  ['Block Group 1, Census Tract 32.11, San Diego County, California',
#   '59',
#   '06',
#   '073',
#   '003211',
#   '1'],
#  ['Block Group 2, Census Tract 32.11, San Diego County, California',
#   '53',
#   '06',
#   '073',
#   '003211',
#   '2'],
#  ['Block Group 2, Census Tract 65, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '006500',
#   '2'],
#  ['Block Group 3, Census Tract 65, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '006500',
#   '3'],
#  ['Block Group 1, Census Tract 65, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '006500',
#   '1'],
#  ['Block Group 1, Census Tract 85.11, San Diego County, California',
#   '9',
#   '06',
#   '073',
#   '008511',
#   '1'],
#  ['Block Group 2, Census Tract 127, San Diego County, California',
#   '58',
#   '06',
#   '073',
#   '012700',
#   '2'],
#  ['Block Group 1, Census Tract 127, San Diego County, California',
#   '121',
#   '06',
#   '073',
#   '012700',
#   '1'],
#  ['Block Group 2, Census Tract 185.19, San Diego County, California',
#   '181',
#   '06',
#   '073',
#   '018519',
#   '2'],
#  ['Block Group 1, Census Tract 185.19, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '018519',
#   '1'],
#  ['Block Group 1, Census Tract 191.07, San Diego County, California',
#   '82',
#   '06',
#   '073',
#   '019107',
#   '1'],
#  ['Block Group 2, Census Tract 185.13, San Diego County, California',
#   '98',
#   '06',
#   '073',
#   '018513',
#   '2'],
#  ['Block Group 1, Census Tract 185.13, San Diego County, California',
#   '181',
#   '06',
#   '073',
#   '018513',
#   '1'],
#  ['Block Group 3, Census Tract 185.13, San Diego County, California',
#   '29',
#   '06',
#   '073',
#   '018513',
#   '3'],
#  ['Block Group 3, Census Tract 186.03, San Diego County, California',
#   '213',
#   '06',
#   '073',
#   '018603',
#   '3'],
#  ['Block Group 1, Census Tract 186.03, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '018603',
#   '1'],
#  ['Block Group 2, Census Tract 186.03, San Diego County, California',
#   '170',
#   '06',
#   '073',
#   '018603',
#   '2'],
#  ['Block Group 2, Census Tract 124.01, San Diego County, California',
#   '117',
#   '06',
#   '073',
#   '012401',
#   '2'],
#  ['Block Group 1, Census Tract 124.01, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '012401',
#   '1'],
#  ['Block Group 2, Census Tract 185.15, San Diego County, California',
#   '84',
#   '06',
#   '073',
#   '018515',
#   '2'],
#  ['Block Group 1, Census Tract 185.15, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '018515',
#   '1'],
#  ['Block Group 2, Census Tract 185.18, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '018518',
#   '2'],
#  ['Block Group 1, Census Tract 185.18, San Diego County, California',
#   '100',
#   '06',
#   '073',
#   '018518',
#   '1'],
#  ['Block Group 2, Census Tract 190.01, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '019001',
#   '2'],
#  ['Block Group 1, Census Tract 190.01, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019001',
#   '1'],
#  ['Block Group 3, Census Tract 190.01, San Diego County, California',
#   '80',
#   '06',
#   '073',
#   '019001',
#   '3'],
#  ['Block Group 1, Census Tract 191.03, San Diego County, California',
#   '93',
#   '06',
#   '073',
#   '019103',
#   '1'],
#  ['Block Group 3, Census Tract 191.03, San Diego County, California',
#   '124',
#   '06',
#   '073',
#   '019103',
#   '3'],
#  ['Block Group 2, Census Tract 191.03, San Diego County, California',
#   '43',
#   '06',
#   '073',
#   '019103',
#   '2'],
#  ['Block Group 1, Census Tract 192.06, San Diego County, California',
#   '118',
#   '06',
#   '073',
#   '019206',
#   '1'],
#  ['Block Group 2, Census Tract 192.06, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019206',
#   '2'],
#  ['Block Group 3, Census Tract 192.06, San Diego County, California',
#   '53',
#   '06',
#   '073',
#   '019206',
#   '3'],
#  ['Block Group 1, Census Tract 193.03, San Diego County, California',
#   '75',
#   '06',
#   '073',
#   '019303',
#   '1'],
#  ['Block Group 2, Census Tract 193.03, San Diego County, California',
#   '169',
#   '06',
#   '073',
#   '019303',
#   '2'],
#  ['Block Group 1, Census Tract 194.05, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '019405',
#   '1'],
#  ['Block Group 1, Census Tract 166.09, San Diego County, California',
#   '173',
#   '06',
#   '073',
#   '016609',
#   '1'],
#  ['Block Group 2, Census Tract 166.09, San Diego County, California',
#   '119',
#   '06',
#   '073',
#   '016609',
#   '2'],
#  ['Block Group 2, Census Tract 170.06, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '017006',
#   '2'],
#  ['Block Group 1, Census Tract 170.06, San Diego County, California',
#   '76',
#   '06',
#   '073',
#   '017006',
#   '1'],
#  ['Block Group 1, Census Tract 170.29, San Diego County, California',
#   '374',
#   '06',
#   '073',
#   '017029',
#   '1'],
#  ['Block Group 1, Census Tract 170.39, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017039',
#   '1'],
#  ['Block Group 1, Census Tract 170.40, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '017040',
#   '1'],
#  ['Block Group 2, Census Tract 170.40, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '017040',
#   '2'],
#  ['Block Group 3, Census Tract 170.40, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '017040',
#   '3'],
#  ['Block Group 2, Census Tract 170.48, San Diego County, California',
# ...
#   '96',
#   '06',
#   '073',
#   '013414',
#   '2'],
#  ['Block Group 1, Census Tract 134.14, San Diego County, California',
#   '101',
#   '06',
#   '073',
#   '013414',
#   '1'],
#  ['Block Group 3, Census Tract 185.04, San Diego County, California',
#   '69',
#   '06',
#   '073',
#   '018504',
#   '3'],
#  ['Block Group 2, Census Tract 185.04, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '018504',
#   '2'],
#  ['Block Group 4, Census Tract 185.04, San Diego County, California',
#   '48',
#   '06',
#   '073',
#   '018504',
#   '4'],
#  ['Block Group 1, Census Tract 185.09, San Diego County, California',
#   '44',
#   '06',
#   '073',
#   '018509',
#   '1'],
#  ['Block Group 4, Census Tract 185.09, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '018509',
#   '4'],
#  ['Block Group 2, Census Tract 185.09, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '018509',
#   '2'],
#  ['Block Group 3, Census Tract 185.09, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '018509',
#   '3'],
#  ['Block Group 2, Census Tract 185.17, San Diego County, California',
#   '45',
#   '06',
#   '073',
#   '018517',
#   '2'],
#  ['Block Group 1, Census Tract 185.17, San Diego County, California',
#   '71',
#   '06',
#   '073',
#   '018517',
#   '1'],
#  ['Block Group 1, Census Tract 186.12, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '018612',
#   '1'],
#  ['Block Group 1, Census Tract 193.01, San Diego County, California',
#   '60',
#   '06',
#   '073',
#   '019301',
#   '1'],
#  ['Block Group 2, Census Tract 195.02, San Diego County, California',
#   '84',
#   '06',
#   '073',
#   '019502',
#   '2'],
#  ['Block Group 3, Census Tract 195.02, San Diego County, California',
#   '34',
#   '06',
#   '073',
#   '019502',
#   '3'],
#  ['Block Group 1, Census Tract 195.02, San Diego County, California',
#   '200',
#   '06',
#   '073',
#   '019502',
#   '1'],
#  ['Block Group 1, Census Tract 95.06, San Diego County, California',
#   '100',
#   '06',
#   '073',
#   '009506',
#   '1'],
#  ['Block Group 4, Census Tract 96.02, San Diego County, California',
#   '44',
#   '06',
#   '073',
#   '009602',
#   '4'],
#  ['Block Group 2, Census Tract 96.02, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '009602',
#   '2'],
#  ['Block Group 3, Census Tract 96.02, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '009602',
#   '3'],
#  ['Block Group 1, Census Tract 96.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009602',
#   '1'],
#  ['Block Group 2, Census Tract 96.04, San Diego County, California',
#   '40',
#   '06',
#   '073',
#   '009604',
#   '2'],
#  ['Block Group 4, Census Tract 96.04, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '009604',
#   '4'],
#  ['Block Group 1, Census Tract 133.13, San Diego County, California',
#   '683',
#   '06',
#   '073',
#   '013313',
#   '1'],
#  ['Block Group 2, Census Tract 134.11, San Diego County, California',
#   '39',
#   '06',
#   '073',
#   '013411',
#   '2'],
#  ['Block Group 3, Census Tract 134.11, San Diego County, California',
#   '69',
#   '06',
#   '073',
#   '013411',
#   '3'],
#  ['Block Group 1, Census Tract 134.11, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '013411',
#   '1'],
#  ['Block Group 1, Census Tract 151, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '015100',
#   '1'],
#  ['Block Group 2, Census Tract 151, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '015100',
#   '2'],
#  ['Block Group 4, Census Tract 151, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '015100',
#   '4'],
#  ['Block Group 3, Census Tract 151, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '015100',
#   '3'],
#  ['Block Group 2, Census Tract 154.03, San Diego County, California',
#   '65',
#   '06',
#   '073',
#   '015403',
#   '2'],
#  ['Block Group 1, Census Tract 154.03, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '015403',
#   '1'],
#  ['Block Group 2, Census Tract 155.02, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '015502',
#   '2'],
#  ['Block Group 1, Census Tract 156.01, San Diego County, California',
#   '105',
#   '06',
#   '073',
#   '015601',
#   '1'],
#  ['Block Group 2, Census Tract 156.01, San Diego County, California',
#   '62',
#   '06',
#   '073',
#   '015601',
#   '2'],
#  ['Block Group 1, Census Tract 168.09, San Diego County, California',
#   '67',
#   '06',
#   '073',
#   '016809',
#   '1'],
#  ['Block Group 2, Census Tract 168.09, San Diego County, California',
#   '76',
#   '06',
#   '073',
#   '016809',
#   '2'],
#  ['Block Group 3, Census Tract 168.09, San Diego County, California',
#   '146',
#   '06',
#   '073',
#   '016809',
#   '3'],
#  ['Block Group 1, Census Tract 169.02, San Diego County, California',
#   '90',
#   '06',
#   '073',
#   '016902',
#   '1'],
#  ['Block Group 1, Census Tract 200.14, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '020014',
#   '1'],
#  ['Block Group 4, Census Tract 200.14, San Diego County, California',
#   '43',
#   '06',
#   '073',
#   '020014',
#   '4'],
#  ['Block Group 2, Census Tract 200.14, San Diego County, California',
#   '132',
#   '06',
#   '073',
#   '020014',
#   '2'],
#  ['Block Group 3, Census Tract 200.14, San Diego County, California',
#   '25',
#   '06',
#   '073',
#   '020014',
#   '3'],
#  ['Block Group 1, Census Tract 201.07, San Diego County, California',
#   '8',
#   '06',
#   '073',
#   '020107',
#   '1'],
#  ['Block Group 2, Census Tract 201.07, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '020107',
#   '2'],
#  ['Block Group 1, Census Tract 189.06, San Diego County, California',
#   '104',
#   '06',
#   '073',
#   '018906',
#   '1'],
#  ['Block Group 3, Census Tract 70.02, San Diego County, California',
#   '18',
#   '06',
#   '073',
#   '007002',
#   '3'],
#  ['Block Group 1, Census Tract 70.02, San Diego County, California',
#   '125',
#   '06',
#   '073',
#   '007002',
#   '1'],
#  ['Block Group 2, Census Tract 70.02, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '007002',
#   '2'],
#  ['Block Group 2, Census Tract 75.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007502',
#   '2'],
#  ['Block Group 1, Census Tract 75.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007502',
#   '1'],
#  ['Block Group 3, Census Tract 75.02, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '007502',
#   '3'],
#  ['Block Group 1, Census Tract 95.02, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '009502',
#   '1'],
#  ['Block Group 2, Census Tract 95.02, San Diego County, California',
#   '113',
#   '06',
#   '073',
#   '009502',
#   '2'],
#  ['Block Group 1, Census Tract 87.01, San Diego County, California',
#   '61',
#   '06',
#   '073',
#   '008701',
#   '1'],
#  ['Block Group 2, Census Tract 87.01, San Diego County, California',
#   '69',
#   '06',
#   '073',
#   '008701',
#   '2'],
#  ['Block Group 1, Census Tract 91.04, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '009104',
#   '1'],
#  ['Block Group 2, Census Tract 91.04, San Diego County, California',
#   '37',
#   '06',
#   '073',
#   '009104',
#   '2'],
#  ['Block Group 2, Census Tract 92.02, San Diego County, California',
#   '91',
#   '06',
#   '073',
#   '009202',
#   '2'],
#  ['Block Group 1, Census Tract 92.02, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '009202',
#   '1'],
#  ['Block Group 2, Census Tract 95.06, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '009506',
#   '2'],
#  ['Block Group 3, Census Tract 189.06, San Diego County, California',
#   '43',
#   '06',
#   '073',
#   '018906',
#   '3'],
#  ['Block Group 2, Census Tract 189.06, San Diego County, California',
#   '43',
#   '06',
#   '073',
#   '018906',
#   '2'],
#  ['Block Group 1, Census Tract 190.02, San Diego County, California',
#   '30',
#   '06',
#   '073',
#   '019002',
#   '1'],
#  ['Block Group 3, Census Tract 192.05, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '019205',
#   '3'],
#  ['Block Group 1, Census Tract 192.05, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '019205',
#   '1'],
#  ['Block Group 4, Census Tract 192.05, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '019205',
#   '4'],
#  ['Block Group 2, Census Tract 192.05, San Diego County, California',
#   '162',
#   '06',
#   '073',
#   '019205',
#   '2'],
#  ['Block Group 3, Census Tract 200.19, San Diego County, California',
#   '136',
#   '06',
#   '073',
#   '020019',
#   '3'],
#  ['Block Group 2, Census Tract 200.19, San Diego County, California',
#   '28',
#   '06',
#   '073',
#   '020019',
#   '2'],
#  ['Block Group 1, Census Tract 200.19, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '020019',
#   '1'],
#  ['Block Group 2, Census Tract 203.05, San Diego County, California',
#   '73',
#   '06',
#   '073',
#   '020305',
#   '2'],
#  ['Block Group 3, Census Tract 203.05, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '020305',
#   '3'],
#  ['Block Group 1, Census Tract 203.05, San Diego County, California',
#   '73',
#   '06',
#   '073',
#   '020305',
#   '1'],
#  ['Block Group 2, Census Tract 170.18, San Diego County, California',
#   '66',
#   '06',
#   '073',
#   '017018',
#   '2'],
#  ['Block Group 1, Census Tract 170.18, San Diego County, California',
#   '85',
#   '06',
#   '073',
#   '017018',
#   '1'],
#  ['Block Group 1, Census Tract 170.43, San Diego County, California',
#   '95',
#   '06',
#   '073',
#   '017043',
#   '1'],
#  ['Block Group 1, Census Tract 170.50, San Diego County, California',
#   '12',
#   '06',
#   '073',
#   '017050',
#   '1'],
#  ['Block Group 2, Census Tract 170.50, San Diego County, California',
#   '60',
#   '06',
#   '073',
#   '017050',
#   '2'],
#  ['Block Group 3, Census Tract 173.03, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '017303',
#   '3'],
#  ['Block Group 2, Census Tract 173.03, San Diego County, California',
#   '17',
#   '06',
#   '073',
#   '017303',
#   '2'],
#  ['Block Group 1, Census Tract 173.03, San Diego County, California',
#   '100',
#   '06',
#   '073',
#   '017303',
#   '1'],
#  ['Block Group 2, Census Tract 174.04, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '017404',
#   '2'],
#  ['Block Group 4, Census Tract 174.04, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '017404',
#   '4'],
#  ['Block Group 5, Census Tract 174.04, San Diego County, California',
#   '39',
#   '06',
#   '073',
#   '017404',
#   '5'],
#  ['Block Group 1, Census Tract 174.04, San Diego County, California',
#   '51',
#   '06',
#   '073',
#   '017404',
#   '1'],
#  ['Block Group 3, Census Tract 174.04, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '017404',
#   '3'],
#  ['Block Group 2, Census Tract 181, San Diego County, California',
#   '24',
#   '06',
#   '073',
#   '018100',
#   '2'],
#  ['Block Group 5, Census Tract 181, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '018100',
#   '5'],
#  ['Block Group 1, Census Tract 153.01, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '015301',
#   '1'],
#  ['Block Group 3, Census Tract 154.05, San Diego County, California',
#   '74',
#   '06',
#   '073',
#   '015405',
#   '3'],
#  ['Block Group 1, Census Tract 154.05, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '015405',
#   '1'],
#  ['Block Group 2, Census Tract 154.05, San Diego County, California',
#   '19',
#   '06',
#   '073',
#   '015405',
#   '2'],
#  ['Block Group 1, Census Tract 156.02, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '015602',
#   '1'],
#  ['Block Group 2, Census Tract 156.02, San Diego County, California',
#   '6',
#   '06',
#   '073',
#   '015602',
#   '2'],
#  ['Block Group 1, Census Tract 157.04, San Diego County, California',
#   '80',
#   '06',
#   '073',
#   '015704',
#   '1'],
#  ['Block Group 2, Census Tract 157.04, San Diego County, California',
#   '142',
#   '06',
#   '073',
#   '015704',
#   '2'],
#  ['Block Group 3, Census Tract 161, San Diego County, California',
#   '124',
#   '06',
#   '073',
#   '016100',
#   '3'],
#  ['Block Group 1, Census Tract 161, San Diego County, California',
#   '188',
#   '06',
#   '073',
#   '016100',
#   '1'],
#  ['Block Group 2, Census Tract 161, San Diego County, California',
#   '46',
#   '06',
#   '073',
#   '016100',
#   '2'],
#  ['Block Group 1, Census Tract 163.01, San Diego County, California',
#   '132',
#   '06',
#   '073',
#   '016301',
#   '1'],
#  ['Block Group 4, Census Tract 181, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '018100',
#   '4'],
#  ['Block Group 3, Census Tract 181, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '018100',
#   '3'],
#  ['Block Group 1, Census Tract 181, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '018100',
#   '1'],
#  ['Block Group 1, Census Tract 170.35, San Diego County, California',
#   '10',
#   '06',
#   '073',
#   '017035',
#   '1'],
#  ['Block Group 1, Census Tract 166.16, San Diego County, California',
#   '99',
#   '06',
#   '073',
#   '016616',
#   '1'],
#  ['Block Group 1, Census Tract 167.01, San Diego County, California',
#   '288',
#   '06',
#   '073',
#   '016701',
#   '1'],
#  ['Block Group 2, Census Tract 167.01, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '016701',
#   '2'],
#  ['Block Group 3, Census Tract 170.35, San Diego County, California',
#   '77',
#   '06',
#   '073',
#   '017035',
#   '3'],
#  ['Block Group 2, Census Tract 170.35, San Diego County, California',
#   '16',
#   '06',
#   '073',
#   '017035',
#   '2'],
#  ['Block Group 1, Census Tract 170.46, San Diego County, California',
#   '64',
#   '06',
#   '073',
#   '017046',
#   '1'],
#  ['Block Group 2, Census Tract 170.46, San Diego County, California',
#   '30',
#   '06',
#   '073',
#   '017046',
#   '2'],
#  ['Block Group 1, Census Tract 170.49, San Diego County, California',
#   '33',
#   '06',
#   '073',
#   '017049',
#   '1'],
#  ['Block Group 2, Census Tract 170.49, San Diego County, California',
#   '53',
#   '06',
#   '073',
#   '017049',
#   '2'],
#  ['Block Group 1, Census Tract 173.06, San Diego County, California',
#   '31',
#   '06',
#   '073',
#   '017306',
#   '1'],
#  ['Block Group 2, Census Tract 173.06, San Diego County, California',
#   '14',
#   '06',
#   '073',
#   '017306',
#   '2'],
#  ['Block Group 1, Census Tract 177.02, San Diego County, California',
#   '47',
#   '06',
#   '073',
#   '017702',
#   '1'],
#  ['Block Group 2, Census Tract 177.02, San Diego County, California',
#   '26',
#   '06',
#   '073',
#   '017702',
#   '2'],
#  ['Block Group 3, Census Tract 177.02, San Diego County, California',
#   '32',
#   '06',
#   '073',
#   '017702',
#   '3'],
#  ['Block Group 1, Census Tract 178.01, San Diego County, California',
#   '38',
#   '06',
#   '073',
#   '017801',
#   '1'],
#  ['Block Group 2, Census Tract 178.01, San Diego County, California',
#   '129',
#   '06',
#   '073',
#   '017801',
#   '2'],
#  ['Block Group 1, Census Tract 83.33, San Diego County, California',
#   '457',
#   '06',
#   '073',
#   '008333',
#   '1'],
#  ['Block Group 1, Census Tract 83.35, San Diego County, California',
#   '13',
#   '06',
#   '073',
#   '008335',
#   '1'],
#  ['Block Group 2, Census Tract 83.35, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '008335',
#   '2'],
#  ['Block Group 1, Census Tract 83.36, San Diego County, California',
#   '36',
#   '06',
#   '073',
#   '008336',
#   '1'],
#  ['Block Group 2, Census Tract 83.36, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '008336',
#   '2'],
#  ['Block Group 1, Census Tract 83.44, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '008344',
#   '1'],
#  ['Block Group 2, Census Tract 83.44, San Diego County, California',
#   '15',
#   '06',
#   '073',
#   '008344',
#   '2'],
#  ['Block Group 1, Census Tract 83.48, San Diego County, California',
#   '23',
#   '06',
#   '073',
#   '008348',
#   '1'],
#  ['Block Group 2, Census Tract 83.48, San Diego County, California',
#   '35',
#   '06',
#   '073',
#   '008348',
#   '2'],
#  ['Block Group 1, Census Tract 85.01, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '008501',
#   '1'],
#  ['Block Group 2, Census Tract 139.06, San Diego County, California',
#   '63',
#   '06',
#   '073',
#   '013906',
#   '2'],
#  ['Block Group 4, Census Tract 101.10, San Diego County, California',
#   '42',
#   '06',
#   '073',
#   '010110',
#   '4'],
#  ['Block Group 5, Census Tract 101.10, San Diego County, California',
#   '69',
#   '06',
#   '073',
#   '010110',
#   '5'],
#  ['Block Group 1, Census Tract 101.10, San Diego County, California',
#   '85',
#   '06',
#   '073',
#   '010110',
#   '1'],
#  ['Block Group 2, Census Tract 101.10, San Diego County, California',
#   '89',
#   '06',
#   '073',
#   '010110',
#   '2'],
#  ['Block Group 3, Census Tract 101.10, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '010110',
#   '3'],
#  ['Block Group 2, Census Tract 168.07, San Diego County, California',
#   '0',
#   '06',
#   '073',
#   '016807',
#   '2'],
#  ['Block Group 2, Census Tract 202.11, San Diego County, California',
#   '54',
#   '06',
#   '073',
#   '020211',
#   '2'],
#  ...]

# %%
df4 = pd.DataFrame.from_dict(data)
df4
# Out:
#                                                       0            1      2  \
# 0                                                  NAME  B01001_004E  state
# 1     Block Group 2, Census Tract 178.08, San Diego ...           82     06
# 2     Block Group 4, Census Tract 178.08, San Diego ...           33     06
# 3     Block Group 3, Census Tract 178.08, San Diego ...           49     06
# 4     Block Group 1, Census Tract 178.08, San Diego ...            0     06
# ...                                                 ...          ...    ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...           75     06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...           28     06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...            0     06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...           39     06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...           47     06
#
#            3       4            5
# 0     county   tract  block group
# 1        073  017808            2
# 2        073  017808            4
# 3        073  017808            3
# 4        073  017808            1
# ...      ...     ...          ...
# 1791     073  017109            1
# 1792     073  017109            2
# 1793     073  017109            3
# 1794     073  017109            4
# 1795     073  017110            1
#
# [1796 rows x 6 columns]

# %%
df4.columns = df4.iloc[0]

#set first row as the column names in the dataframe

df4
# Out:
# 0                                                  NAME  B01001_004E  state  \
# 0                                                  NAME  B01001_004E  state
# 1     Block Group 2, Census Tract 178.08, San Diego ...           82     06
# 2     Block Group 4, Census Tract 178.08, San Diego ...           33     06
# 3     Block Group 3, Census Tract 178.08, San Diego ...           49     06
# 4     Block Group 1, Census Tract 178.08, San Diego ...            0     06
# ...                                                 ...          ...    ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...           75     06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...           28     06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...            0     06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...           39     06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...           47     06
#
# 0     county   tract  block group
# 0     county   tract  block group
# 1        073  017808            2
# 2        073  017808            4
# 3        073  017808            3
# 4        073  017808            1
# ...      ...     ...          ...
# 1791     073  017109            1
# 1792     073  017109            2
# 1793     073  017109            3
# 1794     073  017109            4
# 1795     073  017110            1
#
# [1796 rows x 6 columns]

# %%
df4 = df4.iloc[1:]
df4

#delete row 0 after renaming columns
# Out:
# 0                                                  NAME B01001_004E state  \
# 1     Block Group 2, Census Tract 178.08, San Diego ...          82    06
# 2     Block Group 4, Census Tract 178.08, San Diego ...          33    06
# 3     Block Group 3, Census Tract 178.08, San Diego ...          49    06
# 4     Block Group 1, Census Tract 178.08, San Diego ...           0    06
# 5     Block Group 1, Census Tract 191.01, San Diego ...          95    06
# ...                                                 ...         ...   ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...          75    06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...          28    06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...           0    06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...          39    06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...          47    06
#
# 0    county   tract block group
# 1       073  017808           2
# 2       073  017808           4
# 3       073  017808           3
# 4       073  017808           1
# 5       073  019101           1
# ...     ...     ...         ...
# 1791    073  017109           1
# 1792    073  017109           2
# 1793    073  017109           3
# 1794    073  017109           4
# 1795    073  017110           1
#
# [1795 rows x 6 columns]

# %%
df4.NAME
# Out:
# 1       Block Group 2, Census Tract 178.08, San Diego ...
# 2       Block Group 4, Census Tract 178.08, San Diego ...
# 3       Block Group 3, Census Tract 178.08, San Diego ...
# 4       Block Group 1, Census Tract 178.08, San Diego ...
# 5       Block Group 1, Census Tract 191.01, San Diego ...
#                               ...
# 1791    Block Group 1, Census Tract 171.09, San Diego ...
# 1792    Block Group 2, Census Tract 171.09, San Diego ...
# 1793    Block Group 3, Census Tract 171.09, San Diego ...
# 1794    Block Group 4, Census Tract 171.09, San Diego ...
# 1795    Block Group 1, Census Tract 171.10, San Diego ...
# Name: NAME, Length: 1795, dtype: object

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Male Estimates 10 - 14 years
#
# B01001_005E = Estimate!!Total!!Male!!10 to 14 years

# %%
url5 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_005E&for=block%20group:*&in=state:06%20county:073"

# B01001_005E added to url 

response = urlopen(url5)
data = loads(response.read())

data

;
# ; hide dict
# Out:
# ''

# %%
df5 = pd.DataFrame.from_dict(data)

df5.columns = df5.iloc[0]

#set first row as the column names in the dataframe

df5
# Out:
# 0                                                  NAME  B01001_005E  state  \
# 0                                                  NAME  B01001_005E  state
# 1     Block Group 2, Census Tract 178.08, San Diego ...          167     06
# 2     Block Group 4, Census Tract 178.08, San Diego ...           21     06
# 3     Block Group 3, Census Tract 178.08, San Diego ...            0     06
# 4     Block Group 1, Census Tract 178.08, San Diego ...           12     06
# ...                                                 ...          ...    ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...          170     06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...           27     06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...            0     06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...          120     06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...           14     06
#
# 0     county   tract  block group
# 0     county   tract  block group
# 1        073  017808            2
# 2        073  017808            4
# 3        073  017808            3
# 4        073  017808            1
# ...      ...     ...          ...
# 1791     073  017109            1
# 1792     073  017109            2
# 1793     073  017109            3
# 1794     073  017109            4
# 1795     073  017110            1
#
# [1796 rows x 6 columns]

# %%
df5 = df5.iloc[1:]
df5

#delete row 0 after renaming columns
# Out:
# 0                                                  NAME B01001_005E state  \
# 1     Block Group 2, Census Tract 178.08, San Diego ...         167    06
# 2     Block Group 4, Census Tract 178.08, San Diego ...          21    06
# 3     Block Group 3, Census Tract 178.08, San Diego ...           0    06
# 4     Block Group 1, Census Tract 178.08, San Diego ...          12    06
# 5     Block Group 1, Census Tract 191.01, San Diego ...         120    06
# ...                                                 ...         ...   ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...         170    06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...          27    06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...           0    06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...         120    06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...          14    06
#
# 0    county   tract block group
# 1       073  017808           2
# 2       073  017808           4
# 3       073  017808           3
# 4       073  017808           1
# 5       073  019101           1
# ...     ...     ...         ...
# 1791    073  017109           1
# 1792    073  017109           2
# 1793    073  017109           3
# 1794    073  017109           4
# 1795    073  017110           1
#
# [1795 rows x 6 columns]

# %%
df5.NAME
# Out:
# 1       Block Group 2, Census Tract 178.08, San Diego ...
# 2       Block Group 4, Census Tract 178.08, San Diego ...
# 3       Block Group 3, Census Tract 178.08, San Diego ...
# 4       Block Group 1, Census Tract 178.08, San Diego ...
# 5       Block Group 1, Census Tract 191.01, San Diego ...
#                               ...
# 1791    Block Group 1, Census Tract 171.09, San Diego ...
# 1792    Block Group 2, Census Tract 171.09, San Diego ...
# 1793    Block Group 3, Census Tract 171.09, San Diego ...
# 1794    Block Group 4, Census Tract 171.09, San Diego ...
# 1795    Block Group 1, Census Tract 171.10, San Diego ...
# Name: NAME, Length: 1795, dtype: object

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Female Estimates 5 - 9 years
#
# B01001_028E = Estimate!!Total!!Female!!5 to 9 years

# %%
url28 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_028E&for=block%20group:*&in=state:06%20county:073"

# B01001_028E added to url

response = urlopen(url28)
data = loads(response.read())

data
;
# Out:
# ''

# %%
df28 = pd.DataFrame.from_dict(data)

df28.columns = df28.iloc[0]

#set first row as the column names in the dataframe

df28
# Out:
# 0                                                  NAME  B01001_028E  state  \
# 0                                                  NAME  B01001_028E  state
# 1     Block Group 2, Census Tract 178.08, San Diego ...          135     06
# 2     Block Group 4, Census Tract 178.08, San Diego ...           14     06
# 3     Block Group 3, Census Tract 178.08, San Diego ...           38     06
# 4     Block Group 1, Census Tract 178.08, San Diego ...           12     06
# ...                                                 ...          ...    ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...          240     06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...           29     06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...           23     06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...           53     06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...            0     06
#
# 0     county   tract  block group
# 0     county   tract  block group
# 1        073  017808            2
# 2        073  017808            4
# 3        073  017808            3
# 4        073  017808            1
# ...      ...     ...          ...
# 1791     073  017109            1
# 1792     073  017109            2
# 1793     073  017109            3
# 1794     073  017109            4
# 1795     073  017110            1
#
# [1796 rows x 6 columns]

# %%
df28 = df28.iloc[1:]
df28

#delete row 0 after renaming columns
# Out:
# 0                                                  NAME B01001_028E state  \
# 1     Block Group 2, Census Tract 178.08, San Diego ...         135    06
# 2     Block Group 4, Census Tract 178.08, San Diego ...          14    06
# 3     Block Group 3, Census Tract 178.08, San Diego ...          38    06
# 4     Block Group 1, Census Tract 178.08, San Diego ...          12    06
# 5     Block Group 1, Census Tract 191.01, San Diego ...          43    06
# ...                                                 ...         ...   ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...         240    06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...          29    06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...          23    06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...          53    06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...           0    06
#
# 0    county   tract block group
# 1       073  017808           2
# 2       073  017808           4
# 3       073  017808           3
# 4       073  017808           1
# 5       073  019101           1
# ...     ...     ...         ...
# 1791    073  017109           1
# 1792    073  017109           2
# 1793    073  017109           3
# 1794    073  017109           4
# 1795    073  017110           1
#
# [1795 rows x 6 columns]

# %%
df28.NAME
# Out:
# 1       Block Group 2, Census Tract 178.08, San Diego ...
# 2       Block Group 4, Census Tract 178.08, San Diego ...
# 3       Block Group 3, Census Tract 178.08, San Diego ...
# 4       Block Group 1, Census Tract 178.08, San Diego ...
# 5       Block Group 1, Census Tract 191.01, San Diego ...
#                               ...
# 1791    Block Group 1, Census Tract 171.09, San Diego ...
# 1792    Block Group 2, Census Tract 171.09, San Diego ...
# 1793    Block Group 3, Census Tract 171.09, San Diego ...
# 1794    Block Group 4, Census Tract 171.09, San Diego ...
# 1795    Block Group 1, Census Tract 171.10, San Diego ...
# Name: NAME, Length: 1795, dtype: object

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# ## Dataframe for Total Female Estimates 10 - 14 years
#
# B01001_029E = Estimate!!Total!!Female!!10 to 14 years

# %%
url29 = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_029E&for=block%20group:*&in=state:06%20county:073"

#B01001_029E added to url

response = urlopen(url29)
data = loads(response.read())

data
;
# Out:
# ''

# %%
df29 = pd.DataFrame.from_dict(data)

df29.columns = df29.iloc[0]

#set first row as the column names in the dataframe

df29
# Out:
# 0                                                  NAME  B01001_029E  state  \
# 0                                                  NAME  B01001_029E  state
# 1     Block Group 2, Census Tract 178.08, San Diego ...          130     06
# 2     Block Group 4, Census Tract 178.08, San Diego ...           56     06
# 3     Block Group 3, Census Tract 178.08, San Diego ...           94     06
# 4     Block Group 1, Census Tract 178.08, San Diego ...           49     06
# ...                                                 ...          ...    ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...          176     06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...           94     06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...           43     06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...           87     06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...           86     06
#
# 0     county   tract  block group
# 0     county   tract  block group
# 1        073  017808            2
# 2        073  017808            4
# 3        073  017808            3
# 4        073  017808            1
# ...      ...     ...          ...
# 1791     073  017109            1
# 1792     073  017109            2
# 1793     073  017109            3
# 1794     073  017109            4
# 1795     073  017110            1
#
# [1796 rows x 6 columns]

# %%
df29 = df29.iloc[1:]
df29

#delete row 0 after renaming columns
# Out:
# 0                                                  NAME B01001_029E state  \
# 1     Block Group 2, Census Tract 178.08, San Diego ...         130    06
# 2     Block Group 4, Census Tract 178.08, San Diego ...          56    06
# 3     Block Group 3, Census Tract 178.08, San Diego ...          94    06
# 4     Block Group 1, Census Tract 178.08, San Diego ...          49    06
# 5     Block Group 1, Census Tract 191.01, San Diego ...          21    06
# ...                                                 ...         ...   ...
# 1791  Block Group 1, Census Tract 171.09, San Diego ...         176    06
# 1792  Block Group 2, Census Tract 171.09, San Diego ...          94    06
# 1793  Block Group 3, Census Tract 171.09, San Diego ...          43    06
# 1794  Block Group 4, Census Tract 171.09, San Diego ...          87    06
# 1795  Block Group 1, Census Tract 171.10, San Diego ...          86    06
#
# 0    county   tract block group
# 1       073  017808           2
# 2       073  017808           4
# 3       073  017808           3
# 4       073  017808           1
# 5       073  019101           1
# ...     ...     ...         ...
# 1791    073  017109           1
# 1792    073  017109           2
# 1793    073  017109           3
# 1794    073  017109           4
# 1795    073  017110           1
#
# [1795 rows x 6 columns]

# %%
df29.NAME
# Out:
# 1       Block Group 2, Census Tract 178.08, San Diego ...
# 2       Block Group 4, Census Tract 178.08, San Diego ...
# 3       Block Group 3, Census Tract 178.08, San Diego ...
# 4       Block Group 1, Census Tract 178.08, San Diego ...
# 5       Block Group 1, Census Tract 191.01, San Diego ...
#                               ...
# 1791    Block Group 1, Census Tract 171.09, San Diego ...
# 1792    Block Group 2, Census Tract 171.09, San Diego ...
# 1793    Block Group 3, Census Tract 171.09, San Diego ...
# 1794    Block Group 4, Census Tract 171.09, San Diego ...
# 1795    Block Group 1, Census Tract 171.10, San Diego ...
# Name: NAME, Length: 1795, dtype: object

# %%
# del df['NAME']

# code if we decide to drop NAME column

# %% [markdown]
# # Geographic Unit Variables from Urban

# %%
from urllib.request import urlopen
from json import loads
url = "https://educationdata.urban.org/api/v1/schools/nhgis/census-2010/2016/?state_mailing=CA&fips=06&county_fips_geo=06073"
response = urlopen(url)
data = loads(response.read())

# county_fips_geo = 06073 (San Diego)
# years available: 1986 - 2016 
# year = 2016
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-5731a06e2095> in <module>
#       2 from json import loads
#       3 url = "https://educationdata.urban.org/api/v1/schools/nhgis/census-2010/2016/?state_mailing=CA&fips=06&county_fips_geo=06073"
# ----> 4 response = urlopen(url)
#       5 data = loads(response.read())
#       6
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error

# %%
urban = pd.json_normalize(data, 'results')

urban

# %% [markdown]
# # Catchment (attendance boundaries)
#
# come courtesy of the [School Attendance Boundary Survey (SABS)](https://nces.ed.gov/programs/edge/SABS)

# %%
#pip install geopandas

# %%
import geopandas as gpd

# %%
attbound = gpd.read_file("data/nces_att_bound/SABS_1516/SABS_1516.shp")
